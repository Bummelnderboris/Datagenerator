# %% [markdown]
# This notebook suggests an approach for generating dynamicly kategorial data. The idea is, to define intial kategories as a small bag of unique elements with different behaviours and probabilities, that a behaviour will appear. (As an example: A behaviour is: elaborate this topic, and the probility according to the behaviour will result in a probaility a topic is elaborated. Another behaviour for example is the tendency for beeing used in different documents. The following UML activity diagram summatizes the algorithm.
#
# (As a prototype this notebook will use random uniform distributions as functions).

# %% [markdown]
# ![Generator_Konzept.drawio.png](attachment:Generator_Konzept.drawio.png)

# %%
## First the needed bibliotheks and imports have to be set up
#!pip install numpy
#!pip install faker
#!...


##RENAME TEMPORARY VARIABLES WITH A t_ IN THE BEGINNING

# %%
#this cell handles imports / set ups

##LIBRARIES

#"Faker is a Python package that generates fake data for you. " [from the Faker documentation]
#import faker library
from faker import Faker
#create an instance of Faker
fake = Faker()


import random as rnd
import numpy as np
import pandas as pd
import random as rng
import matplotlib.pyplot as plt



# Set the precision of decimals for the whole notebook on 2
np.set_printoptions(precision=3, suppress=True)

# %%
##THIS CELL CONTAINS SOME SIMPLE FUNCTIONS WHICH WILL BE USED MORE OFTEN IN THE PROGRAMM

#Declare a decision boundry function, to create a boundry value each time a decision is to be made**
def decide():
    decision_boundry = np.random.uniform(0,1,1)
    return decision_boundry

#Declare a function to let values vary along a uniform distribution around a given variation. This is a placeholder function for **
def uniform_variance(value, variation):
    low_boarder = value - value * variation
    top_boarder = value + value * variation
    
    value = np.random.uniform(low_boarder,top_boarder,1)
    return value

# %%
###GENERATE BAG OF UNIQUE ELEMENTS
##Set the size of the bag of unique Elements
    
#PUT LATER INTO "MAIN-CELL"
words_to_create = 150000

#This function takes an integer and returns a list of unique words which is the size of the given integer minus deletet doublicates 
def create_bag_of_words(word_amount_to_create):

    words = []

    words_created=0
    
    while words_created < word_amount_to_create:
        words.append(fake.word())
        words_created = words_created + 1 

    
    #check for duplikates
    unique_words = []
    double = 0
    for x in words:
        if x not in unique_words:
            unique_words.append(x)
        else:
            double=+1
    
    return unique_words
            
            
#CREATE A FUNCTION FOR FREQUENTLY USED WORDS (FOR SENTENCE GENERATION)
def create_bag_of_frequently_used_words():
    #Create a list of frequently used words
    frequently_used_words = []
    frequently_used_words.append(words[:100])
    del words[:100]
    
    return frequently_used_words


words = create_bag_of_words(words_to_create)
## Comment:
#Combination of frequently used words and 'normal' words to create sentences with topic words**

# %%
###INITIALIZE FIRST ROW OF TOPICS

##Create bag of x topics
topic_amount = 5

#This function takes an amount of topics as integer and returns a list of empty lists according to the amount
def initialize_empty_topics(amounts_of_topics):
    
    topics_to_create = amounts_of_topics

    ##Create empty list of initial topics
    topic_list_empty = []
    topics_created = 0
    while topics_created < topics_to_create:
        topic_list_empty.insert(0, [])
        topics_created += 1
    
    return topic_list_empty


topic_list_empty = initialize_empty_topics(topic_amount)

topic_list_empty
# Out:
# [[], [], [], [], []]

# %%
###INITIALIZE BEHAVIOURAL PROBABILITIES FOR EACH TOPIC

##This function takes an empty topic list and generate for each topic probabilities, different behaviours will occeu
##Note: The behaviours are implemented as fucntions which are called depending on a random decisionboundry for each 
##generation step and the in this function (initialize_topic_behaviour_parameters) stated probabilities. This 
##implementation aims to mimic tendencies for behaviours.
def initialize_topic_behaviour_parameters(empty_topic_list):

    for topic in empty_topic_list:
        
        
        #Initialize the behavioural parameters**
        topic_probability_is_elaborated = np.random.uniform(0,1,1)
        topic_probability_is_used = np.random.uniform(0,1,1)
        
        topic_probability_creates_new_word = np.random.uniform(0,0.3,1)
        topic_probability_uses_different_topic = np.random.uniform(0,0.3,1)
        #Setting the behavioural parameters here just with implemented with standard uniform distributions in a certain range
        #between 0 and 1. Refining these functions in future work could include changing behavioural probabilities depending 
        #on topic size and topic contents.
        
        
        behavioural_paramters = topic_probability_is_elaborated, topic_probability_is_used 
        #,topic_probability_creates_new_word, topic_probability_uses_different_topic
        
        #The parameters are stored in a tupel, so the tupel can be appended to 
        #a topic as behavioural probabilites and can alway be called as the
        #last item in the list of elements of a topic (topic words are inserted in first position)
        #This architecture is designed to support future implementations of different
        #behavioural paramters.
        
        topic.append(behavioural_paramters)
        

initialize_topic_behaviour_parameters(topic_list_empty)
topic_list_empty
# Out:
# [[(array([0.768]), array([0.822]))],
#  [(array([0.916]), array([0.851]))],
#  [(array([0.488]), array([0.351]))],
#  [(array([0.57]), array([0.118]))],
#  [(array([0.006]), array([0.532]))]]

# %%
###INITIALIZE KEYWORDS FOR EACH TOPIC

#State the low and top boarder for key words per topic
min_words_per_topic = 1 
max_words_per_topic = 5


#Define a function which will return a uniform distributed random** amount of keywords per topic, in the range of 
#min_words_per_topics to max_words_per_topic
def set_keywordamount_per_topic():
    topic_keywords = rnd.randint(min_words_per_topic, max_words_per_topic)
    return topic_keywords


#Define a function which will insert the initial keywords for every topic
def initialize_keywords_to_topic(empty_topic_list):
    for topic in empty_topic_list:
        keyword_amount = set_keywordamount_per_topic()
        keywords_inserted = 0
        while keywords_inserted < keyword_amount:
            #Append a unique word to the topic as a keyword of this topic
            topic.insert(0,words[keywords_inserted])
            #Delete the word out of the baggs of words to ensure, this entry won't be taken a second time
            del words[keywords_inserted]
            keywords_inserted = keywords_inserted +1
    return (empty_topic_list)

topic_list = initialize_keywords_to_topic(topic_list_empty)
# Print the keywords of each topic.
for topic in topic_list:
    print(topic)
# Out:
# ['field', 'also', 'candidate', (array([0.768]), array([0.822]))]
# ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))]
# ['drop', (array([0.488]), array([0.351]))]
# ['color', 'hit', 'factor', (array([0.57]), array([0.118]))]
# ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]

# %%
###SET OF FUNCTIONS FOR THE BEHAVIOUR OF WORD COMPOSITION FOR SUBTOPIC

##Each function is connected to each topic with the tuple holding propabilities of a topic, these probabilities are
##are the tendencies, that a behaviour (declared in the following function set) will appear. With this implementation
##behaviours (defined as functions) can be connected to topics with different tendencies to appear with probabilities.
##Note: To embedd a dynamicly working structure with different amounts of function inputs, future work should replace
##the tuple with (something like) a nested list which generates itself depending on the set of functions picked.
##Note: Each of these functions can call topic as the current list of keywords and probabilites of a topic as they are called
##in create_subtopic_space which is called in elaborate_topic_list on each topic of the given 

#This function just connects two words to a new word and cuts a word if the connected words becomes to long. This can be 
#refined by regenerating two complete new words which can be topics. 
def creates_new_word(word):
    print(len(word))
    word = word + words[rnd.randint(0,20)]
    
    # If the word gets to long cut it at a random amount between 2 and 4
    if len(word)>15:
        word = word[-6:]
        #print(word[:5])
    return word


#This function alway returns the first word of a random topic
def use_different_topic():
    word = str
    word = topic_list[rnd.randint(0,len(topic_list)-1)][0]
    return word

# %%
###CREATE A SUBTOPIC SPACE FOR TOPIC




#This function is called by elaborate_topic_list and takes a topic as a list of elements within this topic and the
#information of tendencies how the topic behaves as a tuple of probabilities and returns an elaboration of that topic,
#here called subtopic (a subtopic is an elaboration of a topic) with changed probabilities.
def create_subtopic_space(topic):
    
    t_subtopic = []
    
    
    #Set the amounts of words used in that subtopic
    subtopic_word_amount = rnd.randint(1,8)
    subtopic_words_picked = 0
    print(topic_list)
    while subtopic_words_picked < subtopic_word_amount:
        decisionboundry = decide()
        #topic_list[position of topics][position of words in topics]

        #Always use a random word from the topic space for the subtopic
        position_word_elaborated = rnd.randint(0,len(topic)-2)
        #print(position_word_elaborated)

        t_subtopic.insert(0,topic[position_word_elaborated])
        #print(topic[position_word_elaborated])
        subtopic_words_picked += 1
        
        
        
        
        ##Check if a special behaviour for elaboration is triggered
        #Set the decision boundry new for each elaboration (doing so and not setting one decision boundry) for each
        #generation enables the behaviour of tendencies.
        
        #Maybe use a different topic here
        probability_use_other_topic = 0.5 #**
        if probability_use_other_topic > decisionboundry:
            t_word = str
            t_word = use_different_topic()
            t_subtopic.insert(0,t_word)
            subtopic_words_picked += 1
        
        #Maybe create a new word
        probability_merge_new_word = 0.5 #**
        if probability_merge_new_word > decisionboundry:
            #subtopic[0] uses the word which was just inserted
            new_word = creates_new_word(t_subtopic[rnd.randint(0,len(t_subtopic)-1)])
            t_subtopic.insert(0,new_word)
            #print(subtopic)
            subtopic_words_picked += 1
            
        #Maybe bring a new word in topic space.. pending

        #Maybe use a topic from another topic space (parent generation) ...pending


    ##Vary the behaviour probabilities of each subtopic**
    #sub_topic_paramter_1 = uniform_variance(topic[-1][0],0.1)
    #sub_topic_paramter_2 = uniform_variance(topic[-1][1],0.1)
    subtopic_parameters = np.random.uniform(0,1,1), np.random.uniform(0,1,1)
    t_subtopic.append(subtopic_parameters)

    
    #print(t_subtopic)
    #print(topic)
    return t_subtopic

# %%
###THIS CELL elaborates a given list of topics to a next generation of topic

#Create the list, where each subtopic generation will be stored  
topic_space_master = []

subtopic = []



#This function takes a list of topics, checks if the probability if a topic is elaborated and if yes, 
#calls create_subtopic_space on the current topic, takes the result and stores it as a sub topic in the subtopic_space.
#In the end the function appends the temporary subtopic_space to the global topic_space_master. (This implementation,
#let have each generation stored in an own list of lists with the most current once in the beginning)
def elaborate_topic_list(topic_list):

    subtopic_space = []
    for topic in topic_list:
        
        topic_counter = 0
        
        #This loop elaborates a topic dpeending on its probability to be elaborated until the decision_boundry will be
        #above the topic probability for being elaborated
        while True: 
            
            decision_boundry = decide()

            t_subtopic = []
            
            
            #subtopic_space = []
            if topic[-1][0][0] > decision_boundry:
                #print(topic[-1][0][0])
                #print(decision_boundry)
                
                #Call the create_subtopic_space_function which returns a subtopic space for the topic including new elements and 
                #new behaviour parameters depending on the topic given as input and append it to the subtopic space.

                t_subtopic = create_subtopic_space(topic)

                
                
                #Store the new generation
                subtopic_space.append(t_subtopic)
                #print(subtopic_space)
                #print("Appending subtopic")
                
                topic_counter += 1
                print(topic_counter)
                if topic_counter > 10:
                    break
            else:
                #print("Breaking while")
                break
    
    #print("Returning subtopic")
    #print(subtopic_space)
    #for t_subtopic in 
    #print(t_subtopic)
    return subtopic_space

# %%
###LAST CELL TO EXECUTE
###INITIALIZE GENERATOR OVER N GENERATIONS

#Set the amount of generations to create
amount_of_generations = 4

topic_space_master = []

#This function creates a given amount of generation by calling the elaborate_topic_list function
def start_generator(list_of_topics):
    #Insert the root topics to the master list
    topic_space_master.insert(0,list_of_topics)
    print("topic_space_master")
    print(topic_space_master)
    
    #Initialize the new_topic_generation variable which is handed to the elaborate_topic_list function
    new_topic_generation = elaborate_topic_list( topic_space_master[0])
    topic_space_master.insert(0,new_topic_generation)
    
    
    generations_created = 0
    print(generations_created)
    
    while generations_created < amount_of_generations:
     
        next_topic_generation = elaborate_topic_list(topic_space_master[0])
        print(next_topic_generation)
        topic_space_master.insert(0,next_topic_generation)
        
        generations_created += 1

    return topic_list


    ##HANDING NEW TOPIC SPACE TO THE NEXT ITERATION NEEDED.

# %%
topic_list_master = start_generator(topic_list)
# Out:
# topic_space_master
# [[['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]]
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 4
# 8
# 1
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 4
# 4
# 2
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 5
# 1
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 5
# 2
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 8
# 3
# 3
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 4
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 8
# 5
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 4
# 6
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 5
# 4
# 7
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 8
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 4
# 1
# 0
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 4
# 1
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 5
# 2
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 4
# 4
# 5
# 3
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 6
# 5
# 6
# 4
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 5
# 6
# 5
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 5
# 6
# 6
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 6
# 6
# 7
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 3
# 8
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 4
# 9
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 15
# 6
# 10
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 8
# 4
# 11
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 1
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 3
# 5
# 2
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 5
# 3
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 4
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 5
# 5
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 6
# 6
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 7
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 5
# 8
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 5
# 9
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 5
# 5
# 10
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 4
# 11
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 3
# 12
# 1
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 8
# 6
# 1
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 6
# 8
# 2
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 6
# 3
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 4
# 4
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 3
# 3
# 5
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 4
# 4
# 1
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 8
# 2
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 3
# 8
# 3
# 3
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 11
# 4
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 6
# 5
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 4
# 5
# 6
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 5
# 8
# 7
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 5
# 1
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 5
# 2
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 5
# 4
# 3
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 4
# 4
# 4
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 4
# 5
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 6
# 6
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 4
# 7
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 8
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 5
# 9
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 10
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 4
# 11
# [['dropfind', 'drop', 'also', (array([0.028]), array([0.45]))], ['fieldany', 'color', 'field', (array([0.057]), array([0.267]))], ['fieldworld', 'drop', 'field', 'alsopositive', 'color', 'alsokind', 'alsokind', 'alsoonto', 'color', 'also', (array([0.369]), array([0.488]))], ['agencyme', 'agency', 'also', 'colorhalf', 'color', 'field', 'also', 'agencykind', 'color', 'agency', (array([0.687]), array([0.441]))], ['nology', 'field', 'agency', 'alsokindprovide', 'alsokindprovide', 'fieldimportant', 'field', 'agency', (array([0.416]), array([0.596]))], ['agencyperform', 'nor', 'also', 'fieldme', 'field', 'agency', (array([0.079]), array([0.668]))], ['agencyhope', 'field', 'agency', 'agency', 'agencyperform', 'agency', 'agency', (array([0.265]), array([0.126]))], ['nortechnology', 'nor', 'also', (array([0.262]), array([0.365]))], ['alsopainting', 'nor', 'field', 'also', 'agency', 'alsokindprovide', 'agency', (array([0.092]), array([0.077]))], ['oulderperform', 'agency', 'field', 'oulder', 'nor', 'field', 'field', 'field', 'alsokindprovide', (array([0.888]), array([0.011]))], ['alsopositive', 'field', 'alsokindprovide', 'alsokindwater', 'field', 'alsokind', 'also', (array([0.24]), array([0.581]))], ['also', 'field', (array([0.736]), array([0.588]))], ['colorhim', 'field', 'nor', 'norhim', 'color', 'nor', (array([0.514]), array([0.348]))], ['fieldcivil', 'field', 'field', 'alsopainting', (array([0.704]), array([0.583]))], ['nor', (array([0.187]), array([0.038]))], ['fieldkind', 'agency', 'field', 'dropany', (array([0.191]), array([0.744]))], ['agencyhalf', 'agency', 'alsopainting', (array([0.984]), array([0.127]))], ['alsopainting', 'also', 'field', 'alsopainting', 'nor', 'field', 'also', (array([0.067]), array([0.057]))], ['colortechnology', 'color', 'nor', (array([0.674]), array([0.283]))], ['nor', 'colorshoulder', 'color', 'drop', (array([0.52]), array([0.224]))], ['fieldfind', 'nor', 'field', 'dropany', 'fieldtechnology', 'drop', 'dropany', 'field', (array([0.207]), array([0.894]))], ['alsotechnology', 'agency', 'also', (array([0.464]), array([0.766]))], ['zehalf', 'agency', 'majority', 'norrecognize', 'nor', 'ahead', (array([0.777]), array([0.048]))], ['majority', 'agencylong', 'agency', 'majority', 'majorityperform', 'agency', 'majority', 'majority', (array([0.602]), array([0.801]))], ['majoritykind', 'nor', 'majority', 'majority', 'agencyhope', 'agency', 'majority', 'majority', (array([0.92]), array([0.293]))], ['majority', 'majority', 'agencyfind', 'agency', 'majority', 'majority', (array([0.756]), array([0.187]))], ['droppositive', 'drop', 'majority', (array([0.751]), array([0.185]))], ['norworld', 'agency', 'majority', 'norhalf', 'nor', 'majority', 'majority', (array([0.74]), array([0.738]))], ['dropimportant', 'field', 'although', 'field', 'dropprovide', 'drop', 'although', (array([0.982]), array([0.412]))], ['oulder', 'agency', 'although', 'although', (array([0.97]), array([0.738]))], ['norhim', 'field', 'althoughany', 'althoughprovide', 'field', 'although', 'norimportant', 'nor', 'although', (array([0.347]), array([0.882]))], ['inting', 'nor', 'field', 'althoughany', 'although', (array([0.565]), array([0.146]))], ['althoughany', 'although', 'although', 'althoughany', 'field', 'agencykind', 'agency', 'although', (array([0.473]), array([0.399]))], ['fieldwife', 'field', 'although', 'dropme', 'drop', 'field', (array([0.431]), array([0.382]))], ['althoughperform', 'nor', 'althoughany', 'colorworld', 'color', 'although', 'although', 'althoughany', (array([0.249]), array([0.371]))], ['fieldpositive', 'field', 'dropshoulder', 'drop', (array([0.265]), array([0.749]))], ['fieldfind', 'field', 'drop', (array([0.389]), array([0.56]))], ['dropshoulder', 'dropwater', 'field', 'drop', 'drop', 'colorhim', 'color', 'drop', (array([0.651]), array([0.925]))], ['dropwife', 'color', 'drop', 'drop', 'drop', 'drophalf', 'color', 'drop', (array([0.1]), array([0.315]))], ['drop', 'dropfind', 'field', 'dropshoulder', 'drop', 'drop', 'drop', 'drop' ...
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 8
# 1
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 1
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 5
# 1
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 5
# 13
# 2
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 3
# 3
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 8
# 1
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 5
# 1
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 3
# 1
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 1
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 6
# 2
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 15
# 3
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 4
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 5
# 9
# 3
# 1
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 4
# 1
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 2
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 4
# 1
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 8
# 2
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 5
# 3
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 6
# 5
# 3
# 4
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 3
# 1
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 8
# 5
# 1
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 2
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 10
# 3
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 8
# 6
# 4
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 3
# 8
# 5
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 6
# 6
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 6
# 6
# 7
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 8
# 1
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 6
# 2
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 10
# 3
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 4
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 5
# 5
# 5
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 6
# 6
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 8
# 7
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 3
# 8
# 11
# 8
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 3
# 11
# 9
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 6
# 10
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 5
# 1
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 5
# 8
# 2
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 8
# 8
# 3
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 5
# 1
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 4
# 2
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 4
# 8
# 3
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 5
# 4
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 5
# 5
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 4
# 6
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 8
# 7
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 3
# 3
# 5
# 8
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 5
# 13
# 9
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 10
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 11
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 6
# 1
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 5
# 2
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 8
# 6
# 6
# 3
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 8
# 4
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 6
# 6
# 5
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 6
# 6
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 8
# 7
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 6
# 8
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 5
# 9
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 4
# 10
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 6
# 6
# 4
# 11
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 5
# 1
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 11
# 1
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 11
# 11
# 2
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 5
# 1
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 10
# 2
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 5
# 4
# 4
# 1
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 4
# 2
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 5
# 1
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 4
# 2
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 9
# 3
# ...
# 5
# 6
# 8
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 3
# 4
# 9
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 10
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 11
# 8
# 11
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 1
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 12
# 12
# 1
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 6
# 11
# 2
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 5
# 3
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 5
# 4
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 5
# 3
# 5
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 6
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 15
# 7
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 5
# 8
# 8
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 9
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 5
# 3
# 1
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 15
# 2
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 5
# 8
# 3
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 5
# 4
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 15
# 8
# 5
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 12
# 6
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 5
# 7
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 5
# 8
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 8
# 9
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 12
# 12
# 10
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 11
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 5
# 1
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 3
# 10
# 2
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 3
# 3
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 4
# 3
# 3
# 1
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 5
# 2
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 6
# 3
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 1
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 3
# 13
# 2
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 4
# 5
# 3
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 4
# 4
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))], ['agency', 'ahead', 'effort', 'majority', 'although', (array([0.916]), array([0.851]))], ['drop', (array([0.488]), array([0.351]))], ['color', 'hit', 'factor', (array([0.57]), array([0.118]))], ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]
# 10
# 5
# [['colorhim', 'color', 'color', 'also', 'also', (array([0.41]), array([0.732]))], ['norme', 'nor', 'drop', 'alsofind', 'agency', 'also', (array([0.523]), array([0.874]))], ['agencyshoulder', 'agency', 'also', (array([0.627]), array([0.764]))], ['oulder', 'drop', 'also', 'alsocivil', (array([0.426]), array([0.03]))], ['agencyme', 'agency', 'also', (array([0.281]), array([0.543]))], ['alsopositive', 'field', 'drop', 'also', 'drop', (array([0.475]), array([0.407]))], ['agencywife', 'agency', 'color', 'agencylong', 'agency', 'drop', (array([0.097]), array([0.166]))], ['droplong', 'drop', 'color', (array([0.678]), array([0.909]))], ['alsocivil', (array([0.384]), array([0.519]))], ['norshoulder', 'nor', 'agencyme', 'norpainting', 'nor', 'drop', 'drop', 'also', (array([0.772]), array([0.318]))], ['orldme', 'field', 'drop', 'alsocivilworld', 'field', 'drop', 'alsocivil', (array([0.385]), array([0.368]))], ['agency', 'agencymehim', 'agencyperform', 'agency', (array([0.738]), array([0.2]))], ['field', 'norpaintingfind', 'color', 'agencymehim', 'norpainting', 'nor', 'nor', (array([0.92]), array([0.427]))], ['agencyfind', 'agency', 'agencyme', 'mwater', (array([0.788]), array([0.038]))], ['colorany', 'agency', 'color', 'color', 'color', (array([0.264]), array([0.916]))], ['sitive', 'agency', 'drop', 'norwater', 'agency', 'agency', 'norimportant', 'nor', 'agencyfind', 'agency', (array([0.322]), array([0.695]))], ['agencywife', 'field', 'agencyfind', 'droppainting', 'agency', 'drop', (array([0.205]), array([0.528]))], ['droppositive', 'drop', 'drop', (array([0.212]), array([0.485]))], ['ortant', 'field', 'agencyrecognize', 'ortant', 'color', 'oulder', 'drop', 'dropwife', 'drop', 'drop', (array([0.493]), array([0.33]))], ['fieldshoulder', 'nor', 'drop', 'fieldany', 'drop', 'field', (array([0.973]), array([0.205]))], ['nizeme', 'agency', 'agencyrecognize', (array([0.373]), array([0.897]))], ['agencyfindworld', 'agency', 'agencyfind', (array([0.559]), array([0.29]))], ['drop', 'oulder', 'nology', 'agency', 'agency', (array([0.992]), array([0.908]))], ['agency', (array([0.724]), array([0.884]))], ['agencyfindworld', 'nor', 'agency', 'agencyfind', (array([0.047]), array([0.091]))], ['agencypainting', 'color', 'agencyrecognize', 'field', 'agencyprovide', 'color', 'agency', (array([0.126]), array([0.8]))], ['drop', (array([0.228]), array([0.086]))], ['dropmeany', 'agency', 'agency', 'dropme', (array([0.963]), array([0.407]))], ['dropmeonto', 'nor', 'dropme', 'field', 'alsokindwife', 'field', 'dropprovide', 'fieldany', 'field', 'dropme', (array([0.297]), array([0.501]))], ['dropshoulder', 'drop', 'dropprovide', (array([0.514]), array([0.986]))], ['droplong', 'agency', 'fieldcivil', 'fieldcivil', 'drop', (array([0.939]), array([0.03]))], ['norhalf', 'nor', 'fieldcivil', (array([0.292]), array([0.225]))], ['norwife', 'nor', 'alsokind', (array([0.738]), array([0.559]))], ['fieldcivil', 'color', 'drop', 'field', (array([0.948]), array([0.397]))], ['dropprovide', 'drop', 'drop', 'dropme', 'agencywife', 'drop', 'agency', (array([0.253]), array([0.529]))], ['drop', 'drophalf', 'drop', 'field', (array([0.648]), array([0.044]))], ['agency', 'droplong', 'nor', 'dropprovide', 'drop', 'agency', (array([0.512]), array([0.411]))], ['norhalf', 'color', 'nor', 'norfind', 'color', 'nor', 'nor', (array([0.706]), array([0.908]))], ['fieldimportant', 'agency', 'colorfind', 'fieldwater', 'colorfind', 'field', 'drophim', 'drop', 'fieldwater', (array([0.906]), array([0.889]))], ['norprovidefind', 'agency', 'nor', 'norprovide', 'field', 'nor', (array([0.867]), array([0.67]))], ['colortechnology', 'agency', 'fieldwater', 'coloronto', 'field', 'colorfind', 'color', 'colorfind', (array([0.756]), array([0.95]))], ['dropimportant', 'drop', 'fieldwater', 'nor', 'fieldwater', 'fieldwater', 'dropimportant', 'drop', 'field', (array([0.898]), array([0.944]))], ['norrecognizeme', 'drop', 'nor', 'field', 'colorfind', 'norrecognize', 'color', 'color', 'nor', (array([0.013]), array([0. ...

# %%
topic_space_master
# Out:
# [[['colorhim',
#    'color',
#    'color',
#    'also',
#    'also',
#    (array([0.41]), array([0.732]))],
#   ['norme',
#    'nor',
#    'drop',
#    'alsofind',
#    'agency',
#    'also',
#    (array([0.523]), array([0.874]))],
#   ['agencyshoulder', 'agency', 'also', (array([0.627]), array([0.764]))],
#   ['oulder', 'drop', 'also', 'alsocivil', (array([0.426]), array([0.03]))],
#   ['agencyme', 'agency', 'also', (array([0.281]), array([0.543]))],
#   ['alsopositive',
#    'field',
#    'drop',
#    'also',
#    'drop',
#    (array([0.475]), array([0.407]))],
#   ['agencywife',
#    'agency',
#    'color',
#    'agencylong',
#    'agency',
#    'drop',
#    (array([0.097]), array([0.166]))],
#   ['droplong', 'drop', 'color', (array([0.678]), array([0.909]))],
#   ['alsocivil', (array([0.384]), array([0.519]))],
#   ['norshoulder',
#    'nor',
#    'agencyme',
#    'norpainting',
#    'nor',
#    'drop',
#    'drop',
#    'also',
#    (array([0.772]), array([0.318]))],
#   ['orldme',
#    'field',
#    'drop',
#    'alsocivilworld',
#    'field',
#    'drop',
#    'alsocivil',
#    (array([0.385]), array([0.368]))],
#   ['agency',
#    'agencymehim',
#    'agencyperform',
#    'agency',
#    (array([0.738]), array([0.2]))],
#   ['field',
#    'norpaintingfind',
#    'color',
#    'agencymehim',
#    'norpainting',
#    'nor',
#    'nor',
#    (array([0.92]), array([0.427]))],
#   ['agencyfind',
#    'agency',
#    'agencyme',
#    'mwater',
#    (array([0.788]), array([0.038]))],
#   ['colorany',
#    'agency',
#    'color',
#    'color',
#    'color',
#    (array([0.264]), array([0.916]))],
#   ['sitive',
#    'agency',
#    'drop',
#    'norwater',
#    'agency',
#    'agency',
#    'norimportant',
#    'nor',
#    'agencyfind',
#    'agency',
#    (array([0.322]), array([0.695]))],
#   ['agencywife',
#    'field',
#    'agencyfind',
#    'droppainting',
#    'agency',
#    'drop',
#    (array([0.205]), array([0.528]))],
#   ['droppositive', 'drop', 'drop', (array([0.212]), array([0.485]))],
#   ['ortant',
#    'field',
#    'agencyrecognize',
#    'ortant',
#    'color',
#    'oulder',
#    'drop',
#    'dropwife',
#    'drop',
#    'drop',
#    (array([0.493]), array([0.33]))],
#   ['fieldshoulder',
#    'nor',
#    'drop',
#    'fieldany',
#    'drop',
#    'field',
#    (array([0.973]), array([0.205]))],
#   ['nizeme', 'agency', 'agencyrecognize', (array([0.373]), array([0.897]))],
#   ['agencyfindworld', 'agency', 'agencyfind', (array([0.559]), array([0.29]))],
#   ['drop',
#    'oulder',
#    'nology',
#    'agency',
#    'agency',
#    (array([0.992]), array([0.908]))],
#   ['agency', (array([0.724]), array([0.884]))],
#   ['agencyfindworld',
#    'nor',
#    'agency',
#    'agencyfind',
#    (array([0.047]), array([0.091]))],
#   ['agencypainting',
#    'color',
#    'agencyrecognize',
#    'field',
#    'agencyprovide',
#    'color',
#    'agency',
#    (array([0.126]), array([0.8]))],
#   ['drop', (array([0.228]), array([0.086]))],
#   ['dropmeany',
#    'agency',
#    'agency',
#    'dropme',
#    (array([0.963]), array([0.407]))],
#   ['dropmeonto',
#    'nor',
#    'dropme',
#    'field',
#    'alsokindwife',
#    'field',
#    'dropprovide',
#    'fieldany',
#    'field',
#    'dropme',
#    (array([0.297]), array([0.501]))],
#   ['dropshoulder', 'drop', 'dropprovide', (array([0.514]), array([0.986]))],
#   ['droplong',
#    'agency',
#    'fieldcivil',
#    'fieldcivil',
#    'drop',
#    (array([0.939]), array([0.03]))],
#   ['norhalf', 'nor', 'fieldcivil', (array([0.292]), array([0.225]))],
#   ['norwife', 'nor', 'alsokind', (array([0.738]), array([0.559]))],
#   ['fieldcivil', 'color', 'drop', 'field', (array([0.948]), array([0.397]))],
#   ['dropprovide',
#    'drop',
#    'drop',
#    'dropme',
#    'agencywife',
#    'drop',
#    'agency',
#    (array([0.253]), array([0.529]))],
#   ['drop', 'drophalf', 'drop', 'field', (array([0.648]), array([0.044]))],
#   ['agency',
#    'droplong',
#    'nor',
#    'dropprovide',
#    'drop',
#    'agency',
#    (array([0.512]), array([0.411]))],
#   ['norhalf',
#    'color',
#    'nor',
#    'norfind',
#    'color',
#    'nor',
#    'nor',
#    (array([0.706]), array([0.908]))],
#   ['fieldimportant',
#    'agency',
#    'colorfind',
#    'fieldwater',
#    'colorfind',
#    'field',
#    'drophim',
#    'drop',
#    'fieldwater',
#    (array([0.906]), array([0.889]))],
#   ['norprovidefind',
#    'agency',
#    'nor',
#    'norprovide',
#    'field',
#    'nor',
#    (array([0.867]), array([0.67]))],
#   ['colortechnology',
#    'agency',
#    'fieldwater',
#    'coloronto',
#    'field',
#    'colorfind',
#    'color',
#    'colorfind',
#    (array([0.756]), array([0.95]))],
#   ['dropimportant',
#    'drop',
#    'fieldwater',
#    'nor',
#    'fieldwater',
#    'fieldwater',
#    'dropimportant',
#    'drop',
#    'field',
#    (array([0.898]), array([0.944]))],
#   ['norrecognizeme',
#    'drop',
#    'nor',
#    'field',
#    'colorfind',
#    'norrecognize',
#    'color',
#    'color',
#    'nor',
#    (array([0.013]), array([0.274]))],
#   ['nor', 'norimportant', 'field', 'nor', (array([0.894]), array([0.505]))],
#   ['norcivil', 'field', 'field', 'drop', (array([0.327]), array([0.799]))],
#   ['norhalf',
#    'nor',
#    'nor',
#    'norcivil',
#    'nor',
#    'drop',
#    (array([0.707]), array([0.034]))],
#   ['dropwife',
#    'field',
#    'nor',
#    'dropany',
#    'field',
#    'drop',
#    'norfind',
#    'field',
#    'nor',
#    (array([0.233]), array([0.616]))],
#   ['fieldfind',
#    'color',
#    'norcivil',
#    'nor',
#    'norhope',
#    'field',
#    'nor',
#    'field',
#    'norcivil',
#    (array([0.028]), array([0.78]))],
#   ['ortant',
#    'agency',
#    'colorme',
#    'colorme',
#    'colorlong',
#    'agency',
#    'color',
#    (array([0.86]), array([0.278]))],
#   ['colorme',
#    'fieldhope',
#    'field',
#    'colorme',
#    'fieldhope',
#    'field',
#    'nor',
#    (array([0.718]), array([0.216]))],
#   ['agencyhalf',
#    'drop',
#    'field',
#    'fieldwifecivil',
#    'agency',
#    'field',
#    'fieldwife',
#    (array([0.72]), array([0.591]))],
#   ['field', 'norprovide', 'nor', 'nor', (array([0.086]), array([0.426]))],
#   ['nor', (array([0.189]), array([0.366]))],
#   ['nor', 'field', 'norany', (array([0.12]), array([0.767]))],
#   ['noranyhimwater',
#    'nor',
#    'field',
#    'noranyhim',
#    'color',
#    'norany',
#    'norany',
#    (array([0.133]), array([0.805]))],
#   ['norany',
#    'norany',
#    'nor',
#    'nor',
#    'noranyhim',
#    'field',
#    'norany',
#    (array([0.169]), array([0.919]))],
#   ['dropwater', 'drop', 'field', (array([0.818]), array([0.537]))],
#   ['agencyfind',
#    'drop',
#    'alsotechnology',
#    'fieldpositive',
#    'agency',
#    'field',
#    (array([0.329]), array([0.936]))],
#   ['alsotechnology', 'alsotechnology', (array([0.201]), array([0.905]))],
#   ['rwater',
#    'field',
#    'agency',
#    'also',
#    'alsoshoulder',
#    'drop',
#    'also',
#    'alsotechnology',
#    (array([0.79]), array([0.702]))],
#   ['alsofind', 'color', 'also', (array([0.681]), array([0.389]))],
#   ['norwater',
#    'agency',
#    'agency',
#    'norhalf',
#    'nor',
#    'alsohim',
#    'also',
#    (array([0.013]), array([0.294]))],
#   ['also',
#    'also',
#    'agency',
#    'also',
#    'rovide',
#    'field',
#    'alsotechnology',
#    'alsotechnology',
#    (array([0.998]), array([0.486]))],
#   ['agency',
#    'alsohim',
#    'alsohimwife',
#    'agency',
#    'alsohim',
#    'alsotechnology',
#    (array([0.034]), array([0.55]))],
#   ['agency', 'also', 'also', (array([0.626]), array([0.777]))],
#   ['norperform', 'nor', 'also', (array([0.513]), array([0.984]))],
#   ['dropfind',
#    'drop',
#    'agency',
#    'alsotechnology',
#    (array([0.486]), array([0.368]))],
#   ['fieldpainting',
#    'field',
#    'field',
#    'alsoworld',
#    'droponto',
#    'drop',
#    'alsoworld',
#    (array([0.79]), array([0.392]))],
#   ['also', 'fieldhalf', 'field', 'also', (array([0.815]), array([0.784]))],
#   ['alsoonto', 'field', 'also', (array([0.434]), array([0.35]))],
#   ['norhope', 'nor', 'also', (array([0.229]), array([0.966]))],
#   ['alsoprovide', 'agency', 'also', 'also', (array([0.13]), array([0.413]))],
#   ['droptechnology', 'drop', 'also', (array([0.759]), array([0.341]))],
#   ['alsoanyprovide',
#    'nor',
#    'also',
#    'also',
#    'also',
#    'alsoany',
#    'drop',
#    'also',
#    (array([0.775]), array([0.288]))],
#   ['alsohope',
#    'color',
#    'also',
#    'also',
#    'also',
#    'also',
#    'alsoprovide',
#    'agency',
#    'also',
#    (array([0.187]), array([0.786]))],
#   ['also',
#    'also',
#    'alsohalf',
#    'color',
#    'also',
#    'alsoonto',
#    'drop',
#    'also',
#    (array([0.779]), array([0.496]))],
#   ['norworld', 'nor', 'also', (array([0.792]), array([0.208]))],
#   ['also', (array([0.775]), array([0.779]))],
#   ['also',
#    'alsoprovide',
#    'nor',
#    'also',
#    'also',
#    'also',
#    (array([0.037]), array([0.291]))],
#   ['ycivilrecognize',
#    'agency',
#    'ycivil',
#    'ycivil',
#    'ycivil',
#    (array([0.736]), array([0.149]))],
#   ['agencymewater',
#    'agency',
#    'zehalf',
#    'nology',
#    'agencyme',
#    'agency',
#    'agency',
#    (array([0.786]), array([0.854]))],
#   ['erform',
#    'nor',
#    'droprecognize',
#    'agencyhope',
#    'agency',
#    'drop',
#    (array([0.745]), array([0.195]))],
#   ['colormehalf', 'nor', 'colorme', (array([0.458]), array([0.271]))],
#   ['field',
#    'colorme',
#    'agency',
#    'agency',
#    'colorme',
#    (array([0.079]), array([0.649]))],
#   ['norfind',
#    'agency',
#    'agencyperform',
#    'norworld',
#    'nor',
#    'nor',
#    (array([0.493]), array([0.429]))],
#   ['norpainting',
#    'drop',
#    'agencypositive',
#    'norcivil',
#    'color',
#    'nor',
#    (array([0.204]), array([0.497]))],
#   ['rovide',
#    'drop',
#    'agencypositive',
#    'agency',
#    'agencypositive',
#    'agencypositive',
#    'nor',
#    (array([0.538]), array([0.726]))],
#   ['vehalf',
#    'field',
#    'agencypositive',
#    'agencypositive',
#    'agency',
#    'nor',
#    (array([0.735]), array([0.427]))],
#   ['colorwater',
#    'nor',
#    'nor',
#    'color',
#    'fieldperform',
#    'field',
#    'nor',
#    (array([0.22]), array([0.17]))],
#   ['iveany', 'nor', 'agency', (array([0.852]), array([0.873]))],
#   ['fieldshoulder',
#    'field',
#    'agencypositive',
#    (array([0.813]), array([0.491]))],
#   ['colorpainting',
#    'nor',
#    'color',
#    'norhope',
#    'agency',
#    'nor',
#    (array([0.635]), array([0.927]))],
#   ['fieldhalf',
#    'drop',
#    'nor',
#    'droptechnology',
#    'field',
#    'agency',
#    'dropwife',
#    'drop',
#    'iveany',
#    (array([0.54]), array([0.444]))],
#   ['noranyhim',
#    'field',
#    'iveany',
#    'nor',
#    'norany',
#    'nor',
#    'color',
#    (array([0.394]), array([0.57]))],
#   ['norfind',
#    'drop',
#    'nor',
#    'fieldworld',
#    'field',
#    'color',
#    'nor',
#    (array([0.706]), array([0.044]))],
#   ['agencyme', 'nor', 'agency', 'agency', (array([0.86]), array([0.58]))],
#   ['fieldwater',
#    'field',
#    'agencylongfind',
#    'agencylongfind',
#    (array([0.445]), array([0.596]))],
#   ['rovide',
#    'drop',
#    'norpositive',
#    'agencylong',
#    (array([0.683]), array([0.386]))],
#   ['droplong', 'agency', 'drop', (array([0.958]), array([0.893]))],
#   ['drop',
#    'majorityany',
#    'drop',
#    'majority',
#    'majority',
#    'majorityme',
#    (array([0.977]), array([0.258]))],
#   ['majority', 'majorityme', 'majority', (array([0.241]), array([0.236]))],
#   ['normeworld',
#    'agency',
#    'droponto',
#    'drop',
#    'colorworld',
#    'drop',
#    'norme',
#    'colorprovide',
#    'color',
#    'field',
#    (array([0.069]), array([0.262]))],
#   ['agencyhalf',
#    'agency',
#    'agency',
#    'drop',
#    'drop',
#    (array([0.404]), array([0.488]))],
#   ['fieldfind',
#    'field',
#    'agency',
#    'inting',
#    'drop',
#    'agencyrecognize',
#    (array([0.175]), array([0.8]))],
#   ['norlong',
#    'agency',
#    'nor',
#    'agencyrecognize',
#    (array([0.359]), array([0.921]))],
#   ['norpainting',
#    'nor',
#    'nor',
#    'agencyonto',
#    'nor',
#    'agency',
#    (array([0.711]), array([0.16]))],
#   ['fieldprovide',
#    'nor',
#    'field',
#    'field',
#    'field',
#    (array([0.896]), array([0.454]))],
#   ['nology',
#    'nologyme',
#    'nor',
#    'nology',
#    'color',
#    'fieldonto',
#    'field',
#    'nology',
#    (array([0.251]), array([0.254]))],
#   ['nology',
#    'nology',
#    'colorpainting',
#    'color',
#    'color',
#    (array([0.53]), array([0.615]))],
#   ['nologycivil',
#    'drop',
#    'nology',
#    'nology',
#    'agencylonghalf',
#    'agency',
#    'color',
#    'agencylong',
#    'agency',
#    'agency',
#    (array([0.479]), array([0.821]))],
#   ['nologykind',
#    'color',
#    'nology',
#    'nologyperform',
#    'nor',
#    'nology',
#    'nology',
#    'colorperform',
#    'color',
#    (array([0.395]), array([0.867]))],
#   ['colorshoulder',
#    'nor',
#    'majority',
#    'color',
#    'colorme',
#    (array([0.226]), array([0.473]))],
#   ['color', 'majority', 'majority', (array([0.782]), array([0.725]))],
#   ['oulder',
#    'color',
#    'color',
#    'majoritylong',
#    'nor',
#    'majority',
#    'color',
#    (array([0.019]), array([0.864]))],
#   ['ognize',
#    'field',
#    'agency',
#    'majority',
#    'majority',
#    (array([0.884]), array([0.461]))],
#   ['ivehim',
#    'agency',
#    'majority',
#    'agencyonto',
#    'agency',
#    'colorpositive',
#    (array([0.849]), array([0.845]))],
#   ['colorwater', 'nor', 'color', (array([0.076]), array([0.187]))],
#   ['colorpositive',
#    'color',
#    'color',
#    'color',
#    'agency',
#    (array([0.38]), array([0.255]))],
#   ['velong',
#    'drop',
#    'colorpositive',
#    'color',
#    'agency',
#    (array([0.251]), array([0.405]))],
#   ['oulder', 'drop', 'majority', (array([0.357]), array([0.934]))],
#   ['ognizehim',
#    'color',
#    'colorpositive',
#    'ognize',
#    'ognize',
#    (array([0.479]), array([0.222]))],
#   ['sitive',
#    'drop',
#    'majority',
#    'velong',
#    'drop',
#    'colorpositive',
#    (array([0.041]), array([0.87]))],
#   ['droppainting', 'drop', 'color', (array([0.998]), array([0.472]))],
#   ['color',
#    'agencyprovide',
#    'agency',
#    'majority',
#    (array([0.883]), array([0.226]))],
#   ['drop',
#    'fieldme',
#    'field',
#    'majority',
#    'color',
#    'color',
#    (array([0.556]), array([0.787]))],
#   ['inting',
#    'nor',
#    'majority',
#    'majoritylong',
#    'agency',
#    'majority',
#    'majority',
#    (array([0.439]), array([0.588]))],
#   ['oulderpositive',
#    'nor',
#    'majority',
#    'oulder',
#    'color',
#    'majority',
#    (array([0.123]), array([0.954]))],
#   ['ortant',
#    'color',
#    'majority',
#    'majority',
#    'majority',
#    'majority',
#    (array([0.611]), array([0.712]))],
#   ['ognize',
#    'drop',
#    'majority',
#    'agencyfind',
#    'erform',
#    'nor',
#    'agencyfind',
#    'fieldrecognize',
#    'field',
#    'agencyfind',
#    (array([0.227]), array([0.051]))],
#   ['dropfind',
#    'field',
#    'agency',
#    'majority',
#    'drop',
#    'majority',
#    'agencyperform',
#    'color',
#    'majority',
#    'agency',
#    (array([0.975]), array([0.615]))],
#   ['drop',
#    'agency',
#    'fieldhalf',
#    'field',
#    'majority',
#    'agencyfind',
#    (array([0.301]), array([0.803]))],
#   ['fieldkindlong',
#    'nor',
#    'agency',
#    'fieldkind',
#    'field',
#    'agency',
#    'drop',
#    (array([0.452]), array([0.006]))],
#   ['dropfind', 'drop', 'majority', (array([0.669]), array([0.722]))],
#   ['majoritylongme',
#    'color',
#    'majoritylong',
#    'agencyfind',
#    (array([0.157]), array([0.133]))],
#   ['droppainting',
#    'nor',
#    'drop',
#    'majority',
#    (array([0.598]), array([0.144]))],
#   ['droppositive', (array([0.619]), array([0.63]))],
#   ['nor', 'drop', (array([0.958]), array([0.27]))],
#   ['colorrecognize',
#    'color',
#    'nor',
#    'color',
#    'nor',
#    'drop',
#    'color',
#    (array([0.846]), array([0.079]))],
#   ['agencypainting', 'agency', 'nology', (array([0.111]), array([0.214]))],
#   ['drop',
#    'agency',
#    'nology',
#    'nor',
#    'agency',
#    'agency',
#    (array([0.24]), array([0.595]))],
#   ['nologywife',
#    'agency',
#    'nology',
#    'dropkind',
#    'agency',
#    'drop',
#    (array([0.724]), array([0.57]))],
#   ['drop',
#    'drop',
#    'agency',
#    'majority',
#    'nology',
#    (array([0.242]), array([0.789]))],
#   ['majorityme',
#    'fieldrecognize',
#    'field',
#    'sitive',
#    'agencyimportant',
#    'field',
#    'agency',
#    (array([0.861]), array([0.683]))],
#   ['norme', 'nor', 'majority', (array([0.773]), array([0.51]))],
#   ['agency',
#    'majority',
#    'drop',
#    'droplong',
#    'drop',
#    'agency',
#    (array([0.697]), array([0.238]))],
#   ['drophim',
#    'drop',
#    'nor',
#    'nor',
#    'agency',
#    'agencyrecognize',
#    'field',
#    'agency',
#    (array([0.427]), array([0.898]))],
#   ['nology',
#    'nor',
#    'agencyshoulder',
#    'agency',
#    'agency',
#    'drop',
#    (array([0.261]), array([0.15]))],
#   ['agencywater',
#    'agency',
#    'sitive',
#    'droprecognize',
#    'field',
#    'drop',
#    (array([0.35]), array([0.21]))],
#   ['nor',
#    'agencywife',
#    'agency',
#    'nor',
#    'norhalf',
#    'field',
#    'nor',
#    'nology',
#    (array([0.284]), array([0.288]))],
#   ['drop', (array([0.401]), array([0.466]))],
#   ['dropwateronto', 'color', 'dropwater', (array([0.824]), array([0.824]))],
#   ['drop', (array([0.685]), array([0.818]))],
#   ['norshoulder',
#    'agency',
#    'drop',
#    'dropwater',
#    'dropwater',
#    'dropwife',
#    'nor',
#    'drop',
#    (array([0.533]), array([0.266]))],
#   ['dropwife',
#    'field',
#    'drop',
#    'dropworld',
#    'drop',
#    'drop',
#    'norany',
#    'nor',
#    'drop',
#    (array([0.463]), array([0.574]))],
#   ['norpositive',
#    'drop',
#    'nor',
#    'dropwater',
#    (array([0.503]), array([0.365]))],
#   ['coloronto',
#    'color',
#    'drop',
#    'nor',
#    'dropimportant',
#    'drop',
#    'drop',
#    (array([0.506]), array([0.623]))],
#   ['dropfind',
#    'drop',
#    'dropwater',
#    'norcivil',
#    'agency',
#    'drop',
#    'norimportant',
#    'drop',
#    'nor',
#    (array([0.212]), array([0.464]))],
#   ['ognize',
#    'drop',
#    'nor',
#    'drop',
#    'dropwater',
#    'oulder',
#    'agency',
#    'drop',
#    'dropwater',
#    (array([0.65]), array([0.684]))],
#   ['norme',
#    'nor',
#    'dropwater',
#    'nor',
#    'drophalf',
#    'drop',
#    'dropwater',
#    'drop',
#    (array([0.051]), array([0.62]))],
#   ['dropfind', 'drop', 'drop', 'nor', (array([0.572]), array([0.647]))],
#   ['agencylong',
#    'agency',
#    'colortechnology',
#    'drop',
#    'majorityme',
#    (array([0.849]), array([0.176]))],
#   ['ognize',
#    'color',
#    'majorityme',
#    'colorhalf',
#    'agency',
#    'colortechnology',
#    'color',
#    (array([0.257]), array([0.97]))],
#   ['drop', (array([0.861]), array([0.085]))],
#   ['rovide', 'color', 'majorityme', (array([0.619]), array([0.927]))],
#   ['fieldpainting', 'field', 'field', (array([0.707]), array([0.431]))],
#   ['agencyprovide',
#    'nor',
#    'colorworld',
#    'coloronto',
#    'agency',
#    'drop',
#    'dropprovide',
#    'agency',
#    'color',
#    'drop',
#    (array([0.132]), array([0.168]))],
#   ['drop', (array([0.359]), array([0.472]))],
#   ['fieldme',
#    'field',
#    'drop',
#    'norwater',
#    'nor',
#    'drop',
#    'field',
#    (array([0.043]), array([0.674]))],
#   ['fieldshoulder', 'agency', 'field', (array([0.404]), array([0.321]))],
#   ['agencywife', 'color', 'agency', (array([0.145]), array([0.306]))],
#   ['agencyhim',
#    'agencyhim',
#    'norfind',
#    'nor',
#    'drop',
#    'agencyhim',
#    (array([0.202]), array([0.637]))],
#   ['agencyhimwater', 'color', 'agencyhim', (array([0.605]), array([0.557]))],
#   ['erform',
#    'drop',
#    'drop',
#    'agencyhim',
#    'agencyonto',
#    'color',
#    'agency',
#    (array([0.919]), array([0.807]))],
#   ['agencyhimme', 'agency', 'agencyhim', (array([0.663]), array([0.449]))],
#   ['dropkind',
#    'field',
#    'drop',
#    'agencyhimkind',
#    'drop',
#    'agencyhim',
#    'agencyhimhope',
#    'drop',
#    'agencyhim',
#    (array([0.556]), array([0.024]))],
#   ['agencyhimlong', 'color', 'agencyhim', (array([0.233]), array([0.751]))],
#   ['agencyhim',
#    'agencyhimonto',
#    'color',
#    'drop',
#    'agencyhim',
#    'agencyhim',
#    'agencyhim',
#    (array([0.247]), array([0.422]))],
#   ['dropcivil',
#    'drop',
#    'drop',
#    'drop',
#    'agencyhim',
#    'agencylong',
#    'color',
#    'agency',
#    (array([0.455]), array([0.172]))],
#   ['norshoulder',
#    'nor',
#    'agencyhim',
#    'agency',
#    'agencyhim',
#    (array([0.703]), array([0.606]))],
#   ['inting',
#    'color',
#    'drop',
#    'agencycivil',
#    'drop',
#    'agency',
#    'agencyhim',
#    (array([0.151]), array([0.468]))],
#   ['norpainting',
#    'nor',
#    'ognize',
#    'norhalf',
#    'nor',
#    'ognize',
#    'dropprovide',
#    'nor',
#    'drop',
#    (array([0.954]), array([0.622]))],
#   ['colorany',
#    'field',
#    'colorany',
#    'colorme',
#    'color',
#    'color',
#    (array([0.261]), array([0.795]))],
#   ['colorlong', 'color', 'colorkind', (array([0.37]), array([0.181]))],
#   ['fieldonto', 'field', 'color', (array([0.411]), array([0.603]))],
#   ['colorimportant',
#    'color',
#    'nor',
#    'color',
#    (array([0.173]), array([0.335]))],
#   ['colorkind', 'majority', (array([0.975]), array([0.647]))],
#   ['majority', (array([0.587]), array([0.274]))],
#   ['agencyshoulder', 'agency', 'colorkind', (array([0.516]), array([0.174]))],
#   ['dropworld', 'drop', 'drop', (array([0.272]), array([0.284]))],
#   ['gywife',
#    'field',
#    'norprovide',
#    'droptechnology',
#    'although',
#    'agency',
#    'drophalf',
#    'drop',
#    'droptechnology',
#    (array([0.398]), array([0.572]))],
#   ['droptechnology', 'agencyimportant', (array([0.343]), array([0.684]))],
#   ['color',
#    'colorprovide',
#    'agency',
#    'color',
#    (array([0.76]), array([0.704]))],
#   ['gykind',
#    'color',
#    'drop',
#    'agency',
#    'droptechnology',
#    (array([0.295]), array([0.62]))],
#   ['erform',
#    'nor',
#    'field',
#    'eronto',
#    'field',
#    'field',
#    'field',
#    'field',
#    'agencyshoulder',
#    'agencyhim',
#    (array([0.757]), array([0.439]))],
#   ['dropkind', 'dropkind', 'dropkind', (array([0.453]), array([0.515]))],
#   ['fieldcivil',
#    'color',
#    'field',
#    'agencyonto',
#    'agency',
#    'fieldonto',
#    (array([0.275]), array([0.852]))],
#   ['ecivil',
#    'nor',
#    'agencypositive',
#    'agencyperform',
#    'agency',
#    'agency',
#    (array([0.997]), array([0.861]))],
#   ['nor', 'norhim', 'drop', 'nor', 'agency', (array([0.443]), array([0.416]))],
#   ['agency',
#    'agencypositive',
#    'agencypositive',
#    (array([0.081]), array([0.975]))],
#   ['agencypositive', 'norkind', (array([0.98]), array([0.435]))],
#   ['norprovide',
#    'nor',
#    'agencypositive',
#    'agency',
#    'agency',
#    (array([0.027]), array([0.42]))],
#   ['norprovide', 'field', 'nor', (array([0.217]), array([0.563]))],
#   ['drophope',
#    'drop',
#    'nor',
#    'agency',
#    'agencypositive',
#    'nor',
#    (array([0.411]), array([0.306]))],
#   ['colorrecognize',
#    'field',
#    'agencypositive',
#    'colorpainting',
#    'color',
#    'norkind',
#    (array([0.91]), array([0.62]))],
#   ['norwife',
#    'color',
#    'agency',
#    'norkind',
#    'nor',
#    'agency',
#    (array([0.439]), array([0.667]))],
#   ['nor', 'nor', (array([0.942]), array([0.127]))],
#   ['norprovide', 'field', 'nor', (array([0.733]), array([0.457]))],
#   ['fieldhalfkind', 'agency', 'fieldhalf', (array([0.201]), array([0.177]))],
#   ['fieldwater',
#    'agency',
#    'agency',
#    'fieldhalf',
#    'color',
#    'field',
#    (array([0.639]), array([0.359]))],
#   ['although', (array([0.751]), array([0.385]))],
#   ['oulder',
#    'color',
#    'agencykindme',
#    'although',
#    (array([0.407]), array([0.404]))],
#   ['field',
#    'oulder',
#    'field',
#    'agencykind',
#    'although',
#    'colorrecognize',
#    'color',
#    'although',
#    (array([0.372]), array([0.45]))],
#   ['agencykindme', (array([0.399]), array([0.837]))],
#   ['nglong',
#    'drop',
#    'agencykindme',
#    'althoughlong',
#    'drop',
#    'agencykind',
#    'althoughperform',
#    'agency',
#    'although',
#    'although',
#    (array([0.495]), array([0.858]))],
#   ['althoughworld', 'agency', 'although', (array([0.101]), array([0.159]))],
#   ['rovide',
#    'nor',
#    'agencykind',
#    'agencyfind',
#    'agency',
#    'although',
#    'althoughfind',
#    (array([0.853]), array([0.663]))],
#   ['norfind',
#    'nor',
#    'althoughfind',
#    'agencykind',
#    'althoughprovide',
#    'field',
#    'althoughfind',
#    'although',
#    'field',
#    (array([0.035]), array([0.574]))],
#   ['agencyimportant',
#    'agency',
#    'agency',
#    'althoughkind',
#    'nor',
#    'although',
#    (array([0.477]), array([0.589]))],
#   ['although', 'field', (array([0.664]), array([0.873]))],
#   ['althoughprovide',
#    'field',
#    'although',
#    'although',
#    'although',
#    'although',
#    'colorprovide',
#    'color',
#    'although',
#    (array([0.718]), array([0.885]))],
#   ['dehope',
#    'field',
#    'althoughprovide',
#    'dropimportant',
#    'drop',
#    'althoughprovide',
#    (array([0.121]), array([0.493]))],
#   ['zehope',
#    'nor',
#    'nortechnology',
#    'fieldrecognize',
#    'field',
#    'agencykind',
#    'agency',
#    (array([0.607]), array([0.83]))],
#   ['ognize',
#    'drop',
#    'although',
#    'inting',
#    'agency',
#    'although',
#    'norcivil',
#    'nor',
#    'although',
#    (array([0.312]), array([0.615]))],
#   ['inting', 'color', 'agencykind', (array([0.811]), array([0.959]))],
#   ['agencykindhalf',
#    'drop',
#    'althoughprovide',
#    'norme',
#    'nor',
#    'agency',
#    'agencykind',
#    (array([0.514]), array([0.989]))],
#   ['oulder', 'drop', 'although', (array([0.703]), array([0.279]))],
#   ['norany',
#    'drop',
#    'nor',
#    'agency',
#    'colorprovide',
#    'color',
#    'nor',
#    (array([0.675]), array([0.796]))],
#   ['fieldpositive',
#    'field',
#    'although',
#    'dehope',
#    'agency',
#    'althoughprovide',
#    (array([0.175]), array([0.478]))],
#   ['fieldme', 'field', 'althoughprovide', (array([0.017]), array([0.344]))],
#   ['fieldpainting',
#    'field',
#    'althoughprovide',
#    'norhim',
#    'field',
#    'nor',
#    (array([0.667]), array([0.176]))],
#   ['nor',
#    'lwater',
#    'field',
#    'although',
#    'agencykind',
#    'althoughcivil',
#    'agency',
#    'although',
#    (array([0.314]), array([0.226]))],
#   ['colorhalfworld',
#    'drop',
#    'colorhalf',
#    'drophope',
#    'drop',
#    'colorhalf',
#    (array([0.285]), array([0.671]))],
#   ['agencykind', (array([0.307]), array([0.734]))],
#   ['ognize',
#    'agency',
#    'although',
#    'agencykind',
#    'agency',
#    'colorhalf',
#    (array([0.056]), array([0.071]))],
#   ['colorpainting',
#    'agency',
#    'color',
#    'color',
#    (array([0.981]), array([0.149]))],
#   ['sitive', 'drop', 'although', (array([0.377]), array([0.839]))],
#   ['agencyshoulder',
#    'field',
#    'oulder',
#    'dropme',
#    'agency',
#    'drop',
#    (array([0.711]), array([0.266]))],
#   ['oulder', (array([0.607]), array([0.59]))],
#   ['although',
#    'oulder',
#    'color',
#    'althoughcivil',
#    'oulderprovide',
#    'field',
#    'oulder',
#    (array([0.812]), array([0.215]))],
#   ['althoughcivilme',
#    'field',
#    'although',
#    'droptechnology',
#    'color',
#    'althoughcivil',
#    'drop',
#    (array([0.148]), array([0.891]))],
#   ['oulderimportant',
#    'nor',
#    'although',
#    'oulder',
#    'droplong',
#    'agency',
#    'oulder',
#    'drop',
#    (array([0.914]), array([0.825]))],
#   ['oulder',
#    'dropcivil',
#    'color',
#    'drop',
#    'norworld',
#    'nor',
#    'althoughcivil',
#    (array([0.178]), array([0.798]))],
#   ['although', 'although', (array([0.921]), array([0.475]))],
#   ['fieldhope', 'field', 'although', (array([0.232]), array([0.161]))],
#   ['dropshoulder',
#    'drop',
#    'although',
#    'although',
#    'although',
#    'although',
#    (array([0.424]), array([0.935]))],
#   ['ognize', 'drop', 'although', (array([0.355]), array([0.426]))],
#   ['oulder',
#    'field',
#    'although',
#    'ortant',
#    'drop',
#    'although',
#    'although',
#    (array([0.343]), array([0.69]))],
#   ['although',
#    'although',
#    'althoughhalf',
#    'nor',
#    'although',
#    'although',
#    (array([0.496]), array([0.623]))],
#   ['althoughhalf',
#    'field',
#    'although',
#    'inting',
#    'nor',
#    'although',
#    'although',
#    (array([0.636]), array([0.415]))],
#   ['althoughme', 'drop', 'although', (array([0.451]), array([0.719]))],
#   ['agencyhalf', 'agency', 'although', (array([0.005]), array([0.752]))],
#   ['althoughcivil',
#    'agency',
#    'although',
#    'although',
#    'although',
#    'although',
#    'norfind',
#    'nor',
#    'although',
#    (array([0.848]), array([0.052]))],
#   ['fieldpainting',
#    'field',
#    'although',
#    'agencypainting',
#    'agency',
#    'although',
#    (array([0.909]), array([0.792]))],
#   ['dropany',
#    'field',
#    'color',
#    'dropme',
#    'drop',
#    'although',
#    'althoughonto',
#    (array([0.353]), array([0.763]))],
#   ['oulderimportant',
#    'agency',
#    'dropany',
#    'oulder',
#    (array([0.446]), array([0.689]))],
#   ['oulder',
#    'droptechnology',
#    'drop',
#    'drop',
#    'color',
#    'dropany',
#    (array([0.623]), array([0.204]))],
#   ['nology',
#    'color',
#    'oulder',
#    'oulderany',
#    'nor',
#    'oulder',
#    'oulder',
#    (array([0.317]), array([0.42]))],
#   ['fieldme', 'field', 'oulder', 'oulder', (array([0.962]), array([0.891]))],
#   ['colortechnology',
#    'drop',
#    'color',
#    'color',
#    'color',
#    (array([0.122]), array([0.634]))],
#   ['color',
#    'colorwater',
#    'agency',
#    'color',
#    'color',
#    (array([0.627]), array([0.099]))],
#   ['coloronto', 'field', 'color', (array([0.122]), array([0.333]))],
#   ['color',
#    'colorkind',
#    'color',
#    'color',
#    'color',
#    'color',
#    (array([0.664]), array([0.153]))],
#   ['color', 'color', (array([0.545]), array([0.902]))],
#   ['colorperform',
#    'color',
#    'color',
#    'agencywater',
#    'agency',
#    'color',
#    'color',
#    'color',
#    (array([0.083]), array([0.548]))],
#   ['colorkind',
#    'color',
#    'color',
#    'color',
#    'fieldme',
#    'field',
#    'color',
#    (array([0.192]), array([0.581]))],
#   ['color',
#    'color',
#    'norhim',
#    'nor',
#    'color',
#    'color',
#    (array([0.195]), array([0.609]))],
#   ['agencyworld',
#    'agency',
#    'agency',
#    'dwater',
#    'field',
#    'althoughfind',
#    'althoughfindme',
#    'color',
#    'althoughfind',
#    (array([0.411]), array([0.633]))],
#   ['agencyrecognize',
#    'color',
#    'agency',
#    'although',
#    'ognize',
#    'field',
#    'although',
#    'although',
#    'although',
#    (array([0.306]), array([0.4]))],
#   ['sitivefind',
#    'nor',
#    'althoughfind',
#    'sitive',
#    'nor',
#    'althoughfind',
#    'agencyworld',
#    'color',
#    'agency',
#    (array([0.444]), array([0.79]))],
#   ['dropimportant',
#    'drop',
#    'although',
#    'althoughfind',
#    (array([0.788]), array([0.275]))],
#   ['dropfindany',
#    'drop',
#    'agency',
#    'dropfind',
#    'drop',
#    'althoughfind',
#    (array([0.983]), array([0.617]))],
#   ['agency', 'althoughfind', 'althoughfind', (array([0.494]), array([0.987]))],
#   ['agencykind',
#    'nor',
#    'although',
#    'althoughfind',
#    'agency',
#    'althoughfind',
#    'agency',
#    (array([0.782]), array([0.103]))],
#   ['althoughhalf',
#    'drop',
#    'although',
#    'colorfind',
#    'color',
#    'although',
#    (array([0.075]), array([0.545]))],
#   ['agencyworld',
#    'field',
#    'agency',
#    'agency',
#    'agency',
#    'fieldpainting',
#    'field',
#    'although',
#    (array([0.766]), array([0.615]))],
#   ['although',
#    'althoughonto',
#    'drop',
#    'agency',
#    'although',
#    (array([0.356]), array([0.564]))],
#   ['agency', 'althoughfind', (array([0.802]), array([0.148]))],
#   ['oulderfind',
#    'nor',
#    'nor',
#    'nor',
#    'oulder',
#    (array([0.855]), array([0.37]))],
#   ['droppositive',
#    'drop',
#    'norfind',
#    'norfind',
#    (array([0.403]), array([0.626]))],
#   ['fieldfind',
#    'color',
#    'fieldhim',
#    'field',
#    'rovide',
#    'field',
#    'fieldwater',
#    'field',
#    (array([0.71]), array([0.204]))],
#   ['rovide', 'color', 'althoughprovide', (array([0.642]), array([0.373]))],
#   ['inting',
#    'agency',
#    'norperform',
#    'colorwife',
#    'color',
#    'norperform',
#    'nor',
#    'althoughprovide',
#    (array([0.153]), array([0.699]))],
#   ['nor',
#    'norperform',
#    'norcivil',
#    'agency',
#    'nor',
#    (array([0.549]), array([0.182]))],
#   ['althoughany',
#    'althoughany',
#    'althoughany',
#    'agency',
#    (array([0.509]), array([0.455]))],
#   ['althoughany',
#    'agencykind',
#    'agency',
#    'agencykind',
#    'agencykindfind',
#    'drop',
#    'agencykind',
#    (array([0.889]), array([0.406]))],
#   ['agencyrecognize',
#    'agency',
#    'althoughany',
#    'agencyhope',
#    'field',
#    'agency',
#    (array([0.147]), array([0.226]))],
#   ['agency',
#    'althoughany',
#    'agency',
#    'agencyperform',
#    'agency',
#    'althoughany',
#    'althoughany',
#    (array([0.762]), array([0.291]))],
#   ['dropworld',
#    'drop',
#    'agency',
#    'fieldprovide',
#    'field',
#    'althoughany',
#    (array([0.327]), array([0.257]))],
#   ['norrecognize',
#    'agency',
#    'rovide',
#    'rovide',
#    'droprecognize',
#    'drop',
#    'nor',
#    (array([0.045]), array([0.738]))],
#   ['rovideworld', 'nor', 'color', 'rovide', (array([0.276]), array([0.385]))],
#   ['colorperform', 'color', 'rovide', (array([0.301]), array([0.591]))],
#   ['colorfind',
#    'field',
#    'rovideprovide',
#    'dehope',
#    'nor',
#    'rovideprovide',
#    'color',
#    (array([0.553]), array([0.185]))],
#   ['agencyme', 'field', 'agency', (array([0.216]), array([0.579]))],
#   ['norhim', 'nor', 'rovide', (array([0.33]), array([0.479]))],
#   ['nor', 'nor', (array([0.087]), array([0.076]))],
#   ['fieldkind', 'field', 'agency', (array([0.584]), array([0.403]))],
#   ['oulder',
#    'nor',
#    'colorworld',
#    'colorworld',
#    'colorworldonto',
#    'field',
#    'colorworld',
#    'colorworld',
#    (array([0.171]), array([0.65]))],
#   ['ognizecivil',
#    'field',
#    'field',
#    'ognize',
#    'fieldshoulder',
#    'nor',
#    'field',
#    'field',
#    (array([0.616]), array([0.031]))],
#   ['dropwife',
#    'drop',
#    'drop',
#    'colorworld',
#    'agencykind',
#    'agencycivil',
#    'color',
#    'agency',
#    (array([0.617]), array([0.475]))],
#   ['sitive',
#    'nor',
#    'field',
#    'fieldlong',
#    'nor',
#    'field',
#    'agencyhalf',
#    'agency',
#    'field',
#    (array([0.203]), array([0.556]))],
#   ['agency',
#    'fieldperform',
#    'colorhim',
#    'color',
#    'erform',
#    (array([0.283]), array([0.029]))],
#   ['agencyrecognize',
#    'field',
#    'agency',
#    'agency',
#    'agencyimportant',
#    'agency',
#    'agency',
#    'agency',
#    (array([0.282]), array([0.681]))],
#   ['ortant',
#    'field',
#    'fieldperform',
#    'erform',
#    'fieldperform',
#    'erform',
#    'erform',
#    (array([0.203]), array([0.057]))],
#   ['drop',
#    'drop',
#    'drop',
#    'nor',
#    'drophim',
#    'drop',
#    'drop',
#    (array([0.429]), array([0.208]))],
#   ['drop',
#    'colorany',
#    'color',
#    'drop',
#    'drop',
#    'colorperform',
#    'color',
#    'drop',
#    (array([0.811]), array([0.059]))],
#   ['dropwater', 'nor', 'drop', 'fieldme', (array([0.396]), array([0.628]))],
#   ['fieldkind', 'field', 'drop', 'drop', (array([0.674]), array([0.887]))],
#   ['erform',
#    'agency',
#    'field',
#    'dropcivilfind',
#    'agency',
#    'fieldme',
#    'fieldme',
#    'dropcivil',
#    (array([0.317]), array([0.216]))],
#   ['fieldme',
#    'fieldrecognize',
#    'color',
#    'drop',
#    'fieldmepositive',
#    'color',
#    'fieldme',
#    'field',
#    (array([0.483]), array([0.954]))],
#   ['inting',
#    'drop',
#    'drop',
#    'fieldme',
#    'fieldperform',
#    (array([0.694]), array([0.09]))],
#   ['fieldme',
#    'agencyrecognize',
#    'color',
#    'agency',
#    'sitive',
#    'drop',
#    'fieldperform',
#    'dropcivil',
#    (array([0.545]), array([0.484]))],
#   ['fieldwife',
#    'drop',
#    'agency',
#    'field',
#    'dropworld',
#    'drop',
#    'fieldperform',
#    (array([0.328]), array([0.558]))],
#   ['fieldmeworld',
#    'color',
#    'dropcivil',
#    'field',
#    'droplong',
#    'drop',
#    'fieldme',
#    (array([0.259]), array([0.115]))],
#   ['droprecognize',
#    'field',
#    'dropcivil',
#    'fieldmehope',
#    'drop',
#    'fieldme',
#    'colorwater',
#    'color',
#    'dropcivil',
#    (array([0.85]), array([0.815]))],
#   ['dropwater',
#    'field',
#    'drop',
#    'field',
#    'fieldme',
#    (array([0.04]), array([0.179]))],
#   ['fieldperform',
#    'drop',
#    'fieldperformhim',
#    'agency',
#    'dropcivil',
#    'fieldperform',
#    'field',
#    (array([0.271]), array([0.894]))],
#   ['ivehim',
#    'color',
#    'drop',
#    'colorpositive',
#    'color',
#    'drop',
#    'drop',
#    (array([0.707]), array([0.064]))],
#   ['drophalf',
#    'field',
#    'droplong',
#    'droplonglong',
#    'droplonglong',
#    'dropshoulder',
#    'nor',
#    'drop',
#    (array([0.094]), array([0.515]))],
#   ['agencykind', 'agency', 'drop', 'drop', (array([0.185]), array([0.744]))],
#   ['fieldkind', 'field', 'norkind', (array([0.412]), array([0.579]))],
#   ['dropwater',
#    'drop',
#    'norkind',
#    'dropfind',
#    'drop',
#    'drop',
#    'nor',
#    (array([0.075]), array([0.605]))],
#   ['dropprovide',
#    'field',
#    'drop',
#    'drop',
#    'dropimportant',
#    'nor',
#    'drop',
#    (array([0.463]), array([0.033]))],
#   ['ngkind', 'color', 'droplonglong', (array([0.52]), array([0.53]))],
#   ['fieldfind',
#    'agency',
#    'field',
#    'dropfind',
#    'field',
#    'field',
#    'droplonglong',
#    'drop',
#    (array([0.747]), array([0.355]))],
#   ['colorshoulder',
#    'color',
#    'drop',
#    'nor',
#    'fieldprovide',
#    'color',
#    'norkind',
#    'norkindfind',
#    'field',
#    'norkind',
#    (array([0.39]), array([0.555]))],
#   ['dropkind', 'agency', 'drop', 'drop', (array([0.179]), array([0.211]))],
#   ['drop', 'fieldhope', 'field', 'drop', (array([0.649]), array([0.61]))],
#   ['dropmehope',
#    'agency',
#    'drop',
#    'dropme',
#    'agency',
#    'drop',
#    'drophim',
#    'drop',
#    'drop',
#    'drop',
#    (array([0.95]), array([0.922]))],
#   ['drop', (array([0.878]), array([0.387]))],
#   ['fieldperform', 'field', 'drop', 'drop', (array([0.477]), array([0.793]))],
#   ['dropperform', 'field', 'drop', (array([0.698]), array([0.637]))],
#   ['dropfind',
#    'drop',
#    'drop',
#    'droptechnology',
#    'nor',
#    'drop',
#    'drop',
#    (array([0.337]), array([0.098]))],
#   ['drophope', 'agency', 'drop', (array([0.012]), array([0.701]))],
#   ['norpositive', 'nor', 'field', (array([0.202]), array([0.825]))],
#   ['dropwifeme',
#    'agency',
#    'field',
#    'dropwife',
#    'drop',
#    'fieldshoulder',
#    'field',
#    'field',
#    (array([0.643]), array([0.151]))],
#   ['dropshoulder',
#    'drop',
#    'drop',
#    'norpositive',
#    'agency',
#    'drop',
#    'agency',
#    'drop',
#    'nor',
#    'dropwife',
#    (array([0.497]), array([0.252]))],
#   ['drophalf', 'sitive', 'dropwife', (array([0.788]), array([0.01]))],
#   ['norlong',
#    'agency',
#    'dropwife',
#    'drophalfany',
#    'nor',
#    'drophalf',
#    (array([0.428]), array([0.473]))],
#   ['nor', (array([0.185]), array([0.714]))],
#   ['colorprovide', 'color', 'dropwife', (array([0.975]), array([0.806]))],
#   ['dropwife', (array([0.422]), array([0.549]))],
#   ['agencycivil',
#    'nor',
#    'agency',
#    'drophalf',
#    'nor',
#    'drop',
#    (array([0.157]), array([0.414]))],
#   ['dropany',
#    'color',
#    'field',
#    'fieldhim',
#    'field',
#    'dropfind',
#    'drop',
#    'agency',
#    (array([0.594]), array([0.497]))],
#   ['fieldfind', 'field', 'drop', (array([0.289]), array([0.479]))],
#   ['fieldhimfind', 'field', (array([0.506]), array([0.506]))],
#   ['vefind',
#    'field',
#    'drop',
#    'droppositive',
#    'agency',
#    'drop',
#    'colorhalf',
#    'color',
#    'dropwife',
#    (array([0.405]), array([0.969]))],
#   ['dropwifehalf', 'nor', 'dropwife', (array([0.877]), array([0.475]))],
#   ['fieldhim',
#    'colorperform',
#    'color',
#    'fieldhim',
#    'agency',
#    'fieldhimfind',
#    (array([0.136]), array([0.034]))],
#   ['colorhalf',
#    'color',
#    'fieldhim',
#    'dropwife',
#    (array([0.07]), array([0.33]))],
#   ['agencyperform',
#    'field',
#    'agency',
#    'drop',
#    (array([0.419]), array([0.625]))],
#   ['field',
#    'agency',
#    'fieldhimhope',
#    'color',
#    'fieldhim',
#    'dropwife',
#    (array([0.987]), array([0.879]))],
#   ['colortechnology',
#    'drop',
#    'drop',
#    'norimportanthim',
#    'color',
#    'fieldhim',
#    'norimportant',
#    'nor',
#    'drop',
#    (array([0.351]), array([0.66]))],
#   ['drophope', 'color', 'drop', (array([0.328]), array([0.401]))],
#   ['drophope',
#    'color',
#    'color',
#    'colorhalf',
#    'drop',
#    'color',
#    (array([0.084]), array([0.511]))],
#   ['color', 'colorperform', 'drop', 'color', (array([0.036]), array([0.095]))],
#   ['colorprovide',
#    'field',
#    'color',
#    'colorme',
#    'color',
#    'color',
#    'color',
#    (array([0.199]), array([0.695]))],
#   ['inting', (array([0.356]), array([0.997]))],
#   ['intingwater', 'agency', 'inting', (array([0.133]), array([0.972]))],
#   ['color',
#    'color',
#    'colorwater',
#    'nor',
#    'color',
#    'colorwife',
#    (array([0.696]), array([0.106]))],
#   ['colorwife', (array([0.582]), array([0.271]))],
#   ['nor', (array([0.959]), array([0.786]))],
#   ['drop',
#    'drop',
#    'droppositive',
#    'nor',
#    'drop',
#    'drop',
#    'norrecognize',
#    (array([0.613]), array([0.164]))],
#   ['dropworld', 'field', 'drop', (array([0.401]), array([0.235]))],
#   ['fieldtechnology', 'field', 'drophalf', (array([0.858]), array([0.228]))],
#   ['fieldlongany',
#    'color',
#    'agency',
#    'drop',
#    'fieldlong',
#    'field',
#    'agency',
#    'agency',
#    (array([0.616]), array([0.532]))],
#   ['agencyrecognize',
#    'agency',
#    'agency',
#    'agency',
#    (array([0.933]), array([0.709]))],
#   ['ntwife',
#    'field',
#    'agencyimportant',
#    'nology',
#    'color',
#    'agency',
#    'agency',
#    (array([0.527]), array([0.711]))],
#   ['ognize', 'color', 'agencyimportant', (array([0.4]), array([0.44]))],
#   ['agencyimportant',
#    'tcivil',
#    'agency',
#    'agencyimportant',
#    (array([0.856]), array([0.569]))],
#   ['agencyimportant',
#    'rovideperform',
#    'agency',
#    'drop',
#    'rovide',
#    'color',
#    'agencyimportant',
#    (array([0.848]), array([0.191]))],
#   ['droplong',
#    'drop',
#    'agency',
#    'agency',
#    'drop',
#    (array([0.888]), array([0.269]))],
#   ['fieldwater', 'field', 'drop', (array([0.255]), array([0.702]))],
#   ['norhope',
#    'nor',
#    'drop',
#    'drop',
#    'drop',
#    'drop',
#    (array([0.535]), array([0.184]))],
#   ['dropperform',
#    'field',
#    'agencyimportant',
#    'ntwife',
#    'drop',
#    'agencyimportant',
#    (array([0.73]), array([0.24]))],
#   ['agencyimportant',
#    'agencyprovide',
#    'field',
#    'agency',
#    (array([0.3]), array([0.669]))],
#   ['oulder',
#    'drop',
#    'mwater',
#    'mwater',
#    'mwater',
#    'fieldlong',
#    'color',
#    'field',
#    'drop',
#    (array([0.09]), array([0.067]))],
#   ['ngwife',
#    'drop',
#    'dropperform',
#    'colorpainting',
#    'drop',
#    'color',
#    (array([0.56]), array([0.977]))],
#   ['dropany',
#    'color',
#    'ortant',
#    'drop',
#    'oulder',
#    'color',
#    'dropperformwife',
#    (array([0.194]), array([0.755]))],
#   ['droponto', 'drop', 'field', 'drop', (array([0.313]), array([0.891]))],
#   ['color',
#    'ortantkind',
#    'nor',
#    'ortant',
#    'ortant',
#    'agency',
#    'agency',
#    (array([0.136]), array([0.777]))],
#   ['dropkind', 'agency', (array([0.618]), array([0.12]))],
#   ['dropkind', 'agency', 'ortant', (array([0.251]), array([0.019]))],
#   ['color', (array([0.05]), array([0.851]))],
#   ['ortantrecognize',
#    'nor',
#    'agency',
#    'ortant',
#    'agencywife',
#    'agency',
#    'dropkind',
#    (array([0.129]), array([0.508]))],
#   ['dropkindfind', 'field', 'dropkind', (array([0.788]), array([0.559]))],
#   ['sitive', 'drop', 'dropkind', (array([0.777]), array([0.452]))],
#   ['droppainting',
#    'drop',
#    'color',
#    'color',
#    'droplong',
#    'drop',
#    'color',
#    (array([0.74]), array([0.833]))],
#   ['dropkindme',
#    'drop',
#    'color',
#    'dropkind',
#    (array([0.737]), array([0.909]))],
#   ['coloronto',
#    'agency',
#    'nor',
#    'colormeperform',
#    'agency',
#    'erform',
#    'colorme',
#    'color',
#    'color',
#    'nor',
#    (array([0.072]), array([0.165]))],
#   ['colorany',
#    'field',
#    'color',
#    'fieldwifecivil',
#    'field',
#    'color',
#    'fieldwife',
#    'field',
#    'erform',
#    (array([0.215]), array([0.803]))],
#   ['fieldlong',
#    'field',
#    'nor',
#    'erformwife',
#    'nor',
#    'dropkind',
#    'color',
#    'erform',
#    (array([0.424]), array([0.261]))],
#   ['nor',
#    'agencylong',
#    'color',
#    'dropkind',
#    'color',
#    'colorworld',
#    'agency',
#    'color',
#    (array([0.274]), array([0.187]))],
#   ['nor',
#    'dropperform',
#    'drop',
#    'erform',
#    'norpositive',
#    'color',
#    'nor',
#    'erform',
#    (array([0.242]), array([0.407]))],
#   ['nor', (array([0.778]), array([0.259]))],
#   ['dropkindperform',
#    'agency',
#    'dropkind',
#    'gwater',
#    'color',
#    'color',
#    'norpainting',
#    (array([0.892]), array([0.83]))],
#   ['color',
#    'agency',
#    'dropkind',
#    'field',
#    'field',
#    'dropkind',
#    (array([0.545]), array([0.424]))],
#   ['ortant',
#    'nor',
#    'dropkind',
#    'sitive',
#    'field',
#    'dropkindkind',
#    'dropkindkind',
#    'dropkind',
#    (array([0.369]), array([0.456]))],
#   ['inting',
#    'drop',
#    'dropkind',
#    'dropkind',
#    'agencyworld',
#    'agency',
#    'field',
#    (array([0.158]), array([0.798]))],
#   ['fieldlong',
#    'agency',
#    'field',
#    'dropkind',
#    (array([0.033]), array([0.996]))],
#   ['dropkindkind',
#    'colorpainting',
#    'color',
#    'dropkindkind',
#    (array([0.127]), array([0.604]))],
#   ['dropkindkind',
#    'norme',
#    'nor',
#    'dropkind',
#    'fieldshoulder',
#    'field',
#    'dropkindkindhim',
#    (array([0.995]), array([0.154]))],
#   ['dropkindkindhim',
#    'dropkind',
#    'dropkind',
#    (array([0.184]), array([0.082]))],
#   ['imonto', 'agency', 'dropkindkindhim', (array([0.719]), array([0.862]))],
#   ['oulder',
#    'nor',
#    'dropkind',
#    'dropkind',
#    'fieldkind',
#    'field',
#    'field',
#    'dropkind',
#    (array([0.632]), array([0.113]))],
#   ['field', 'dropkind', 'dropkind', (array([0.527]), array([0.402]))],
#   ['norwife',
#    'nor',
#    'dropkindkind',
#    'dropkindkind',
#    'coloronto',
#    'color',
#    'dropkind',
#    (array([0.206]), array([0.846]))],
#   ['dropkindprovide',
#    'dropkindkind',
#    'deonto',
#    'nor',
#    'field',
#    'dropkindkind',
#    'dropkindprovide',
#    'field',
#    (array([0.462]), array([0.406]))],
#   ['dropkindhope',
#    'nor',
#    'dropkind',
#    'fieldkind',
#    'nor',
#    'field',
#    (array([0.575]), array([0.347]))],
#   ['fieldpositive', 'nor', 'field', (array([0.011]), array([0.941]))],
#   ['ognize',
#    'color',
#    'field',
#    'defind',
#    'drop',
#    'dropkindprovide',
#    'dropkind',
#    (array([0.3]), array([0.977]))],
#   ['ndfind', 'color', 'dropkindkind', (array([0.684]), array([0.956]))],
#   ['fieldhope', 'field', 'dropkindprovide', (array([0.32]), array([0.385]))],
#   ['dropkindprovide',
#    'dropkindprovide',
#    'dropkindprovide',
#    'colortechnology',
#    'color',
#    'dropkindkind',
#    (array([0.954]), array([0.769]))],
#   ['dropkindhope',
#    'color',
#    'dropkindprovide',
#    'dropkind',
#    (array([0.191]), array([0.361]))],
#   ['ndkind',
#    'agency',
#    'dropkindprovide',
#    'field',
#    'dropkindprovide',
#    'dropkindkind',
#    'ortant',
#    'field',
#    'dropkindkind',
#    (array([0.079]), array([0.901]))],
#   ['dropkindprovide', (array([0.042]), array([0.362]))],
#   ['fieldonto', 'field', 'fieldonto', (array([0.503]), array([0.777]))],
#   ['norprovidehope',
#    'agency',
#    'dropkind',
#    'norprovide',
#    'nor',
#    'dropkind',
#    (array([0.423]), array([1.]))],
#   ['color',
#    'dropkind',
#    'field',
#    'norwife',
#    'nor',
#    'nor',
#    (array([0.743]), array([0.33]))],
#   ['norimportant',
#    'field',
#    'nor',
#    'norhalf',
#    'agency',
#    'nor',
#    'dropperform',
#    'drop',
#    'agencypositive',
#    (array([0.465]), array([0.417]))],
#   ['agencypositive',
#    'colorwater',
#    'color',
#    'norpainting',
#    (array([0.78]), array([0.687]))],
#   ['agencykind',
#    'agency',
#    'agency',
#    'agencypositive',
#    'nor',
#    'agency',
#    (array([0.042]), array([0.267]))],
#   ['drop', 'dropkind', (array([0.015]), array([0.769]))],
#   ['erform',
#    'agency',
#    'fieldperform',
#    'nortechnology',
#    'nor',
#    'drop',
#    (array([0.66]), array([0.532]))],
#   ['fieldworld',
#    'field',
#    'field',
#    'dropimportant',
#    'field',
#    'drop',
#    (array([0.184]), array([0.388]))],
#   ['dropimportant', 'field', 'drop', (array([0.09]), array([0.389]))],
#   ['sitive',
#    'color',
#    'drop',
#    'dropkindme',
#    'drop',
#    (array([0.523]), array([0.882]))]],
#  [['agencyme',
#    'color',
#    'drop',
#    'alsocivil',
#    'drop',
#    'also',
#    'agencymehim',
#    'also',
#    (array([0.997]), array([0.395]))],
#   ['dropshoulder',
#    'color',
#    'drop',
#    'droprecognize',
#    'drop',
#    'drop',
#    'color',
#    (array([0.472]), array([0.643]))],
#   ['noronto',
#    'nor',
#    'agencyme',
#    'norwife',
#    'nor',
#    'also',
#    'drop',
#    (array([0.262]), array([0.208]))],
#   ['alsoprovide', 'drop', 'also', 'drop', (array([0.579]), array([0.11]))],
#   ['agencyhim',
#    'agency',
#    'agencymehim',
#    'agencyperform',
#    'agency',
#    'also',
#    (array([0.391]), array([0.441]))],
#   ['mwaterme',
#    'nor',
#    'agencyme',
#    'also',
#    'mwater',
#    'field',
#    'agencymehim',
#    (array([0.694]), array([0.171]))],
#   ['agencymewater',
#    'agency',
#    'agencymehim',
#    'agencyme',
#    (array([0.257]), array([0.18]))],
#   ['agencyfind', 'color', 'agency', (array([0.395]), array([0.613]))],
#   ['agencyfind',
#    'drop',
#    'agency',
#    'field',
#    'agencyrecognize',
#    'agency',
#    'oulder',
#    'agency',
#    (array([0.971]), array([0.176]))],
#   ['norlong',
#    'field',
#    'nor',
#    'field',
#    'norrecognize',
#    'field',
#    'nor',
# ...
#    'oulderperform',
#    (array([0.664]), array([0.162]))],
#   ['norme',
#    'agency',
#    'field',
#    'nor',
#    'field',
#    'agency',
#    'alsokindprovide',
#    'field',
#    'field',
#    'field',
#    (array([0.846]), array([0.502]))],
#   ['alsokindwife',
#    'agency',
#    'alsokindprovide',
#    'alsokindwater',
#    'also',
#    'alsokind',
#    'also',
#    'alsokindprovide',
#    (array([0.277]), array([0.032]))],
#   ['fieldme', 'agency', 'field', (array([0.586]), array([0.001]))],
#   ['nor',
#    'nor',
#    'norkind',
#    'field',
#    'nor',
#    'nor',
#    'nor',
#    (array([0.994]), array([0.786]))],
#   ['nor', (array([0.84]), array([0.003]))],
#   ['color',
#    'colortechnology',
#    'agencywife',
#    'agency',
#    'colortechnology',
#    'color',
#    (array([0.086]), array([0.723]))],
#   ['gyonto', 'drop', 'colortechnology', (array([0.005]), array([0.2]))],
#   ['colortechnology', 'color', 'color', (array([0.845]), array([0.411]))],
#   ['nortechnology',
#    'nor',
#    'field',
#    'fieldfindkind',
#    'nor',
#    'fieldfind',
#    'fieldhope',
#    'drop',
#    'field',
#    (array([0.318]), array([0.874]))],
#   ['alsotechnology',
#    'alsoshoulder',
#    'color',
#    'alsotechnology',
#    'also',
#    'also',
#    (array([0.894]), array([0.528]))],
#   ['also', 'alsotechnology', (array([0.985]), array([0.998]))],
#   ['drophim',
#    'drop',
#    'nor',
#    'majority',
#    'ahead',
#    'agency',
#    (array([0.515]), array([0.003]))],
#   ['nor',
#    'zehalf',
#    'zehalf',
#    'majoritywater',
#    'drop',
#    'majority',
#    (array([0.198]), array([0.365]))],
#   ['aheadme',
#    'agency',
#    'zehalf',
#    'norrecognize',
#    'norrecognize',
#    'ahead',
#    (array([0.043]), array([0.37]))],
#   ['norperform',
#    'nor',
#    'nor',
#    'colorrecognize',
#    'agency',
#    'zehalf',
#    'agencypositive',
#    'color',
#    'agency',
#    (array([0.905]), array([0.003]))],
#   ['norme', 'nor', 'agencylong', (array([0.9]), array([0.37]))],
#   ['agencyhope',
#    'colorperform',
#    'color',
#    'agency',
#    'agency',
#    'ortant',
#    'color',
#    'majority',
#    (array([0.622]), array([0.105]))],
#   ['agency', 'majority', (array([0.412]), array([0.5]))],
#   ['majority',
#    'erform',
#    'field',
#    'agencyhope',
#    (array([0.852]), array([0.44]))],
#   ['agencyany',
#    'color',
#    'majority',
#    'majority',
#    'agencyhope',
#    'majority',
#    'majority',
#    'nology',
#    'agency',
#    'majority',
#    (array([0.411]), array([0.584]))],
#   ['inting',
#    'color',
#    'agencyhope',
#    'majority',
#    'majority',
#    'norme',
#    'nor',
#    'majority',
#    (array([0.742]), array([0.544]))],
#   ['agencyonto',
#    'nor',
#    'agency',
#    'nor',
#    'majority',
#    (array([0.606]), array([0.31]))],
#   ['nology',
#    'agency',
#    'majoritykind',
#    'majority',
#    'agencywater',
#    'agency',
#    'agency',
#    (array([0.823]), array([0.212]))],
#   ['majorityprovide',
#    'color',
#    'majority',
#    'majority',
#    'majority',
#    'majority',
#    (array([0.789]), array([0.347]))],
#   ['agencyhope', 'field', 'agency', (array([0.323]), array([0.484]))],
#   ['ortant',
#    'color',
#    'majority',
#    'agencyfind',
#    'agencyfind',
#    'agency',
#    (array([0.015]), array([0.062]))],
#   ['majority', (array([0.648]), array([0.296]))],
#   ['fieldpainting',
#    'agency',
#    'agency',
#    'fieldany',
#    'field',
#    'agency',
#    (array([0.144]), array([0.456]))],
#   ['agencyfind',
#    'majority',
#    'agencyfind',
#    'agencycivil',
#    'agency',
#    'majority',
#    (array([0.343]), array([0.754]))],
#   ['sitive',
#    'agency',
#    'agencyfind',
#    'majority',
#    (array([0.162]), array([0.618]))],
#   ['norshoulderhalf',
#    'nor',
#    'agency',
#    'ortant',
#    'field',
#    'agency',
#    'norshoulder',
#    'nor',
#    'majority',
#    (array([0.054]), array([0.102]))],
#   ['norpaintinglong',
#    'color',
#    'majority',
#    'agencyfind',
#    'norpainting',
#    'nor',
#    'majority',
#    (array([0.372]), array([0.522]))],
#   ['nology',
#    'agency',
#    'agencyfind',
#    'majority',
#    (array([0.604]), array([0.025]))],
#   ['drop',
#    'colorshoulder',
#    'color',
#    'droppositive',
#    'drop',
#    'majority',
#    'droppositive',
#    (array([0.613]), array([0.503]))],
#   ['majorityme',
#    'drop',
#    'drop',
#    'majority',
#    'droppositive',
#    'drop',
#    'colorworld',
#    'color',
#    'majority',
#    (array([0.893]), array([0.914]))],
#   ['ognize',
#    'color',
#    'majority',
#    'majoritylong',
#    'field',
#    'drop',
#    'majority',
#    (array([0.668]), array([0.256]))],
#   ['colorhope', 'color', 'field', (array([0.261]), array([0.068]))],
#   ['drop',
#    'field',
#    'drophalf',
#    'drop',
#    'drop',
#    (array([0.478]), array([0.189]))],
#   ['oulder',
#    'color',
#    'although',
#    'droptechnology',
#    'drop',
#    'field',
#    (array([0.993]), array([0.284]))],
#   ['dropprovide',
#    'colorshoulder',
#    'color',
#    'dropprovide',
#    (array([0.798]), array([0.571]))],
#   ['drop',
#    'although',
#    'fieldlong',
#    'field',
#    'field',
#    'field',
#    (array([0.247]), array([0.168]))],
#   ['dropme', 'drop', 'field', (array([0.649]), array([0.174]))],
#   ['althoughcivil',
#    'drop',
#    'although',
#    'although',
#    (array([0.12]), array([0.43]))],
#   ['fieldwife',
#    'field',
#    'although',
#    'norkind',
#    'nor',
#    'field',
#    'norprovide',
#    'nor',
#    'field',
#    (array([0.401]), array([0.23]))],
#   ['inting',
#    'agency',
#    'although',
#    'fieldpainting',
#    'field',
#    'field',
#    (array([0.759]), array([0.259]))],
#   ['drop', 'drop', (array([0.11]), array([0.222]))],
#   ['field',
#    'although',
#    'dropimportant',
#    'although',
#    (array([0.773]), array([0.583]))],
#   ['agencykind', 'agency', 'although', (array([0.958]), array([0.292]))],
#   ['colorfind', 'color', 'oulder', (array([0.734]), array([0.253]))],
#   ['agencypainting',
#    'nor',
#    'although',
#    'agencyworld',
#    'color',
#    'although',
#    'although',
#    'althoughkind',
#    'agency',
#    'although',
#    (array([0.488]), array([0.791]))],
#   ['sitive',
#    'color',
#    'although',
#    'although',
#    'although',
#    'oulder',
#    'although',
#    (array([0.961]), array([0.485]))],
#   ['agencyhope',
#    'nor',
#    'although',
#    'oulder',
#    'agencypainting',
#    'nor',
#    'oulder',
#    'agency',
#    'although',
#    (array([0.378]), array([0.051]))],
#   ['although',
#    'oulderpositive',
#    'field',
#    'oulder',
#    (array([0.835]), array([0.721]))],
#   ['althoughwife',
#    'field',
#    'although',
#    'oulder',
#    'although',
#    'oulder',
#    (array([0.767]), array([0.913]))],
#   ['oulder',
#    'agencyrecognize',
#    'agency',
#    'although',
#    'although',
#    (array([0.694]), array([0.654]))],
#   ['fieldhim', 'field', 'agency', (array([0.45]), array([0.674]))],
#   ['agency',
#    'oulder',
#    'although',
#    'although',
#    'although',
#    'dropshoulder',
#    'drop',
#    'oulder',
#    (array([0.318]), array([0.075]))],
#   ['droplong',
#    'agency',
#    'agency',
#    'agency',
#    'oulderme',
#    'field',
#    'although',
#    'oulderfind',
#    'drop',
#    'oulder',
#    (array([0.334]), array([0.458]))],
#   ['althoughprovide',
#    'fieldprovide',
#    'field',
#    'nor',
#    (array([0.234]), array([0.709]))],
#   ['rovide',
#    'nor',
#    'although',
#    'althoughany',
#    (array([0.889]), array([0.984]))],
#   ['althoughanywife',
#    'nor',
#    'agency',
#    'althoughanyme',
#    'color',
#    'althoughany',
#    (array([0.24]), array([0.562]))],
#   ['fieldprovide', 'field', 'nor', (array([0.758]), array([0.236]))],
#   ['ognize', 'drop', 'colorworld', (array([0.693]), array([0.152]))],
#   ['dropcivil',
#    'field',
#    'drop',
#    'drophalf',
#    'drop',
#    'field',
#    'fieldperform',
#    'field',
#    'drop',
#    (array([0.894]), array([0.379]))],
#   ['dropwife', 'agency', 'drop', (array([0.75]), array([0.153]))],
#   ['colorme', 'color', 'dropshoulder', (array([0.649]), array([0.675]))],
#   ['color', 'droplong', 'color', 'drop', (array([0.683]), array([0.313]))],
#   ['dropwaterhim', 'drop', 'dropwater', (array([0.476]), array([0.505]))],
#   ['drop',
#    'dropwife',
#    'drop',
#    'drop',
#    'drophalf',
#    'nor',
#    'drop',
#    (array([0.877]), array([0.688]))],
#   ['dropprovide',
#    'agency',
#    'colorhope',
#    'inting',
#    'color',
#    'drop',
#    'color',
#    'drop',
#    'colorhope',
#    (array([0.982]), array([0.051]))],
#   ['dropkind', 'droponto', 'nor', 'drop', (array([0.701]), array([0.305]))],
#   ['dropshoulder', 'nor', 'drop', (array([0.78]), array([0.021]))],
#   ['dropkindfind',
#    'drop',
#    'dropkind',
#    'dropwife',
#    'nor',
#    'drop',
#    'dropkind',
#    'drop',
#    (array([0.115]), array([0.565]))],
#   ['dropperform', 'nor', 'drop', 'drop', (array([0.804]), array([0.757]))],
#   ['dropkindkind',
#    'color',
#    'dropkind',
#    'dropkind',
#    'fieldwife',
#    'field',
#    'drop',
#    'dropkind',
#    (array([0.995]), array([0.901]))],
#   ['dropkind',
#    'dropkindperform',
#    'nor',
#    'dropkind',
#    'dropkindkind',
#    'field',
#    'dropkind',
#    'dropkind',
#    (array([0.245]), array([0.339]))],
#   ['dropprovideme',
#    'nor',
#    'drop',
#    'dropprovide',
#    'agency',
#    'drop',
#    (array([0.665]), array([0.157]))],
#   ['dropcivil', 'agency', 'drop', (array([0.41]), array([0.513]))],
#   ['dropkind',
#    'drop',
#    'dropkind',
#    'dropprovide',
#    'color',
#    'drop',
#    (array([0.428]), array([0.511]))],
#   ['dropme',
#    'field',
#    'dropkind',
#    'drop',
#    'droponto',
#    'agency',
#    'drop',
#    'drop',
#    'dropkind',
#    (array([0.847]), array([0.733]))],
#   ['norpositivekind',
#    'color',
#    'drop',
#    'norpositive',
#    'nor',
#    'drop',
#    (array([0.519]), array([0.329]))]],
#  [['dropfind', 'drop', 'also', (array([0.028]), array([0.45]))],
#   ['fieldany', 'color', 'field', (array([0.057]), array([0.267]))],
#   ['fieldworld',
#    'drop',
#    'field',
#    'alsopositive',
#    'color',
#    'alsokind',
#    'alsokind',
#    'alsoonto',
#    'color',
#    'also',
#    (array([0.369]), array([0.488]))],
#   ['agencyme',
#    'agency',
#    'also',
#    'colorhalf',
#    'color',
#    'field',
#    'also',
#    'agencykind',
#    'color',
#    'agency',
#    (array([0.687]), array([0.441]))],
#   ['nology',
#    'field',
#    'agency',
#    'alsokindprovide',
#    'alsokindprovide',
#    'fieldimportant',
#    'field',
#    'agency',
#    (array([0.416]), array([0.596]))],
#   ['agencyperform',
#    'nor',
#    'also',
#    'fieldme',
#    'field',
#    'agency',
#    (array([0.079]), array([0.668]))],
#   ['agencyhope',
#    'field',
#    'agency',
#    'agency',
#    'agencyperform',
#    'agency',
#    'agency',
#    (array([0.265]), array([0.126]))],
#   ['nortechnology', 'nor', 'also', (array([0.262]), array([0.365]))],
#   ['alsopainting',
#    'nor',
#    'field',
#    'also',
#    'agency',
#    'alsokindprovide',
#    'agency',
#    (array([0.092]), array([0.077]))],
#   ['oulderperform',
#    'agency',
#    'field',
#    'oulder',
#    'nor',
#    'field',
#    'field',
#    'field',
#    'alsokindprovide',
#    (array([0.888]), array([0.011]))],
#   ['alsopositive',
#    'field',
#    'alsokindprovide',
#    'alsokindwater',
#    'field',
#    'alsokind',
#    'also',
#    (array([0.24]), array([0.581]))],
#   ['also', 'field', (array([0.736]), array([0.588]))],
#   ['colorhim',
#    'field',
#    'nor',
#    'norhim',
#    'color',
#    'nor',
#    (array([0.514]), array([0.348]))],
#   ['fieldcivil',
#    'field',
#    'field',
#    'alsopainting',
#    (array([0.704]), array([0.583]))],
#   ['nor', (array([0.187]), array([0.038]))],
#   ['fieldkind',
#    'agency',
#    'field',
#    'dropany',
#    (array([0.191]), array([0.744]))],
#   ['agencyhalf', 'agency', 'alsopainting', (array([0.984]), array([0.127]))],
#   ['alsopainting',
#    'also',
#    'field',
#    'alsopainting',
#    'nor',
#    'field',
#    'also',
#    (array([0.067]), array([0.057]))],
#   ['colortechnology', 'color', 'nor', (array([0.674]), array([0.283]))],
#   ['nor', 'colorshoulder', 'color', 'drop', (array([0.52]), array([0.224]))],
#   ['fieldfind',
#    'nor',
#    'field',
#    'dropany',
#    'fieldtechnology',
#    'drop',
#    'dropany',
#    'field',
#    (array([0.207]), array([0.894]))],
#   ['alsotechnology', 'agency', 'also', (array([0.464]), array([0.766]))],
#   ['zehalf',
#    'agency',
#    'majority',
#    'norrecognize',
#    'nor',
#    'ahead',
#    (array([0.777]), array([0.048]))],
#   ['majority',
#    'agencylong',
#    'agency',
#    'majority',
#    'majorityperform',
#    'agency',
#    'majority',
#    'majority',
#    (array([0.602]), array([0.801]))],
#   ['majoritykind',
#    'nor',
#    'majority',
#    'majority',
#    'agencyhope',
#    'agency',
#    'majority',
#    'majority',
#    (array([0.92]), array([0.293]))],
#   ['majority',
#    'majority',
#    'agencyfind',
#    'agency',
#    'majority',
#    'majority',
#    (array([0.756]), array([0.187]))],
#   ['droppositive', 'drop', 'majority', (array([0.751]), array([0.185]))],
#   ['norworld',
#    'agency',
#    'majority',
#    'norhalf',
#    'nor',
#    'majority',
#    'majority',
#    (array([0.74]), array([0.738]))],
#   ['dropimportant',
#    'field',
#    'although',
#    'field',
#    'dropprovide',
#    'drop',
#    'although',
#    (array([0.982]), array([0.412]))],
#   ['oulder',
#    'agency',
#    'although',
#    'although',
#    (array([0.97]), array([0.738]))],
#   ['norhim',
#    'field',
#    'althoughany',
#    'althoughprovide',
#    'field',
#    'although',
#    'norimportant',
#    'nor',
#    'although',
#    (array([0.347]), array([0.882]))],
#   ['inting',
#    'nor',
#    'field',
#    'althoughany',
#    'although',
#    (array([0.565]), array([0.146]))],
#   ['althoughany',
#    'although',
#    'although',
#    'althoughany',
#    'field',
#    'agencykind',
#    'agency',
#    'although',
#    (array([0.473]), array([0.399]))],
#   ['fieldwife',
#    'field',
#    'although',
#    'dropme',
#    'drop',
#    'field',
#    (array([0.431]), array([0.382]))],
#   ['althoughperform',
#    'nor',
#    'althoughany',
#    'colorworld',
#    'color',
#    'although',
#    'although',
#    'althoughany',
#    (array([0.249]), array([0.371]))],
#   ['fieldpositive',
#    'field',
#    'dropshoulder',
#    'drop',
#    (array([0.265]), array([0.749]))],
#   ['fieldfind', 'field', 'drop', (array([0.389]), array([0.56]))],
#   ['dropshoulder',
#    'dropwater',
#    'field',
#    'drop',
#    'drop',
#    'colorhim',
#    'color',
#    'drop',
#    (array([0.651]), array([0.925]))],
#   ['dropwife',
#    'color',
#    'drop',
#    'drop',
#    'drop',
#    'drophalf',
#    'color',
#    'drop',
#    (array([0.1]), array([0.315]))],
#   ['drop',
#    'dropfind',
#    'field',
#    'dropshoulder',
#    'drop',
#    'drop',
#    'drop',
#    'drop',
#    (array([0.269]), array([0.783]))],
#   ['agencyany', 'agency', 'drop', 'drop', (array([0.514]), array([0.213]))],
#   ['droptechnology',
#    'agency',
#    'drop',
#    'drop',
#    'dropshoulder',
#    'drop',
#    (array([0.169]), array([0.993]))],
#   ['drop', 'drop', (array([0.805]), array([0.336]))],
#   ['drop', 'colorhope', 'color', 'drop', (array([0.399]), array([0.634]))],
#   ['dropshoulder', (array([0.23]), array([0.136]))],
#   ['dropkind', 'drop', 'drop', (array([0.805]), array([0.087]))]],
#  [['alsokindprovide',
#    'agency',
#    'field',
#    'alsokind',
#    'agency',
#    'also',
#    'also',
#    (array([0.978]), array([0.536]))],
#   ['alsopainting',
#    'nor',
#    'also',
#    'dropany',
#    'drop',
#    'field',
#    (array([0.758]), array([0.533]))],
#   ['ahead',
#    'although',
#    'aheadlong',
#    'agency',
#    'ahead',
#    'agency',
#    'effort',
#    (array([0.122]), array([0.307]))],
#   ['fieldfind',
#    'field',
#    'majority',
#    'agency',
#    'ahead',
#    'ahead',
#    'majority',
#    (array([0.63]), array([0.639]))],
#   ['ahead',
#    'norfind',
#    'nor',
#    'effort',
#    'althoughany',
#    'color',
#    'although',
#    (array([0.38]), array([0.942]))],
#   ['majority', 'majority', 'majority', (array([0.76]), array([0.556]))],
#   ['althoughany',
#    'field',
#    'although',
#    'although',
#    'although',
#    (array([0.899]), array([0.115]))],
#   ['ahead',
#    'effort',
#    'dropkind',
#    'drop',
#    'although',
#    (array([0.084]), array([0.926]))],
#   ['droplong',
#    'drop',
#    'agency',
#    'although',
#    'fieldwater',
#    'field',
#    'although',
#    (array([0.48]), array([0.287]))],
#   ['ahead', (array([0.311]), array([0.758]))],
#   ['drop', 'dropshoulder', 'drop', 'drop', (array([0.965]), array([0.158]))]],
#  [['field', 'also', 'candidate', (array([0.768]), array([0.822]))],
#   ['agency',
#    'ahead',
#    'effort',
#    'majority',
#    'although',
#    (array([0.916]), array([0.851]))],
#   ['drop', (array([0.488]), array([0.351]))],
#   ['color', 'hit', 'factor', (array([0.57]), array([0.118]))],
#   ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]]

# %%
topic_list
# Out:
# [['field', 'also', 'candidate', (array([0.768]), array([0.822]))],
#  ['agency',
#   'ahead',
#   'effort',
#   'majority',
#   'although',
#   (array([0.916]), array([0.851]))],
#  ['drop', (array([0.488]), array([0.351]))],
#  ['color', 'hit', 'factor', (array([0.57]), array([0.118]))],
#  ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]

# %%
##Seems like the generator is working. The quality of the output can be handled by tuning the probabilities and behaviour
##functions, but the topic_space_master documents contains a list generations and each generations is a list of lists where
##each list in a generation represents one subtopic (one elaboration). These subtopics can be used and seen as the keyword 
##base for documents dealing with these topics and be used as input for sentence generation to simulate noise in speech.

# %%
#Define a bag of frequently used words:
used_words = words[-50:]
del words[-50:]

frequently_used_words = words[-20:]
del words[-20:]

often_used_words = words[-5:]
del words[-5:]

# %%
#WRITE ABSTRACTS FROM TOPIC SPACE FUNCTION

abstracts_master = []
#This functions writes an abstract for each topic to embedd the noise of text data.**
def write_abstracts(master_topic_space):
    for generation in master_topic_space:
        #print(generation)
        abstract_topic_space = []
        for topic in generation:
            #print(topic)
            abstract=[]
            for word in topic[:-1]:
                word_usage_amount = rnd.randint(1,3)
                words_used=0
                while words_used < word_usage_amount:
                    #print(word)
                    abstract.insert(0,fake.sentence(nb_words = rnd.randint(5,10), ext_word_list=[
                    word,
                    word,
                    word,
                    frequently_used_words[rnd.randint(0,len(frequently_used_words)-1)],
                    frequently_used_words[rnd.randint(0,len(frequently_used_words)-1)],
                    often_used_words[rnd.randint(0,len(often_used_words)-1)],
                    used_words[rnd.randint(0,len(used_words)-1)],
                    used_words[rnd.randint(0,len(used_words)-1)],
                    words[rnd.randint(0,len(words)-1)],
                    words[rnd.randint(0,len(words)-1)]
                    ]))
                    words_used = words_used + 1
                    #print(words_used)
            abstract_topic_space.insert(0,abstract)
        abstracts_master.insert(0,abstract_topic_space)
    return abstracts_master
#Note: The purpose of this cell is to write abstract out of the keywords to embedd noise with sentences.
#Thus different amount of 'word noise' can be embedded and the speach recognition algorithms can be tested
#on accurate finding the words which were key parts of the topics.
abstracts = write_abstracts(topic_space_master)

# %%
abstracts
# Out:
# [[['Free free statement statement statement stock stock act statement agreement statement stock.',
#    'Knowledge best statement statement produce statement herself.',
#    'Statement record statement statement.',
#    'Piece daughter piece daughter piece keep act keep still piece.',
#    'Unit daughter traditional piece mission piece.',
#    'Eye old letter eye upon parent upon.',
#    'Whatever guy eye eye guy guy eye fire.',
#    'Eye act reality act eye always act bill bill bill bill eye record.',
#    'Deep knowledge nor knowledge knowledge ever.',
#    'Old economy own own.'],
#   ['Necessary factor great factor factor recently during recently nice during.',
#    'Talk turn factor guy.',
#    'Structure sister bill exist hair factor.',
#    'Whole hit whole stock hit.',
#    'Thing hit fire upon record record.',
#    'Necessary relate probably necessary color relate.',
#    'But recently meeting suffer recently.',
#    'Color color pay color three pay color yet.'],
#   ['Great recently knowledge drop drop there choose drop.'],
#   ['Thing thing although mouth thing.',
#    'Although usually although act.',
#    'Guy believe keep keep believe.',
#    'Middle turn meeting blood turn middle old effort center effort blood effort.',
#    'Point effort even even point.',
#    'Support ahead case case vote support ahead ahead.',
#    'Single own own ahead point.',
#    'Ahead choice ahead impact.',
#    'Agency get throughout old old finish agency.',
#    'Because because because necessary because fire develop agency necessary fire agency necessary.',
#    'Call agency call.'],
#   ['Candidate entire candidate but candidate act candidate candidate.',
#    'Candidate make probably candidate.',
#    'Bill during bill during candidate understand interest.',
#    'Than talk also also than own born.',
#    'Also also sure sort also.',
#    'Idea also also also recently.',
#    'Begin sort field sort sort probably yet.',
#    'Field probably field field field party health probably health record field record.',
#    'Old turn music stock case old music stock old.']],
#  [['Drop recently but daughter able but.',
#    'Response chair drop.',
#    'Stock bad drop drop the probably drop.',
#    'Believe believe hard old upon upon.',
#    'Understand dropshoulder history share share dropshoulder dropshoulder.',
#    'Dropshoulder unit dropshoulder recently.',
#    'Thing drop mother mother this.'],
#   ['Ahead ahead skin five skin five ahead.',
#    'Would ahead would pay knowledge recently knowledge pay parent nothing.',
#    'Guy guy case case impact ahead ahead.'],
#   ['Although talk although character sure although.',
#    'Probably although always change.',
#    'Field exist develop field field.',
#    'Old field field sense sense develop.',
#    'Field herself upon talk field class between.',
#    'Fire huge huge student fieldwater.',
#    'Fieldwater pay meeting pay box meeting box anyone recently fieldwater anyone.',
#    'Fieldwater fieldwater fieldwater case case bring fieldwater.',
#    'Although although guy although recently accept because because although.',
#    'Walk determine begin determine.',
#    'Drop drop drop fire drop exist anyone exist.',
#    'Own thing droplong droplong recently.'],
#   ['Third although probably probably stay probably although.',
#    'Loss old yet although meeting daughter although.',
#    'Believe his drop fire begin drop believe result his his begin.',
#    'Drop unit early believe drop.',
#    'But world probably but probably.',
#    'Assume assume effort effort record effort fire left.',
#    'Fire ahead safe ahead admit fire too fire ahead too ahead.',
#    'Standard onto knowledge great ahead recently ahead stock.'],
#   ['Herself probably keep although herself although although probably keep.',
#    'Table although although.',
#    'Although although nothing character character although talk number character character.',
#    'Real real although anyone old anyone.',
#    'Although whole although good good good.',
#    'Five deep window window although although.',
#    'Although although deep probably.',
#    'Field history even even culture table culture field turn history table field.',
#    'Have fire understand meeting field.',
#    'Field exist catch system develop exist develop believe field because.',
#    'Althoughany althoughany improve probably probably improve althoughany althoughany althoughany.'],
#   ['Necessary loss similar understand anyone though anyone though.',
#    'Majority couple determine value couple couple majority guy value old majority old.',
#    'Character fire thus know majority thus guy know.',
#    'Increase increase health but.',
#    'Majority talk bill majority sure.',
#    'Determine many majority tree majority knowledge.',
#    'But new majority teacher majority own new.',
#    'Majority history necessary history old fine stock majority.'],
#   ['Loss road support although support loss.',
#    'Fire thus bill herself color shoulder color.',
#    'Get color color stock color old whole whole old stock old.',
#    'Color old color color knowledge color knowledge color color.',
#    'Beyond beyond begin begin believe form althoughany.',
#    'Behind anyone effort effort old study exist anyone old.',
#    'Nor nor knowledge nor fire letter nor.',
#    'Recently bill staff sure norfind norfind bill norfind finally.',
#    'Norfind trade talk.',
#    'Marriage simply norfind always anyone simply.',
#    'Ahead point movie before ahead recently.'],
#   ['During majority majority stuff majority recently create recently during.',
#    'Majority act table.',
#    'Majority student majority student strong old student.',
#    'Act ahead case bill.',
#    'Seven fire fire fire fire unit knowledge fire.',
#    'Ahead ahead ahead ahead probably door well develop.',
#    'Begin begin history ahead daughter ahead.',
#    'Act energy traditional agency agency support best support energy exist exist energy agency.',
#    'Entire agency fire top.',
#    'Majority majority majority wide health.',
#    'Field case we during during.',
#    'Case field perhaps anyone field field loss fire case anyone fire.',
#    'Keep whole recently attack.',
#    'Mind talk fieldfind.',
#    'Fieldfind fieldfind community middle fieldfind fear.'],
#   ['Property case early keep keep property keep early early challenge case.',
#    'Effort character support support.',
#    'Daughter believe always effort dog.',
#    'Early agency arm agency arm arm early agency.',
#    'Agency stock agency always left voice.',
#    'Fire loss ahead ahead ahead.',
#    'Begin agency recently agency begin do.',
#    'Believe agency fire pay agency fire agency pay rest agency.',
#    'Record aheadlong fire aheadlong aheadlong own place aheadlong politics.',
#    'Thing rather aheadlong thing suffer aheadlong thing.',
#    'Aheadlong phone record above aheadlong necessary necessary above probably phone.',
#    'Allow history history although history although.',
#    'Point ahead population ahead image herself population image religious meeting.',
#    'Ahead recently ahead ahead ahead early.'],
#   ['Hair keep hair table save field save keep.',
#    'Recently begin popular begin use begin call recently recently drop popular recently use.',
#    'Fire knowledge knowledge dropany great.',
#    'Dropany many develop dropany dropany probably hair entire dropany.',
#    'Fire also believe guy believe fire also also believe believe also.',
#    'Study talk nor case talk.',
#    'Probably relate nor nor star star nor.',
#    'Begin alsopainting use analysis.'],
#   ['Determine also stock point simply point act simply guy act.',
#    'Your old understand point.',
#    'Also also great great really also.',
#    'Also relate also act daughter develop.',
#    'Smile agency especially especially fire pay agency develop.',
#    'Case character agency case feeling agency agency turn.',
#    'Record alsokind smile he smile record.',
#    'Act guy alsokind country.',
#    'Stock field relate field meeting.',
#    'Term term table develop discussion field.',
#    'Begin field understand field begin understand understand field understand environmental field field.',
#    'History own show daughter daughter act agency.',
#    'Professor agency before agency even finish school professor.',
#    'Cultural account account agency agency determine cultural.',
#    'Thing middle alsokindprovide trial middle trial.',
#    'Alsokindprovide pay he alsokindprovide alsokindprovide month alsokindprovide.']],
#  [['Out approach drop out recently.',
#    'Discover develop drop drop develop guy develop guy.',
#    'Drop focus middle drop drop drop drop exist middle.',
#    'Impact drop age record drop.',
#    'Begin old old drop begin make table drop leave drop begin drop.',
#    'Dropkind recently use call recently recently tend dropkind recently.',
#    'Relate dropkind unit old dropkind dropkind.'],
#   ['Fund old dropshoulder dropshoulder fund old record old.',
#    'Recently dropshoulder dropshoulder recently meeting understand dropshoulder recently dropshoulder herself meeting.'],
#   ['Drop herself herself drop.',
#    'Drop support no support drop recently always support drop.',
#    'Old night drop his old necessary drop drop night drop drop night but.',
#    'Guess color this guess color color usually bill bill.',
#    'Unit color color third spring unit.',
#    'Thing support support both ground colorhope road road road act both ground both.',
#    'Colorhope deal colorhope colorhope than than colorhope.',
#    'Colorhope recently reduce colorhope colorhope meeting meeting colorhope upon table thing.',
#    'Dinner probably case get.',
#    'Necessary necessary entire necessary skill drop probably skill exist.',
#    'Risk industry drop drop new new drop drop.'],
#   ['Include develop billion necessary.',
#    'Under act under drop.',
#    'Finally anyone responsibility anyone thus thus anyone.'],
#   ['Drop note drop believe note boy boy believe.',
#    'Drug drop drop support.',
#    'Dropshoulder many dropshoulder fire always herself many herself guess dropshoulder herself always.',
#    'Get design history history dropshoulder probably probably oil oil.',
#    'Dropshoulder pick support dropshoulder begin support support point dropshoulder.',
#    'Drop drop drop anyone entire language entire entire drop suffer drop drop.',
#    'Drop call now tree now drop.',
#    'Drop own drop begin drop fire drop sense fire drop sense.',
#    'Agency middle agency agency check agency check probably.',
#    'Guy then but.',
#    'Agency throughout even own agency me.',
#    'Least make least droptechnology.',
#    'Probably droptechnology droptechnology claim take droptechnology droptechnology.'],
#   ['Drop guess guess bag best drop.',
#    'Drop science loss science probably.',
#    'New drop new old.',
#    'Impact support impact last drop drop.',
#    'Firm usually recently case drop drop recently usually firm firm drop.',
#    'Agency agency meeting agency agency agency go too.',
#    'Thing agencyany daughter agencyany.',
#    'Born even call director even even.',
#    'Agencyany probably agencyany probably agencyany from agencyany table agencyany table.'],
#   ['Six drop raise develop.',
#    'Power great great usually drop power recently director daughter drop director power.',
#    'Make recently drop teacher make herself drop drop.',
#    'Drop worker health use drop old drop old drop drop.',
#    'Space space drop drop over thing.',
#    'School fire drop school.',
#    'Drop act herself knowledge.',
#    'Painting painting entire old support always.',
#    'Always partner officer entire.',
#    'A stock probably dropshoulder.',
#    'Security dropshoulder dropshoulder special dropshoulder dropshoulder dropshoulder upon probably.',
#    'Relate herself field traditional create create traditional.',
#    'Effect field field knowledge field.',
#    'But necessary necessary field feeling feeling here suffer field field necessary.',
#    'Get act believe get dropfind democratic deep.',
#    'Probably relate dropfind dropfind relate.',
#    'Knowledge fire meeting finally drop.',
#    'Record drop drop drop drop drop drop.'],
#   ['Hundred relate believe hundred believe recently class believe drop believe.',
#    'Color table anyone table table anyone color color color table.',
#    'Open fire pay anyone color.',
#    'Record figure figure color record.',
#    'Drophalf drophalf old drophalf begin drophalf.',
#    'Act teacher begin begin bill.',
#    'Recently drop form drop recently become become.',
#    'Drop table table drop.',
#    'Drop anyone drop church five.',
#    'Old talk old color old talk color color color.',
#    'Exist until dropwife dropwife region believe region probably.',
#    'Dropwife stock huge early line before.',
#    'Table dropwife old believe technology technology believe dropwife.'],
#   ['Table drop drop table table middle American table change middle.',
#    'Believe color animal color make color color color.',
#    'Colorhim pay chair begin turn.',
#    'Hair talk colorhim guy colorhim.',
#    'Recently but colorhim.',
#    'Herself mind tree but drop drop.',
#    'Believe believe drop fire knowledge analysis knowledge drop fire.',
#    'Old drop unit drop identify drop identify unit drop.',
#    'Relate drop treatment relate drop recently support treatment drop.',
#    'As field guy guy.',
#    'Anyone field field anyone bill act act sure sure.',
#    'Paper dropwater believe dropwater fire.',
#    'Entire eight believe dropshoulder point entire.'],
#   ['Probably develop because pay.',
#    'Get field relate daughter.',
#    'Five religious field field onto religious onto.',
#    'Help guy guy.'],
#   ['Drop drop yet probably drop believe probably probably believe control.',
#    'Drop meeting recently recently.',
#    'Table old hair hair table stock.',
#    'Exist exist during old talk during into dropshoulder dropshoulder dropshoulder dropshoulder difficult.',
#    'Develop stock stock hour.',
#    'Dropshoulder bill support history old finally dropshoulder dropshoulder history support.',
#    'Discuss great field field design field.',
#    'Act school case buy fieldpositive school act case case school fieldpositive.',
#    'Fieldpositive only get fieldpositive get history only fieldpositive.',
#    'Fieldpositive fieldpositive record parent fieldpositive.'],
#   ['Point stock remain remain althoughany herself recently.',
#    'Record act although bag character character.',
#    'Usually although political.',
#    'Although old although before necessary.',
#    'Meeting single meeting mouth color color.',
#    'Unit suddenly meeting colorworld hair.',
#    'Colorworld colorworld colorworld colorworld colorworld.',
#    'Usually soldier althoughany usually character develop organization soldier.',
#    'Religious recent nor tend tend.',
#    'Republican Republican case Republican use Republican Republican nor use.',
#    'Nor meeting nor meeting nor special.',
#    'Even althoughperform he althoughperform althoughperform.',
#    'Unit challenge knowledge five knowledge green fire case fire fire.',
#    'Few althoughperform whole althoughperform get unit althoughperform althoughperform.'],
#   ['Health thing daughter thing field thing thing system military.',
#    'Guess knowledge relate drop act drop.',
#    'Finish blood drop drop meeting.',
#    'Ready data data drop act throughout.',
#    'Suffer suffer suffer dropme test dropme dropme suffer test a suffer.',
#    'Act record thus act act here dropme record.',
#    'Dropme dropme probably card.',
#    'Although although although although although probably traditional guy throughout daughter.',
#    'Necessary although price although although price guess necessary.',
#    'Break then field field then field knowledge pay knowledge act.',
#    'Fieldwife air fieldwife fieldwife act.'],
#   ['Until loss until although until even.',
#    'Time guy time time guy agency he.',
#    'Agencykind anyone entire entire.',
#    'Daughter range impact range impact impact act agencykind agencykind agencykind impact.',
#    'Get always meeting type maybe always.',
#    'Field support hold field field field.',
#    'Business business recently.',
#    'Work field field field character character.',
#    'Guy tree guy.',
#    'Fire althoughany dark because althoughany althoughany.',
#    'Throughout act act althoughany althoughany class althoughany althoughany.',
#    'Although act character character knowledge although act sure character parent.',
#    'Store unit media stock stock.',
#    'Although although probably health although health.',
#    'Although although although hear yet but but.',
#    'Case althoughany althoughany probably traditional nation.',
#    'Believe guy history believe althoughany.',
#    'Impact network althoughany althoughany impact knowledge.'],
#   ['Tree although old stop stop herself but.',
#    'Old anyone although even old old own.',
#    'Old guy but although but although.',
#    'Althoughany daughter althoughany althoughany daughter althoughany althoughany althoughany sure car middle althoughany herself.',
#    'Save althoughany althoughany turn he exactly althoughany althoughany but daughter he.',
#    'Talk althoughany althoughany ball.',
#    'Develop whole field guy develop field develop field.',
#    'Field field field field fire similar call similar similar field call.',
#    'Field field score act support score whole field field early score anyone.',
#    'Nor case even and nor probably probably nor loss nor he probably.',
#    'Inting finally inting meeting central inting five.'],
#   ['School believe now even.',
#    'Place probably meeting meeting deep nor deep.',
#    'Case norimportant norimportant norimportant act case norimportant hair norimportant company act.',
#    'Different norimportant different whole recently norimportant norimportant but recently different.',
#    'Case unit necessary case norimportant norimportant norimportant norimportant before.',
#    'Fire turn turn throughout although although.',
#    'Unit talk case although agent act although.',
#    'Field field finally else whole field field field whole.',
#    'New develop old call field.',
#    'Meeting field field soon field record field record old.',
#    'Althoughprovide recently recently ball meeting ball recently network.',
#    'Althoughany althoughany althoughany probably traditional tree althoughany althoughany.',
#    'Althoughany nothing althoughany althoughany recently nothing althoughany althoughany.',
#    'Yet field yet field notice table anyone probably beat probably field yet notice.',
#    'Believe norhim believe norhim point norhim norhim bed point.',
#    'Modern modern but norhim but.',
#    'Norhim norhim recently support develop affect support.'],
#   ['Although meeting similar although case case.',
#    'Although table although specific table specific.',
#    'Beat deep necessary.',
#    'Begin always dinner agency during spring dinner.',
#    'Citizen citizen agency agency gas case.',
#    'Something even get oulder get get bank.',
#    'Hair table point long oulder recently industry table.',
#    'Oulder consumer result great great.'],
#   ['Daughter even although we we even doctor determine determine although.',
#    'Act although although hair guy guy although.',
#    'Own own drop result water drop.',
#    'Dropprovide dropprovide dropprovide dropprovide keep keep dropprovide.',
#    'Dropprovide dropprovide magazine dropprovide own history left.',
#    'Yet school table table wide field wide.',
#    'Even yet above field field field even field believe.',
#    'Even although point describe develop even.',
#    'Record probably believe probably although.',
#    'Get field get field field like before federal.',
#    'Field strong hair field begin begin.',
#    'Act table suddenly yet act.',
#    'Too another dropimportant dropimportant talk too act.',
#    'Tree dropimportant probably guy.'],
#   ['Result talk act fast fast result usually majority usually result.',
#    'Majority support old tax.',
#    'Knowledge health necessary.',
#    'Television majority television majority majority.',
#    'Guy effect nor nation deep nor.',
#    'Law nor nor lawyer.',
#    'Religious norhalf meeting meeting meeting act act keep act.',
#    'Support unit majority record nothing ever.',
#    'Wide majority wide point wide majority.',
#    'Throughout middle get middle middle agency.',
#    'Agency agency agency reflect.',
#    'Guy admit norworld.',
#    'Anyone norworld anyone nothing table over over norworld.',
#    'Even fire character norworld fire norworld character use allow never never.'],
#   ['Probably probably anyone.',
#    'Drop measure knowledge build build act.',
#    'Meeting he drop drop fire he drop guess fire even.',
#    'Droppositive droppositive road droppositive daughter.',
#    'Leader pay get but get religious droppositive pay old droppositive pay.'],
#   ['Majority paper bill bill majority whole paper always bill bill.',
#    'Daughter bring daughter majority health unit majority daughter and bring daughter probably majority.',
#    'Wonder develop develop determine.',
#    'Finally majority why gun majority support majority finally majority relate gun finally.',
#    'Probably usually probably develop yet usually yet develop Mr Mr.',
#    'Price school agency guy guy school school.',
#    'Believe usually usually case agency case agency believe.',
#    'Agencyfind agencyfind old agencyfind.',
#    'Stock guess base majority base guess majority.',
#    'Majority program majority majority anyone.',
#    'Act book book majority camera act.',
#    'Majority history majority table history majority police majority table.'],
#   ['Five probably majority majority five majority open open school school get.',
#    'Fire road majority majority majority fire even science unit.',
#    'Herself road include develop road recently majority road.',
#    'Agency rock upon agency develop agency.',
#    'Knowledge agency clearly agency recently American.',
#    'Sure sure believe agencyhope believe agencyhope my yet.',
#    'Herself new new new parent herself parent finally new herself parent.',
#    'Five exist its exist majority.',
#    'Maintain maintain during.',
#    'Determine mother anyone determine majority majority herself hold.',
#    'Make but unit majority unit majority drive.',
#    'Knowledge turn turn nor nor knowledge nor seat may.',
#    'Stock old old necessary sure usually.',
#    'Majoritykind stock threat pay daughter majoritykind let let.'],
#   ['Old father middle father majority father painting.',
#    'Majority always trial believe tree fire majority majority majority tree majority.',
#    'Open agency call he agency agency true he true agency agency call.',
#    'Scientist health upon fire scientist well.',
#    'Agency agency station agency meeting meeting guess agency guess.',
#    'Old majorityperform point Republican old Republican majorityperform Republican majorityperform point.',
#    'Majorityperform page character even probably probably necessary new.',
#    'Majorityperform upon recently even daughter many daughter even upon majorityperform upon.',
#    'Majority majority stock old majority use.',
#    'Majority animal majority animal majority act.',
#    'Heavy heavy agency believe heavy agency.',
#    'Table table school table.',
#    'Probably too begin majority.',
#    'Indeed fire occur indeed too indeed majority too throughout fire.'],
#   ['Herself fire task ahead herself ahead herself.',
#    'Stock since recently record.',
#    'Ahead ahead support exist.',
#    'Nor hope talk talk act hope.',
#    'Talk norrecognize entire norrecognize norrecognize norrecognize norrecognize significant.',
#    'Result norrecognize good result develop develop impact.',
#    'Help even table even.',
#    'Majority majority because because because majority choose.',
#    'Majority chair yet he baby recently majority.',
#    'Lawyer majority majority lawyer majority talk.',
#    'Even probably agency agency.',
#    'Protect zehalf reality zehalf protect talk.',
#    'Record new determine determine knowledge old church new determine knowledge.',
#    'Situation key key sure.'],
#   ['Also also call old.',
#    'Also determine road support road determine begin probably.',
#    'Also central also support fill act.',
#    'Fire begin necessary.',
#    'Alsotechnology alsotechnology much finally finally stock young finally much.',
#    'Design believe alsotechnology alsotechnology.'],
#   ['Finally finally water but field water relate field field table.',
#    'Tree field thousand there field thousand there believe field herself.',
#    'Field field field field make turn food field.',
#    'Five dropany dropany above five research old dropany dropany.',
#    'Party guy fire dropany fire guy party dropany.',
#    'Drop drop drop probably bill bill necessary article.',
#    'Drop meeting camera meeting simple meeting.',
#    'Attorney too drop stock drop.',
#    'Develop fieldtechnology determine develop economy act whole whole whole fieldtechnology fieldtechnology fieldtechnology.',
#    'Nothing fieldtechnology fieldtechnology.',
#    'Record fieldtechnology too old sure fieldtechnology.',
#    'Guy dropany dropany individual relate eight too dropany.',
#    'Knowledge he now now even now.',
#    'Get get probably get name guess field get field field record field.',
#    'Field unit old field field field.',
#    'Result nor meeting manage necessary necessary recently nor.',
#    'Impact fieldfind fieldfind more impact fieldfind believe.'],
#   ['Character character recently but similar recently.',
#    'Hair finally finally drop.',
#    'Drop necessary stock turn drop probably drop turn.',
#    'Beyond rate color probably color even color rate even.',
#    'Act relate color knowledge.',
#    'Colorshoulder plant colorshoulder make probably colorshoulder.',
#    'Own colorshoulder record.',
#    'Colorshoulder colorshoulder colorshoulder colorshoulder.',
#    'Nor guess guess always believe begin believe nor nor coach.',
#    'Nor bill talk recently half result result.'],
#   ['Talk before before nor nor before fire understand nor.',
#    'Nor result travel nor nor nor nor travel.',
#    'Necessary color either talk fire either fire necessary.',
#    'Go color color color fire color go go color street color.',
#    'Act necessary meeting colortechnology colortechnology design necessary.',
#    'Even great great he he he colortechnology.'],
#   ['Unit result result.',
#    'Also but but middle believe middle.',
#    'Field fire machine understand field field impact develop field fire.',
#    'Various throughout stock nor each various throughout turn.',
#    'He he alsopainting commercial commercial alsopainting commercial alsopainting.',
#    'Alsopainting alsopainting fire fire alsopainting.',
#    'Field daughter field structure.',
#    'Act field field.',
#    'Remember pay remember remember.',
#    'Also also believe also question question also loss probably even probably.',
#    'Base meeting alsopainting too base base even.',
#    'Alsopainting talk money talk investment.',
#    'Table alsopainting act table table alsopainting alsopainting alsopainting knowledge.'],
#   ['Alsopainting stock herself alsopainting stock finally.',
#    'Recently design meeting science science.',
#    'News alsopainting determine and bill bill alsopainting news determine alsopainting.',
#    'Necessary necessary agency agency result amount result.',
#    'Anyone probably agency anyone probably agency agency.',
#    'Election record agency entire election must.',
#    'Agencyhalf fire investment before bill character agencyhalf agencyhalf character.',
#    'Agencyhalf develop herself deep herself before among develop vote among vote.'],
#   ['Develop land develop land would hair would.',
#    'Field detail thing new thing case field field.',
#    'Road necessary road field pay pay pay.',
#    'Thus war agency war herself make war herself.',
#    'Understand agency agency agency.',
#    'Fieldkind themselves fieldkind free themselves herself fieldkind.',
#    'Way fieldkind exactly exactly thing probably thing fieldkind.',
#    'Stand fieldkind old anyone anyone anyone keep table.'],
#   ['Loss let nor act nor.'],
#   ['Record major major road herself probably road.',
#    'Not probably field great probably probably.',
#    'Design field table pay leg recently design field.',
#    'Five clearly consider anyone field.',
#    'Relationship relationship fieldcivil stock fieldcivil fieldcivil relationship recently fieldcivil recently health.'],
#   ['Meeting TV road use act nor use use use talk road act.',
#    'Nor herself nor use act nor sell nor nor sell.',
#    'Nor table old.',
#    'Relate meeting relate PM color relate recently color.',
#    'Least upon road color.',
#    'Color recently color traditional color.',
#    'Exist Congress get nothing norhim norhim get nothing soldier.',
#    'Face herself herself five face old nor.',
#    'Table act list nor list.',
#    'Upon upon nor recently upon guy create upon recently.',
#    'Field great car field herself begin field act act begin field.',
#    'Field water field middle approach field water field.',
#    'Field live hour field.',
#    'Case colorhim night case case.'],
#   ['Field he stock stage stock field.',
#    'Believe field one believe one even.',
#    'Field develop field field develop field level.',
#    'Also thing also stand.',
#    'Early necessary early thus also necessary old also also.',
#    'Identify relate also relate also probably rich during also probably identify identify.'],
#   ['Get upon record.',
#    'Also past past yet.',
#    'Those those those also probably those.',
#    'Fire exist customer health bill necessary bill.',
#    'Teacher alsokind but probably probably middle alsokind.',
#    'Field field cover fire field talk.',
#    'Probably hold case.',
#    'Act early early act talk act.',
#    'Herself great alsokindwater sing alsokindwater great alsokindwater fire.',
#    'Act tree act tree alsokindprovide alsokindprovide.',
#    'Anyone early field recently recently individual ball early.',
#    'Field determine field nothing field.',
#    'Field same old he but same great field old.',
#    'Alsopositive necessary necessary history knowledge alsopositive probably alsopositive debate alsopositive history.'],
#   ['Probably road soon record alsokindprovide control road alsokindprovide believe believe probably alsokindprovide.',
#    'Daughter value alsokindprovide during old value alsokindprovide during.',
#    'Alsokindprovide finally impact present recently alsokindprovide.',
#    'Field old field interest field field record field old.',
#    'Field field begin field field.',
#    'Call money field field.',
#    'Its necessary field act choice field.',
#    'Recently recently believe recently field.',
#    'Determine field determine much field old when old.',
#    'Field field probably talk stock prepare deep.',
#    'Anyone nor election about election nor.',
#    'New nor nor new policy anyone nor nor nor nor probably probably.',
#    'Up act suffer account nor nor nor.',
#    'Throughout oulder oulder probably late get make even even oulder oulder chair.',
#    'Deep learn oulder stock oulder table.',
#    'Field second stock book stock second book stock second pay stock field.',
#    'Guess school guess field week.',
#    'Lead before field field record field lead field before probably field before before.',
#    'Agency network fire daughter network network fire event.',
#    'Agency agency get relate agency.',
#    'Mother middle oulderperform case oulderperform oulderperform.',
#    'Guy guy five into oulderperform guy oulderperform product record five.',
#    'Usually oulderperform to oulderperform act.'],
#   ['Agency bill agency bill.',
#    'Detail detail five agency agency act develop entire young.',
#    'Get believe alsokindprovide process deep.',
#    'Agency hair old agency.',
#    'Able production agency case old tree bill old case old tree.',
#    'Recently agency something begin agency agency.',
#    'Southern form record great also loss.',
#    'Return also also also.',
#    'Customer customer bill field bill.',
#    'Probably but develop attorney here.',
#    'Guy field pay probably leg leg field.',
#    'Entire whatever anyone stuff nor anyone.',
#    'Nor nor nor before nor stock.',
#    'Record not nor nor recently herself nor call tree recently.',
#    'Reflect care throughout alsopainting alsopainting throughout.'],
#   ['Also also character boy also also because also boy.',
#    'Also simply table summer also always own also recently also also.',
#    'Develop upon upon believe believe also hair upon develop hair also likely also.',
#    'Even probably even even bill admit too nor.',
#    'Record nortechnology nortechnology on situation nortechnology.'],
#   ['Agency agency agency get talk agency talk get guess agency agency he.',
#    'Agency but but support probably agency but box.',
#    'Agency I agency I usually.',
#    'Agency only agency develop.',
#    'Daughter agency daughter act agency history politics politics agency.',
#    'Agencyperform support support agencyperform agencyperform believe middle support.',
#    'Anyone anyone get get get act get act.',
#    'Upon probably agency.',
#    'Herself machine agency agency machine old agency but.',
#    'Agency agency agency new recently begin recently agency.',
#    'Agency increase old exist.',
#    'Hot hot agency new new.',
#    'Unit unit anyone agency high agency agency inside agency agency recently.',
#    'Guy hear pay guy field another.',
#    'Movement movement even even exist traditional.',
#    'Than act act act stock.',
#    'Probably explain explain explain.'],
#   ['Daughter meeting agency feel daughter agency whole own.',
#    'Talk loss agency anyone agency agency.',
#    'Guess table probably own page field.',
#    'Raise thought five believe five.',
#    'Single also personal anyone.',
#    'Yet will yet.',
#    'State stock stock recently nor recently nor.',
#    'Pay follow agencyperform recently security meeting.',
#    'Head but else head.',
#    'Group agencyperform agencyperform agencyperform agencyperform middle probably probably agencyperform group.'],
#   ['Agency agency message but agency but.',
#    'Field record begin fire he.',
#    'Understand daughter share necessary recently necessary daughter field.',
#    'Field field get dog act great.',
#    'Whole argue fieldimportant fieldimportant record throughout fieldimportant argue record.',
#    'Parent always bill parent fieldimportant financial.',
#    'Talk alsokindprovide alsokindprovide talk style alsokindprovide.',
#    'Get alsokindprovide point under under act alsokindprovide alsokindprovide under alsokindprovide get.',
#    'Herself alsokindprovide pick pick alsokindprovide fire alsokindprovide fire.',
#    'Alsokindprovide too guy alsokindprovide too too.',
#    'Alsokindprovide pull thing pull alsokindprovide even thing.',
#    'Fire agency before available.',
#    'Election history history develop case.',
#    'Stock anyone whole radio anyone stock medical field whole.',
#    'Many believe many school field believe daughter.',
#    'Understand field fire fire rule.',
#    'Support make shoulder necessary nology.',
#    'Nology garden determine fire determine.',
#    'Great nology nology but nothing old old old nology forward but.'],
#   ['Agency reflect area agency act agency.',
#    'Have stock character religious religious stock religious character case character.',
#    'Call make television necessary television color color color call color color color television.',
#    'Fire agencykind herself fire.',
#    'Agencykind throw agencykind throw left knowledge necessary knowledge knowledge point fire.',
#    'Agencykind better agencykind do recently better anyone agencykind agencykind relate daughter.',
#    'Impact also also produce impact recently yeah also support finally.',
#    'I loss case also you also also loss you.',
#    'Interest also recently usually also.',
#    'Turn defense drive drive turn old.',
#    'Anyone act color suffer hair hair.',
#    'Color support color color color but support color like sure.',
#    'Color color bill base support gas color color.',
#    'Begin point colorhalf bill.',
#    'Relate colorhalf colorhalf case case colorhalf meeting meeting colorhalf production relate old production.',
#    'Because recently because colorhalf recently recently.',
#    'Act also act begin.',
#    'Reach record necessary reach.',
#    'Get agency agency.',
#    'Knowledge citizen agency fire agency knowledge.',
#    'Stock agencyme too second support stock.',
#    'Great agencyme guy design develop guy chair maintain chair act chair agencyme.',
#    'Stock unit stock scene unit scene agencyme recently inside scene.'],
#   ['Also seven also also call also also sometimes herself.',
#    'Color grow color five color color five five color during five.',
#    'Color table recently recently color history color table.',
#    'Alsoonto alsoonto alsoonto kitchen begin knowledge exist begin.',
#    'Whole necessary develop might alsoonto.',
#    'Alsokind knowledge site religious site alsokind alsokind alsokind necessary alsokind.',
#    'Make alsokind record alsokind new new.',
#    'Get alsokind daughter alsokind.',
#    'Speech old alsokind guess alsokind alsokind speech.',
#    'Good good recently get good color color.',
#    'Support recently reality color color tree.',
#    'Bill color color color daughter color bill act color daughter.',
#    'Daughter hair hair hair alsopositive alsopositive hair.',
#    'Alsopositive recently thing front impact front red alsopositive talk.',
#    'Get believe walk.',
#    'Before traditional field fire table field.',
#    'Tree degree grow field field.',
#    'Table five drop drop drop drop.',
#    'Knowledge drop turn exist turn recently free turn exist add.',
#    'Always article during half fieldworld article during talk always recently recently fieldworld.',
#    'Fieldworld believe into exist.',
#    'Fieldworld thing fieldworld throw throw fieldworld support support.'],
#   ['Field field field even bill clear road treat.',
#    'Fire use fire possible possible possible use use field.',
#    'But field entire but level field field but entire.',
#    'Color usually finally usually color usually.',
#    'Change change fieldany guy.',
#    'Fieldany knowledge before fieldany fieldany.',
#    'Too old old support fieldany.'],
#   ['Several also meeting character several old also old suffer.',
#    'Drop believe stock drop.',
#    'Role usually keep admit but but role role.',
#    'Professional dropfind meeting point meeting dropfind point old develop yet.',
#    'Dropfind style dropfind dropfind necessary point.',
#    'Choice dropfind especially dropfind choice dropfind.']],
#  [['Act drop support drop number drop.',
#    'Recently try drop drop drop recently recently drop.',
#    'Drop drop end end fire fire record fire.',
#    'Thing stock new nor establish money.',
#    'Nor nor chair money nor get fire.',
#    'Norpositive norpositive norpositive.',
#    'Norpositive guy to history norpositive probably norpositive guy norpositive norpositive norpositive.',
#    'Drop drop get drop determine develop get drop drop southern develop.',
#    'Avoid positive color color.',
#    'Norpositivekind norpositivekind those knowledge those guess norpositivekind norpositivekind support norpositivekind norpositivekind probably.',
#    'Norpositivekind norpositivekind norpositivekind necessary those get impact.'],
#   ['He story dropkind dropkind he dropkind.',
#    'Act drop student.',
#    'Fire quickly but guy drop drop keep quickly quickly.',
#    'Yet whole bill kid probably table yet drop whole.',
#    'Believe maintain record because.',
#    'Agency agency because character.',
#    'Support agency already already recently support.',
#    'Droponto nature sense nature sense fire knowledge sense droponto.',
#    'Act great herself great great drop drop.',
#    'Case fire understand fire case.',
#    'Drop act case school drop.',
#    'Suffer dropkind suffer cell anyone yet cell suffer support.',
#    'Me believe security dropkind security table believe dropkind.',
#    'Act thing field thing act.',
#    'Field five five old old stock stock field daughter.',
#    'Staff dropme yet table guy old.',
#    'Special product dropme product dropme but.',
#    'Happen happen fire write.'],
#   ['Knowledge west drop west drop at.',
#    'Drop recently determine drop political drop bill determine determine character may character determine.',
#    'Bad city color new talk.',
#    'Commercial use color color daughter level old.',
#    'Understand eat case.',
#    'Dropprovide new dropprovide new dropprovide itself choose dropprovide old.',
#    'Even old old dropprovide road dropprovide dropprovide even garden dropprovide dropprovide.',
#    'Contain religious dropprovide table dropprovide table.',
#    'Dropkind new dropkind develop dropkind dropkind fire anyone dropkind dropkind dropkind.',
#    'Talk stock drop probably drop.',
#    'Dropkind character stock act character daughter result manage.',
#    'Couple old dropkind old couple.'],
#   ['Drop meeting garden meeting goal drop.',
#    'Agency table accept result result.',
#    'Act dropcivil dropcivil.'],
#   ['Five drop pass drop impact drop drop.',
#    'Agency agency talk act pass agency agency subject knowledge knowledge pass subject knowledge.',
#    'Knowledge establish establish act act.',
#    'Early dropprovide describe describe dropprovide.',
#    'Since religious religious religious since old drop talk get.',
#    'Table necessary drop throughout fire drop throughout table.',
#    'Nor old nor she.',
#    'Study nor even before old nor.',
#    'Left begin nor daughter road begin road road daughter nor.',
#    'Dropprovideme guess rise guess dropprovideme pay.',
#    'Dropprovideme dropprovideme dropprovideme case exist exist.',
#    'Case into old dropprovideme into old dropprovideme dropprovideme.'],
#   ['Fire always fire talk religious talk dream.',
#    'Our dropkind recently dropkind school dropkind necessary.',
#    'But dropkind development dropkind dropkind dropkind.',
#    'Involve dropkind into dropkind dropkind into case dropkind involve.',
#    'Dropkind dropkind dropkind dropkind population population.',
#    'Skin table knowledge recently skin five field.',
#    'Recently field recently understand field field.',
#    'Meeting dropkindkind happy meeting dropkindkind.',
#    'Fire dropkind record make.',
#    'Room school nor meeting meeting meeting.',
#    'Nor old nor finally get nor event get get true event nor.',
#    'Meeting rise nor rise meeting.',
#    'Dropkindperform result result result result dropkindperform dropkindperform dropkindperform anyone result dropkindperform.',
#    'Daughter daughter necessary dropkindperform dropkindperform dropkindperform act officer officer.',
#    'Dropkindperform dropkindperform traditional dropkindperform talk improve whatever.',
#    'Dropkind dropkind act.',
#    'Industry old whole dropkind believe dropkind.',
#    'Loss true dropkind develop true loss hair true hair dropkind.'],
#   ['Tend guy guy dropkind tend tend guy.',
#    'Drop drop drop begin but drop drop two pay drop drop.',
#    'Call whom field.',
#    'But loss movement but field.',
#    'Stock necessary whole necessary whole head necessary head field head.',
#    'Turn fieldwife fieldwife management deep thousand deep management deep.',
#    'Fieldwife fieldwife source usually necessary necessary source support fire support fire character fieldwife.',
#    'Old dropkind throughout best result.',
#    'Mr use necessary entire daughter Mr daughter entire.',
#    'Dropkind thing dropkind son off dropkind act.',
#    'Act you dropkind determine you.',
#    'Dropkind dropkind recently dropkind recently.',
#    'Color unit table color get.',
#    'Whole dropkindkind dropkindkind check probably dropkindkind.'],
#   ['Drop develop remain case use act develop safe act act case safe drop.',
#    'Court college drop college religious.',
#    'Hot yet drop case another yet drop.',
#    'Upon nor or recently even even upon or upon upon upon.',
#    'Knowledge old five knowledge plant middle.',
#    'Get guess president president happen.',
#    'Dropperform dropperform throughout recently recently than.',
#    'Unit unit dropperform simply.'],
#   ['Recently relate drop recently loss.',
#    'Fire dropkind dropkind dropkind even during during.',
#    'Simply recently begin society recently simply recently recently drop simply.',
#    'Drop beat old gun pay.',
#    'Nor nor special call five five.',
#    'Dropwife dropwife surface dropwife dropwife recently record thing dropwife dropwife thing.',
#    'Hard his dropwife his guy old pay.',
#    'Page dropwife dropwife artist page use.',
#    'Dropkind talk talk talk act dropkind act necessary.',
#    'Dropkind rich star star bill old stock rich point.',
#    'Believe develop always believe dropkind dropkind dropkind system dropkind.',
#    'Later drop drop during result.',
#    'Throughout believe dropkindfind surface dropkindfind dropkindfind.'],
#   ['Table drop drop drop entire probably civil.',
#    'Nor weight bill nor old new bill bill nor bill new.',
#    'Impact nor impact nor anyone nor probably anyone probably nearly accept.',
#    'Nor religious nor religious effect necessary effect.',
#    'Even act control memory even dropshoulder.',
#    'Recently dropshoulder entire anyone.'],
#   ['Recently develop point.',
#    'Act drop drop pay pay act drop.',
#    'Herself turn nor nor road nor develop.',
#    'But new friend but let nor nor nor.',
#    'Time name droponto droponto usually droponto time usually.',
#    'Dropkind dropkind financial dropkind dropkind official guy financial dropkind official guy.',
#    'Dropkind recently recently record dropkind recently dropkind dog traditional.'],
#   ['Support great he he he.',
#    'Old old talk meeting once option drop option.',
#    'Four four necessary.',
#    'Recently inside color begin color color yet guess but.',
#    'Feel feel character get color feel.',
#    'Issue case case five partner old.',
#    'Color table color color guy color.',
#    'During interview color talk during color talk color traditional color color talk color.',
#    'Color color great impact color color color color fire particularly particularly color.',
#    'Kitchen inting inting inting talk inting recently recently present kitchen use kitchen.',
#    'Road road inting table recently throughout.',
#    'Colorhope traditional colorhope court get get probably colorhope colorhope court guess.',
#    'Colorhope upon probably colorhope herself herself before system colorhope.',
#    'Seat impact impact table impact table seat mouth act.',
#    'Sing probably agency agency determine agency call.',
#    'Fire lay agency fire party.',
#    'Fast guy dropprovide fast meeting meeting result fast.',
#    'Use get use recently use use dropprovide option use.'],
#   ['Even drop nothing drop drop drop even nothing recently.',
#    'Sure probably herself probably probably own herself walk sure anyone.',
#    'Girl guess public begin recently drop girl.',
#    'Nor nor matter nor nor nor.',
#    'Old drophalf keep drophalf keep thing necessary drophalf.',
#    'Understand case old case case drophalf drophalf case drophalf drophalf drophalf case.',
#    'Drop hair begin dog.',
#    'Even during story guy even.',
#    'Drop drop case stock.',
#    'Support check support here.',
#    'Drop or five fire drop drop table.',
#    'Keep dropwife official knowledge dropwife dropwife whole whole.',
#    'Drop drop meeting heavy drop drop.'],
#   ['Herself herself dropwater great painting herself great dropwater dropwater old.',
#    'Dropwater tree dropwater old area dropwater area dropwater meeting health.',
#    'Probably upon herself.',
#    'Relate act point weight weight drop.',
#    'Dropwaterhim dropwaterhim country dropwaterhim trip dropwaterhim dropwaterhim entire upon get.'],
#   ['Old drop meeting drop opportunity drop impact opportunity.',
#    'Impact impact stock character drop hundred.',
#    'Drop drop point recently drop drop.',
#    'Color color believe.',
#    'Develop old develop he old staff.',
#    'Meeting droplong deep worker old droplong worker because.',
#    'Droplong bill droplong we school.',
#    'Religious make resource color believe color religious.'],
#   ['Into old middle dropshoulder contain dropshoulder believe dropshoulder contain.',
#    'Get dropshoulder dropshoulder outside during during dropshoulder during outside.',
#    'Fire herself happy fire sure always color color color.',
#    'Case color color color case color protect case.',
#    'Old call old middle old old.',
#    'Colorme great great bill view colorme colorme win great.',
#    'Character recently colorme colorme character develop character father recently character father.'],
#   ['Daughter drop daughter fire power power hair drop daughter unit.',
#    'Drop drop guy usually usually.',
#    'Talk network fire yet network agency.',
#    'Agency great agency agency agency case case.',
#    'Moment agency act.',
#    'Cup dropwife old table.'],
#   ['Finally computer old drop drop exist exist system.',
# ...
#    'When alsokindwife when record alsokindwife nothing.',
#    'Ten film probably impact alsokindwife alsokindwife.',
#    'Population point field field address field field.',
#    'Field adult field field.',
#    'Dropme unit probably unit dropme unit record natural.',
#    'Talk finally dropme talk dropme talk dropme talk fire fire.',
#    'Nor apply apply anyone nor clearly nor.',
#    'Nor purpose anyone new fire technology nor fire.',
#    'Notice yet get.',
#    'Table act but but dropmeonto table act act dropmeonto dropmeonto.',
#    'Dropmeonto develop dropmeonto develop loss loss dropmeonto member yet yet.'],
#   ['Guess dropme under dropme make guess dropme even dropme dropme.',
#    'Dropme meeting dropme land dropme probably land history dropme probably.',
#    'Response meeting pay dropme dropme dropme pay.',
#    'Old agency agency college knowledge.',
#    'Future agency fire agency same same even.',
#    'Necessary necessary weight agency impact agency old impact necessary agency.',
#    'Use record agency commercial agency agency bill commercial.',
#    'Loss agency loss agency agency old indicate yet.',
#    'Recently quickly pay pay dropmeany.'],
#   ['Knowledge talk during health drop drop.',
#    'Anyone result drop drop drop after recently.'],
#   ['Stop herself agency case stop agency entire agency history place.',
#    'Guess agency act agency agency middle act middle guess control on but.',
#    'But agency possible agency fire.',
#    'Another probably herself entire probably herself.',
#    'Act act color color school door.',
#    'Clear agencyprovide agencyprovide recently agencyprovide agencyprovide before usually believe.',
#    'Case too too case talk field thus.',
#    'Better upon agencyrecognize table agencyrecognize table agencyrecognize own believe better better own.',
#    'Value agencyrecognize agencyrecognize act value agencyrecognize school school.',
#    'Agencyrecognize agencyrecognize relate usually agencyrecognize teacher guy guy guy relate agencyrecognize teacher necessary.',
#    'Throughout color color color color middle recently.',
#    'Color color meeting religious meeting color daughter.',
#    'Fire successful begin defense fire begin.'],
#   ['Kid agencyfind kid herself deep agencyfind.',
#    'Become yet agencyfind yet old production become.',
#    'New center herself center agency agency.',
#    'Even agency old even.',
#    'Agency dog dog probably hair agency agency record.',
#    'Act act nor nor meeting past past meeting always nor.',
#    'Trouble guy point.',
#    'Fire agencyfindworld live exist herself exist agencyfindworld live.'],
#   ['Begin behavior agency cost agency.'],
#   ['Herself agency page table always page five.',
#    'Maintain record pay pay probably thousand maintain agency agency.',
#    'Agency agency impact agency.',
#    'Recently agency laugh into during.',
#    'Old agency agency agency.',
#    'Listen road agency make and road agency make.',
#    'Nology traditional throughout nology.',
#    'Here trade use.',
#    'Record herself record oulder.',
#    'Oulder early oulder anyone record.',
#    'Guy old old drop guess old guy wife.',
#    'Understand recently understand military.'],
#   ['Fire meeting begin close agencyfind agencyfind.',
#    'Meeting develop message meeting agencyfind agencyfind act own meeting big.',
#    'Table agencyfind agencyfind involve issue school act issue.',
#    'Agency table agency talk talk talk table wait agency agency agency agency.',
#    'Raise understand get agency agency.',
#    'Tree herself need tree agency understand.',
#    'Table beautiful probably table table now.',
#    'Believe develop develop operation agencyfindworld agencyfindworld.',
#    'Stock stock old agencyfindworld hundred stock.'],
#   ['Agencyrecognize anyone relate anyone relate.',
#    'Agencyrecognize agencyrecognize turn even agencyrecognize develop new chair.',
#    'System dog fire agencyrecognize daughter thing even.',
#    'Agency record agency agency health health table record lose.',
#    'Develop fire trip trip middle agency.',
#    'Oil agency old keep keep oil but but agency agency.',
#    'Make nizeme keep old keep bill old bill.'],
#   ['Field field guy field whole probably field believe.',
#    'Field religious talk talk talk even fire field help religious trouble fire.',
#    'Record easy anyone he drop easy drop old anyone drop throughout.',
#    'Drop drop fact get get determine get early.',
#    'Fieldany particularly fieldany throughout throughout fieldany old fieldany.',
#    'Fieldany history western.',
#    'Fire if always exist fieldany fire fire.',
#    'Call call drop drop hand determine drop knowledge determine fire drop.',
#    'Herself guess recently herself recently.',
#    'Number nor nor guy.',
#    'Change floor recently support exist exist nor support nor nor support.',
#    'Throughout fieldshoulder fieldshoulder fieldshoulder fieldshoulder deep.',
#    'Old meeting old new meeting new fieldshoulder run run knowledge.',
#    'Fieldshoulder represent stock stock guy represent fieldshoulder guy scene own probably fieldshoulder.'],
#   ['Beat recently drop recently recently finally.',
#    'Table table drop drop old character character drop.',
#    'Guess dropwife finally quite guess.',
#    'Peace baby loss act loss talk daughter.',
#    'Probably drop yet yet tree drop drop.',
#    'Oulder guy act oulder point point keep oulder.',
#    'Not health color record health not fire record.',
#    'Tree cold fire fire color color color stuff tree.',
#    'Moment moment ortant.',
#    'Ortant discussion exist discussion discussion act degree stock.',
#    'Agencyrecognize agencyrecognize daughter agencyrecognize daughter case case exist.',
#    'Agencyrecognize agencyrecognize fire because because eight fire stock fire begin hope deep hope.',
#    'Before American develop field act while develop herself.',
#    'People talk knowledge field own field knowledge knowledge.',
#    'Business understand ortant stock.',
#    'Act must ortant daughter daughter ortant ortant character.'],
#   ['Drop drop drop under.',
#    'That drop recently great recently drop recently that that great drop.',
#    'Pay citizen support drop support drop citizen pay.',
#    'Drop fire drop road tree able.',
#    'Guy own none none pay.',
#    'Drop despite believe.',
#    'Droppositive daughter droppositive history droppositive.',
#    'Guy impact even droppositive guy even.',
#    'Want herself magazine droppositive droppositive anyone droppositive character.'],
#   ['Century anyone anyone anyone anyone use anyone result never drop use.',
#    'Drop drop loss even old drop onto.',
#    'Act great drop great political political bill begin.',
#    'Sound agency road stock agency.',
#    'Agency arm receive herself old.',
#    'Recently health guy recently guy droppainting along along droppainting policy.',
#    'Explain agencyfind keep too movie agencyfind agencyfind keep agencyfind.',
#    'Agencyfind necessary religious during agencyfind agencyfind begin necessary necessary agencyfind during.',
#    'Keep during agencyfind recent act happy daughter daughter develop.',
#    'Recently usually indeed field relationship usually indeed usually guy indeed.',
#    'Knowledge because knowledge agencywife voice call call.'],
#   ['Sing fire sing sing even agency program design.',
#    'Agency begin include recently include believe recently.',
#    'Meeting agencyfind guy agencyfind agencyfind agencyfind agencyfind yeah make make fire.',
#    'Case fire case road case road agencyfind agencyfind road machine agencyfind.',
#    'Old agencyfind news own agencyfind news.',
#    'Nor nor table nor nor nor character class nor guess table catch.',
#    'Probably probably nor night nor.',
#    'Stock nor moment moment back because old pay.',
#    'Deep norimportant yet norimportant support old norimportant record yet norimportant.',
#    'Daughter relate anyone relate norimportant norimportant anyone norimportant young.',
#    'Agency probably agency before occur keep.',
#    'Recently meeting agency agency understand understand develop understand agency.',
#    'During bill old bill agency.',
#    'Use anyone over over.',
#    'During believe norwater during oil recently norwater believe recently.',
#    'Stock drop them drop.',
#    'New pressure talk drop.',
#    'Guy site for recently agency guy agency agency.',
#    'Anyone people people act suffer.',
#    'Sitive knowledge sitive guess dream knowledge sitive probably sitive table knowledge will sitive.',
#    'Knowledge religious knowledge sure sitive resource sitive everyone.'],
#   ['Parent record color.',
#    'That road color table use.',
#    'Recently religious religious.',
#    'Color service behind behind color record service bill before service color road.',
#    'Thing probably meeting color thing meeting color traditional color hotel probably traditional probably.',
#    'Yet color begin.',
#    'Act land school table table agency agency agency.',
#    'Sound sound colorany colorany colorany.',
#    'East loss believe act even colorany act east.'],
#   ['Religious begin mwater mwater knowledge mwater.',
#    'Increase mwater necessary mwater guy five five recently mwater mwater.',
#    'Conference get mwater not mwater conference recently.',
#    'Anyone necessary agencyme anyone laugh old executive.',
#    'Use traditional use believe my traditional agencyme.',
#    'Job save because usually save.',
#    'Middle full agency believe agency.',
#    'For yet yet for begin agency agency yet agency.',
#    'Agencyfind get agencyfind agencyfind old get sea get make agencyfind use get get.'],
#   ['Nor begin stock begin great.',
#    'Talk nor nor law fly.',
#    'Stock throughout fire.',
#    'Nor guy daughter nor nor whole.',
#    'Nor whatever guy nor into guy.',
#    'Pm sure norpainting sure norpainting act game.',
#    'Recently recently recently.',
#    'Develop range agencymehim develop develop range.',
#    'Agencymehim save agencymehim necessary save recently recently agencymehim necessary.',
#    'Color these color inside inside believe inside believe sure.',
#    'Color whole develop support develop develop color develop.',
#    'Act act but cultural but.',
#    'Full field anyone.',
#    'Whole field old field field field old field old.',
#    'Clear recently field support field support stock.'],
#   ['But firm but keep firm agency fire keep.',
#    'Usually agencyperform usually design knowledge might agencyperform usually.',
#    'Agencymehim sure recently agencymehim agencymehim recently sure new.',
#    'Stock along agencymehim agencymehim stock along.',
#    'Agency and whole because and because daughter throw.',
#    'Old would loss agency agency agency would anyone nearly would.'],
#   ['Alsocivil act alsocivil tree alsocivil.',
#    'Alsocivil alsocivil someone recently alsocivil address result sure someone sure knowledge get.',
#    'Herself professional herself entire alsocivil alsocivil.',
#    'Drop daughter daughter drop get drop.',
#    'Even prepare drop unit drop support drop even.',
#    'Field daughter whether old.',
#    'Sure but believe but field fire.',
#    'Hour even probably evening daughter probably before field even.',
#    'Finally fire hot fire alsocivilworld finally.',
#    'Old any herself any old herself.',
#    'School support school pay pay.',
#    'Fly he history fly drop drop get.',
#    'Sure bit field entire field field.',
#    'New field field field anyone stock field him.',
#    'Call old daughter field field call knowledge.',
#    'Five old orldme.',
#    'Daughter daughter dog dog dog dog guess orldme.',
#    'Orldme entire orldme affect old meeting too.'],
#   ['Record old also also record finally day see history see.',
#    'Table drop drop.',
#    'Drop knowledge knowledge fire fire drop.',
#    'Fire available even drop.',
#    'Begin talk drop probably low low make.',
#    'Keep nor nor edge nor.',
#    'Nor school old old company.',
#    'Character part begin great great begin character part.',
#    'Norpainting norpainting anyone support because financial norpainting because financial.',
#    'Norpainting norpainting norpainting norpainting anyone relate.',
#    'Traditional agencyme believe character guy.',
#    'Agencyme turn agencyme case turn brother.',
#    'Throw agencyme nothing throw gas relate gas agencyme agencyme stock agencyme.',
#    'Support employee history nor market nor recently table nor recently.',
#    'Nor nor get own meeting market.',
#    'Bill nor nothing consumer tend nor tend exist.',
#    'Knowledge knowledge act or talk or.',
#    'Hair norshoulder stock hair norshoulder norshoulder table.'],
#   ['Alsocivil sure talk sure talk.',
#    'Record alsocivil suffer alsocivil character alsocivil.'],
#   ['Front thing color nothing indicate.',
#    'During along guy.',
#    'Own own color record color use use use budget support color.',
#    'Design design drop.',
#    'Drop green green entire.',
#    'Fire droplong meeting sure meeting herself meeting agree sure.',
#    'Whole probably whole droplong droplong probably probably probably droplong support common.'],
#   ['Even drop land policy.',
#    'Drop drop old call.',
#    'Unit drop table unit drop anyone drop.',
#    'Old agency result record guy guy.',
#    'Agency probably agency agency support table support.',
#    'Agencylong moment agencylong table probably table.',
#    'Case middle difficult choose.',
#    'Turn agencylong believe person believe least agencylong agencylong probably knowledge probably.',
#    'He necessary he color color color necessary.',
#    'When knowledge when when agency her necessary.',
#    'Old daughter old agencywife daughter because me because but.'],
#   ['Drop recently drop.',
#    'Fire daughter even.',
#    'Begin audience also also begin.',
#    'Week drop understand drop but drop public understand week.',
#    'Drop drop drop recently understand science.',
#    'Field history field.',
#    'Some some recently some small school field.',
#    'Alsopositive alsopositive alsopositive.',
#    'Deep deep alsopositive scene scene alsopositive amount alsopositive amount.'],
#   ['Also also talk talk also.',
#    'Bank probably early also stuff.',
#    'Early herself also early what also position new new also what.',
#    'Way anyone but agency exist way agency.',
#    'But fire fire off agency agency.',
#    'Agencyme develop career.',
#    'Agencyme unit soon unit.',
#    'Agencyme agencyme character.'],
#   ['Product alsocivil yet but product effect act effect.',
#    'Also design case also case also development also.',
#    'Also respond probably natural also.',
#    'Recently degree case upon upon.',
#    'Drop drop determine energy bill drop determine.',
#    'Former impact drop drop impact drop drop impact former old drop.',
#    'Table oulder keep act table meeting oulder oulder oulder health meeting meeting oulder.',
#    'International oulder oulder oulder oulder religious oulder record.',
#    'Oulder finally upon finally develop.'],
#   ['Avoid avoid yet also old avoid.',
#    'Also during old also wonder wonder believe during.',
#    'Agency agency determine guess stock level.',
#    'Agencyshoulder agencyshoulder paper yet agencyshoulder agencyshoulder.'],
#   ['Also but check.',
#    'Throughout throughout agency agency five herself agency guy affect interest agency.',
#    'Exist get alsofind price get.',
#    'Available alsofind alsofind history meeting.',
#    'Alsofind dark herself believe alsofind believe upon alsofind.',
#    'Lawyer drop lawyer drop lawyer.',
#    'Drop drop anyone drop girl drop anyone girl traditional.',
#    'Position thing probably nor nor anyone nor nor position.',
#    'Nor nor old early early early item.',
#    'Impact impact yet nor wind impact nor wind.',
#    'Guess thank old old norme old.',
#    'Norme beautiful middle stock stock.',
#    'Norme norme term act norme term.'],
#   ['Recently also also also recently also also also recently look.',
#    'Develop also develop nothing develop also nothing also.',
#    'Also also lose left act left.',
#    'Loss probably loss guy probably listen probably.',
#    'Color fire fire color color.',
#    'Finally guy color color color key guy.',
#    'Colorhim colorhim nothing believe colorhim.',
#    'Meeting design fire meeting meeting colorhim colorhim single colorhim.',
#    'Knowledge colorhim suffer officer begin officer suffer line.']]]

# %%
topic_space_master
# Out:
# [[['colorhim',
#    'color',
#    'color',
#    'also',
#    'also',
#    (array([0.41]), array([0.732]))],
#   ['norme',
#    'nor',
#    'drop',
#    'alsofind',
#    'agency',
#    'also',
#    (array([0.523]), array([0.874]))],
#   ['agencyshoulder', 'agency', 'also', (array([0.627]), array([0.764]))],
#   ['oulder', 'drop', 'also', 'alsocivil', (array([0.426]), array([0.03]))],
#   ['agencyme', 'agency', 'also', (array([0.281]), array([0.543]))],
#   ['alsopositive',
#    'field',
#    'drop',
#    'also',
#    'drop',
#    (array([0.475]), array([0.407]))],
#   ['agencywife',
#    'agency',
#    'color',
#    'agencylong',
#    'agency',
#    'drop',
#    (array([0.097]), array([0.166]))],
#   ['droplong', 'drop', 'color', (array([0.678]), array([0.909]))],
#   ['alsocivil', (array([0.384]), array([0.519]))],
#   ['norshoulder',
#    'nor',
#    'agencyme',
#    'norpainting',
#    'nor',
#    'drop',
#    'drop',
#    'also',
#    (array([0.772]), array([0.318]))],
#   ['orldme',
#    'field',
#    'drop',
#    'alsocivilworld',
#    'field',
#    'drop',
#    'alsocivil',
#    (array([0.385]), array([0.368]))],
#   ['agency',
#    'agencymehim',
#    'agencyperform',
#    'agency',
#    (array([0.738]), array([0.2]))],
#   ['field',
#    'norpaintingfind',
#    'color',
#    'agencymehim',
#    'norpainting',
#    'nor',
#    'nor',
#    (array([0.92]), array([0.427]))],
#   ['agencyfind',
#    'agency',
#    'agencyme',
#    'mwater',
#    (array([0.788]), array([0.038]))],
#   ['colorany',
#    'agency',
#    'color',
#    'color',
#    'color',
#    (array([0.264]), array([0.916]))],
#   ['sitive',
#    'agency',
#    'drop',
#    'norwater',
#    'agency',
#    'agency',
#    'norimportant',
#    'nor',
#    'agencyfind',
#    'agency',
#    (array([0.322]), array([0.695]))],
#   ['agencywife',
#    'field',
#    'agencyfind',
#    'droppainting',
#    'agency',
#    'drop',
#    (array([0.205]), array([0.528]))],
#   ['droppositive', 'drop', 'drop', (array([0.212]), array([0.485]))],
#   ['ortant',
#    'field',
#    'agencyrecognize',
#    'ortant',
#    'color',
#    'oulder',
#    'drop',
#    'dropwife',
#    'drop',
#    'drop',
#    (array([0.493]), array([0.33]))],
#   ['fieldshoulder',
#    'nor',
#    'drop',
#    'fieldany',
#    'drop',
#    'field',
#    (array([0.973]), array([0.205]))],
#   ['nizeme', 'agency', 'agencyrecognize', (array([0.373]), array([0.897]))],
#   ['agencyfindworld', 'agency', 'agencyfind', (array([0.559]), array([0.29]))],
#   ['drop',
#    'oulder',
#    'nology',
#    'agency',
#    'agency',
#    (array([0.992]), array([0.908]))],
#   ['agency', (array([0.724]), array([0.884]))],
#   ['agencyfindworld',
#    'nor',
#    'agency',
#    'agencyfind',
#    (array([0.047]), array([0.091]))],
#   ['agencypainting',
#    'color',
#    'agencyrecognize',
#    'field',
#    'agencyprovide',
#    'color',
#    'agency',
#    (array([0.126]), array([0.8]))],
#   ['drop', (array([0.228]), array([0.086]))],
#   ['dropmeany',
#    'agency',
#    'agency',
#    'dropme',
#    (array([0.963]), array([0.407]))],
#   ['dropmeonto',
#    'nor',
#    'dropme',
#    'field',
#    'alsokindwife',
#    'field',
#    'dropprovide',
#    'fieldany',
#    'field',
#    'dropme',
#    (array([0.297]), array([0.501]))],
#   ['dropshoulder', 'drop', 'dropprovide', (array([0.514]), array([0.986]))],
#   ['droplong',
#    'agency',
#    'fieldcivil',
#    'fieldcivil',
#    'drop',
#    (array([0.939]), array([0.03]))],
#   ['norhalf', 'nor', 'fieldcivil', (array([0.292]), array([0.225]))],
#   ['norwife', 'nor', 'alsokind', (array([0.738]), array([0.559]))],
#   ['fieldcivil', 'color', 'drop', 'field', (array([0.948]), array([0.397]))],
#   ['dropprovide',
#    'drop',
#    'drop',
#    'dropme',
#    'agencywife',
#    'drop',
#    'agency',
#    (array([0.253]), array([0.529]))],
#   ['drop', 'drophalf', 'drop', 'field', (array([0.648]), array([0.044]))],
#   ['agency',
#    'droplong',
#    'nor',
#    'dropprovide',
#    'drop',
#    'agency',
#    (array([0.512]), array([0.411]))],
#   ['norhalf',
#    'color',
#    'nor',
#    'norfind',
#    'color',
#    'nor',
#    'nor',
#    (array([0.706]), array([0.908]))],
#   ['fieldimportant',
#    'agency',
#    'colorfind',
#    'fieldwater',
#    'colorfind',
#    'field',
#    'drophim',
#    'drop',
#    'fieldwater',
#    (array([0.906]), array([0.889]))],
#   ['norprovidefind',
#    'agency',
#    'nor',
#    'norprovide',
#    'field',
#    'nor',
#    (array([0.867]), array([0.67]))],
#   ['colortechnology',
#    'agency',
#    'fieldwater',
#    'coloronto',
#    'field',
#    'colorfind',
#    'color',
#    'colorfind',
#    (array([0.756]), array([0.95]))],
#   ['dropimportant',
#    'drop',
#    'fieldwater',
#    'nor',
#    'fieldwater',
#    'fieldwater',
#    'dropimportant',
#    'drop',
#    'field',
#    (array([0.898]), array([0.944]))],
#   ['norrecognizeme',
#    'drop',
#    'nor',
#    'field',
#    'colorfind',
#    'norrecognize',
#    'color',
#    'color',
#    'nor',
#    (array([0.013]), array([0.274]))],
#   ['nor', 'norimportant', 'field', 'nor', (array([0.894]), array([0.505]))],
#   ['norcivil', 'field', 'field', 'drop', (array([0.327]), array([0.799]))],
#   ['norhalf',
#    'nor',
#    'nor',
#    'norcivil',
#    'nor',
#    'drop',
#    (array([0.707]), array([0.034]))],
#   ['dropwife',
#    'field',
#    'nor',
#    'dropany',
#    'field',
#    'drop',
#    'norfind',
#    'field',
#    'nor',
#    (array([0.233]), array([0.616]))],
#   ['fieldfind',
#    'color',
#    'norcivil',
#    'nor',
#    'norhope',
#    'field',
#    'nor',
#    'field',
#    'norcivil',
#    (array([0.028]), array([0.78]))],
#   ['ortant',
#    'agency',
#    'colorme',
#    'colorme',
#    'colorlong',
#    'agency',
#    'color',
#    (array([0.86]), array([0.278]))],
#   ['colorme',
#    'fieldhope',
#    'field',
#    'colorme',
#    'fieldhope',
#    'field',
#    'nor',
#    (array([0.718]), array([0.216]))],
#   ['agencyhalf',
#    'drop',
#    'field',
#    'fieldwifecivil',
#    'agency',
#    'field',
#    'fieldwife',
#    (array([0.72]), array([0.591]))],
#   ['field', 'norprovide', 'nor', 'nor', (array([0.086]), array([0.426]))],
#   ['nor', (array([0.189]), array([0.366]))],
#   ['nor', 'field', 'norany', (array([0.12]), array([0.767]))],
#   ['noranyhimwater',
#    'nor',
#    'field',
#    'noranyhim',
#    'color',
#    'norany',
#    'norany',
#    (array([0.133]), array([0.805]))],
#   ['norany',
#    'norany',
#    'nor',
#    'nor',
#    'noranyhim',
#    'field',
#    'norany',
#    (array([0.169]), array([0.919]))],
#   ['dropwater', 'drop', 'field', (array([0.818]), array([0.537]))],
#   ['agencyfind',
#    'drop',
#    'alsotechnology',
#    'fieldpositive',
#    'agency',
#    'field',
#    (array([0.329]), array([0.936]))],
#   ['alsotechnology', 'alsotechnology', (array([0.201]), array([0.905]))],
#   ['rwater',
#    'field',
#    'agency',
#    'also',
#    'alsoshoulder',
#    'drop',
#    'also',
#    'alsotechnology',
#    (array([0.79]), array([0.702]))],
#   ['alsofind', 'color', 'also', (array([0.681]), array([0.389]))],
#   ['norwater',
#    'agency',
#    'agency',
#    'norhalf',
#    'nor',
#    'alsohim',
#    'also',
#    (array([0.013]), array([0.294]))],
#   ['also',
#    'also',
#    'agency',
#    'also',
#    'rovide',
#    'field',
#    'alsotechnology',
#    'alsotechnology',
#    (array([0.998]), array([0.486]))],
#   ['agency',
#    'alsohim',
#    'alsohimwife',
#    'agency',
#    'alsohim',
#    'alsotechnology',
#    (array([0.034]), array([0.55]))],
#   ['agency', 'also', 'also', (array([0.626]), array([0.777]))],
#   ['norperform', 'nor', 'also', (array([0.513]), array([0.984]))],
#   ['dropfind',
#    'drop',
#    'agency',
#    'alsotechnology',
#    (array([0.486]), array([0.368]))],
#   ['fieldpainting',
#    'field',
#    'field',
#    'alsoworld',
#    'droponto',
#    'drop',
#    'alsoworld',
#    (array([0.79]), array([0.392]))],
#   ['also', 'fieldhalf', 'field', 'also', (array([0.815]), array([0.784]))],
#   ['alsoonto', 'field', 'also', (array([0.434]), array([0.35]))],
#   ['norhope', 'nor', 'also', (array([0.229]), array([0.966]))],
#   ['alsoprovide', 'agency', 'also', 'also', (array([0.13]), array([0.413]))],
#   ['droptechnology', 'drop', 'also', (array([0.759]), array([0.341]))],
#   ['alsoanyprovide',
#    'nor',
#    'also',
#    'also',
#    'also',
#    'alsoany',
#    'drop',
#    'also',
#    (array([0.775]), array([0.288]))],
#   ['alsohope',
#    'color',
#    'also',
#    'also',
#    'also',
#    'also',
#    'alsoprovide',
#    'agency',
#    'also',
#    (array([0.187]), array([0.786]))],
#   ['also',
#    'also',
#    'alsohalf',
#    'color',
#    'also',
#    'alsoonto',
#    'drop',
#    'also',
#    (array([0.779]), array([0.496]))],
#   ['norworld', 'nor', 'also', (array([0.792]), array([0.208]))],
#   ['also', (array([0.775]), array([0.779]))],
#   ['also',
#    'alsoprovide',
#    'nor',
#    'also',
#    'also',
#    'also',
#    (array([0.037]), array([0.291]))],
#   ['ycivilrecognize',
#    'agency',
#    'ycivil',
#    'ycivil',
#    'ycivil',
#    (array([0.736]), array([0.149]))],
#   ['agencymewater',
#    'agency',
#    'zehalf',
#    'nology',
#    'agencyme',
#    'agency',
#    'agency',
#    (array([0.786]), array([0.854]))],
#   ['erform',
#    'nor',
#    'droprecognize',
#    'agencyhope',
#    'agency',
#    'drop',
#    (array([0.745]), array([0.195]))],
#   ['colormehalf', 'nor', 'colorme', (array([0.458]), array([0.271]))],
#   ['field',
#    'colorme',
#    'agency',
#    'agency',
#    'colorme',
#    (array([0.079]), array([0.649]))],
#   ['norfind',
#    'agency',
#    'agencyperform',
#    'norworld',
#    'nor',
#    'nor',
#    (array([0.493]), array([0.429]))],
#   ['norpainting',
#    'drop',
#    'agencypositive',
#    'norcivil',
#    'color',
#    'nor',
#    (array([0.204]), array([0.497]))],
#   ['rovide',
#    'drop',
#    'agencypositive',
#    'agency',
#    'agencypositive',
#    'agencypositive',
#    'nor',
#    (array([0.538]), array([0.726]))],
#   ['vehalf',
#    'field',
#    'agencypositive',
#    'agencypositive',
#    'agency',
#    'nor',
#    (array([0.735]), array([0.427]))],
#   ['colorwater',
#    'nor',
#    'nor',
#    'color',
#    'fieldperform',
#    'field',
#    'nor',
#    (array([0.22]), array([0.17]))],
#   ['iveany', 'nor', 'agency', (array([0.852]), array([0.873]))],
#   ['fieldshoulder',
#    'field',
#    'agencypositive',
#    (array([0.813]), array([0.491]))],
#   ['colorpainting',
#    'nor',
#    'color',
#    'norhope',
#    'agency',
#    'nor',
#    (array([0.635]), array([0.927]))],
#   ['fieldhalf',
#    'drop',
#    'nor',
#    'droptechnology',
#    'field',
#    'agency',
#    'dropwife',
#    'drop',
#    'iveany',
#    (array([0.54]), array([0.444]))],
#   ['noranyhim',
#    'field',
#    'iveany',
#    'nor',
#    'norany',
#    'nor',
#    'color',
#    (array([0.394]), array([0.57]))],
#   ['norfind',
#    'drop',
#    'nor',
#    'fieldworld',
#    'field',
#    'color',
#    'nor',
#    (array([0.706]), array([0.044]))],
#   ['agencyme', 'nor', 'agency', 'agency', (array([0.86]), array([0.58]))],
#   ['fieldwater',
#    'field',
#    'agencylongfind',
#    'agencylongfind',
#    (array([0.445]), array([0.596]))],
#   ['rovide',
#    'drop',
#    'norpositive',
#    'agencylong',
#    (array([0.683]), array([0.386]))],
#   ['droplong', 'agency', 'drop', (array([0.958]), array([0.893]))],
#   ['drop',
#    'majorityany',
#    'drop',
#    'majority',
#    'majority',
#    'majorityme',
#    (array([0.977]), array([0.258]))],
#   ['majority', 'majorityme', 'majority', (array([0.241]), array([0.236]))],
#   ['normeworld',
#    'agency',
#    'droponto',
#    'drop',
#    'colorworld',
#    'drop',
#    'norme',
#    'colorprovide',
#    'color',
#    'field',
#    (array([0.069]), array([0.262]))],
#   ['agencyhalf',
#    'agency',
#    'agency',
#    'drop',
#    'drop',
#    (array([0.404]), array([0.488]))],
#   ['fieldfind',
#    'field',
#    'agency',
#    'inting',
#    'drop',
#    'agencyrecognize',
#    (array([0.175]), array([0.8]))],
#   ['norlong',
#    'agency',
#    'nor',
#    'agencyrecognize',
#    (array([0.359]), array([0.921]))],
#   ['norpainting',
#    'nor',
#    'nor',
#    'agencyonto',
#    'nor',
#    'agency',
#    (array([0.711]), array([0.16]))],
#   ['fieldprovide',
#    'nor',
#    'field',
#    'field',
#    'field',
#    (array([0.896]), array([0.454]))],
#   ['nology',
#    'nologyme',
#    'nor',
#    'nology',
#    'color',
#    'fieldonto',
#    'field',
#    'nology',
#    (array([0.251]), array([0.254]))],
#   ['nology',
#    'nology',
#    'colorpainting',
#    'color',
#    'color',
#    (array([0.53]), array([0.615]))],
#   ['nologycivil',
#    'drop',
#    'nology',
#    'nology',
#    'agencylonghalf',
#    'agency',
#    'color',
#    'agencylong',
#    'agency',
#    'agency',
#    (array([0.479]), array([0.821]))],
#   ['nologykind',
#    'color',
#    'nology',
#    'nologyperform',
#    'nor',
#    'nology',
#    'nology',
#    'colorperform',
#    'color',
#    (array([0.395]), array([0.867]))],
#   ['colorshoulder',
#    'nor',
#    'majority',
#    'color',
#    'colorme',
#    (array([0.226]), array([0.473]))],
#   ['color', 'majority', 'majority', (array([0.782]), array([0.725]))],
#   ['oulder',
#    'color',
#    'color',
#    'majoritylong',
#    'nor',
#    'majority',
#    'color',
#    (array([0.019]), array([0.864]))],
#   ['ognize',
#    'field',
#    'agency',
#    'majority',
#    'majority',
#    (array([0.884]), array([0.461]))],
#   ['ivehim',
#    'agency',
#    'majority',
#    'agencyonto',
#    'agency',
#    'colorpositive',
#    (array([0.849]), array([0.845]))],
#   ['colorwater', 'nor', 'color', (array([0.076]), array([0.187]))],
#   ['colorpositive',
#    'color',
#    'color',
#    'color',
#    'agency',
#    (array([0.38]), array([0.255]))],
#   ['velong',
#    'drop',
#    'colorpositive',
#    'color',
#    'agency',
#    (array([0.251]), array([0.405]))],
#   ['oulder', 'drop', 'majority', (array([0.357]), array([0.934]))],
#   ['ognizehim',
#    'color',
#    'colorpositive',
#    'ognize',
#    'ognize',
#    (array([0.479]), array([0.222]))],
#   ['sitive',
#    'drop',
#    'majority',
#    'velong',
#    'drop',
#    'colorpositive',
#    (array([0.041]), array([0.87]))],
#   ['droppainting', 'drop', 'color', (array([0.998]), array([0.472]))],
#   ['color',
#    'agencyprovide',
#    'agency',
#    'majority',
#    (array([0.883]), array([0.226]))],
#   ['drop',
#    'fieldme',
#    'field',
#    'majority',
#    'color',
#    'color',
#    (array([0.556]), array([0.787]))],
#   ['inting',
#    'nor',
#    'majority',
#    'majoritylong',
#    'agency',
#    'majority',
#    'majority',
#    (array([0.439]), array([0.588]))],
#   ['oulderpositive',
#    'nor',
#    'majority',
#    'oulder',
#    'color',
#    'majority',
#    (array([0.123]), array([0.954]))],
#   ['ortant',
#    'color',
#    'majority',
#    'majority',
#    'majority',
#    'majority',
#    (array([0.611]), array([0.712]))],
#   ['ognize',
#    'drop',
#    'majority',
#    'agencyfind',
#    'erform',
#    'nor',
#    'agencyfind',
#    'fieldrecognize',
#    'field',
#    'agencyfind',
#    (array([0.227]), array([0.051]))],
#   ['dropfind',
#    'field',
#    'agency',
#    'majority',
#    'drop',
#    'majority',
#    'agencyperform',
#    'color',
#    'majority',
#    'agency',
#    (array([0.975]), array([0.615]))],
#   ['drop',
#    'agency',
#    'fieldhalf',
#    'field',
#    'majority',
#    'agencyfind',
#    (array([0.301]), array([0.803]))],
#   ['fieldkindlong',
#    'nor',
#    'agency',
#    'fieldkind',
#    'field',
#    'agency',
#    'drop',
#    (array([0.452]), array([0.006]))],
#   ['dropfind', 'drop', 'majority', (array([0.669]), array([0.722]))],
#   ['majoritylongme',
#    'color',
#    'majoritylong',
#    'agencyfind',
#    (array([0.157]), array([0.133]))],
#   ['droppainting',
#    'nor',
#    'drop',
#    'majority',
#    (array([0.598]), array([0.144]))],
#   ['droppositive', (array([0.619]), array([0.63]))],
#   ['nor', 'drop', (array([0.958]), array([0.27]))],
#   ['colorrecognize',
#    'color',
#    'nor',
#    'color',
#    'nor',
#    'drop',
#    'color',
#    (array([0.846]), array([0.079]))],
#   ['agencypainting', 'agency', 'nology', (array([0.111]), array([0.214]))],
#   ['drop',
#    'agency',
#    'nology',
#    'nor',
#    'agency',
#    'agency',
#    (array([0.24]), array([0.595]))],
#   ['nologywife',
#    'agency',
#    'nology',
#    'dropkind',
#    'agency',
#    'drop',
#    (array([0.724]), array([0.57]))],
#   ['drop',
#    'drop',
#    'agency',
#    'majority',
#    'nology',
#    (array([0.242]), array([0.789]))],
#   ['majorityme',
#    'fieldrecognize',
#    'field',
#    'sitive',
#    'agencyimportant',
#    'field',
#    'agency',
#    (array([0.861]), array([0.683]))],
#   ['norme', 'nor', 'majority', (array([0.773]), array([0.51]))],
#   ['agency',
#    'majority',
#    'drop',
#    'droplong',
#    'drop',
#    'agency',
#    (array([0.697]), array([0.238]))],
#   ['drophim',
#    'drop',
#    'nor',
#    'nor',
#    'agency',
#    'agencyrecognize',
#    'field',
#    'agency',
#    (array([0.427]), array([0.898]))],
#   ['nology',
#    'nor',
#    'agencyshoulder',
#    'agency',
#    'agency',
#    'drop',
#    (array([0.261]), array([0.15]))],
#   ['agencywater',
#    'agency',
#    'sitive',
#    'droprecognize',
#    'field',
#    'drop',
#    (array([0.35]), array([0.21]))],
#   ['nor',
#    'agencywife',
#    'agency',
#    'nor',
#    'norhalf',
#    'field',
#    'nor',
#    'nology',
#    (array([0.284]), array([0.288]))],
#   ['drop', (array([0.401]), array([0.466]))],
#   ['dropwateronto', 'color', 'dropwater', (array([0.824]), array([0.824]))],
#   ['drop', (array([0.685]), array([0.818]))],
#   ['norshoulder',
#    'agency',
#    'drop',
#    'dropwater',
#    'dropwater',
#    'dropwife',
#    'nor',
#    'drop',
#    (array([0.533]), array([0.266]))],
#   ['dropwife',
#    'field',
#    'drop',
#    'dropworld',
#    'drop',
#    'drop',
#    'norany',
#    'nor',
#    'drop',
#    (array([0.463]), array([0.574]))],
#   ['norpositive',
#    'drop',
#    'nor',
#    'dropwater',
#    (array([0.503]), array([0.365]))],
#   ['coloronto',
#    'color',
#    'drop',
#    'nor',
#    'dropimportant',
#    'drop',
#    'drop',
#    (array([0.506]), array([0.623]))],
#   ['dropfind',
#    'drop',
#    'dropwater',
#    'norcivil',
#    'agency',
#    'drop',
#    'norimportant',
#    'drop',
#    'nor',
#    (array([0.212]), array([0.464]))],
#   ['ognize',
#    'drop',
#    'nor',
#    'drop',
#    'dropwater',
#    'oulder',
#    'agency',
#    'drop',
#    'dropwater',
#    (array([0.65]), array([0.684]))],
#   ['norme',
#    'nor',
#    'dropwater',
#    'nor',
#    'drophalf',
#    'drop',
#    'dropwater',
#    'drop',
#    (array([0.051]), array([0.62]))],
#   ['dropfind', 'drop', 'drop', 'nor', (array([0.572]), array([0.647]))],
#   ['agencylong',
#    'agency',
#    'colortechnology',
#    'drop',
#    'majorityme',
#    (array([0.849]), array([0.176]))],
#   ['ognize',
#    'color',
#    'majorityme',
#    'colorhalf',
#    'agency',
#    'colortechnology',
#    'color',
#    (array([0.257]), array([0.97]))],
#   ['drop', (array([0.861]), array([0.085]))],
#   ['rovide', 'color', 'majorityme', (array([0.619]), array([0.927]))],
#   ['fieldpainting', 'field', 'field', (array([0.707]), array([0.431]))],
#   ['agencyprovide',
#    'nor',
#    'colorworld',
#    'coloronto',
#    'agency',
#    'drop',
#    'dropprovide',
#    'agency',
#    'color',
#    'drop',
#    (array([0.132]), array([0.168]))],
#   ['drop', (array([0.359]), array([0.472]))],
#   ['fieldme',
#    'field',
#    'drop',
#    'norwater',
#    'nor',
#    'drop',
#    'field',
#    (array([0.043]), array([0.674]))],
#   ['fieldshoulder', 'agency', 'field', (array([0.404]), array([0.321]))],
#   ['agencywife', 'color', 'agency', (array([0.145]), array([0.306]))],
#   ['agencyhim',
#    'agencyhim',
#    'norfind',
#    'nor',
#    'drop',
#    'agencyhim',
#    (array([0.202]), array([0.637]))],
#   ['agencyhimwater', 'color', 'agencyhim', (array([0.605]), array([0.557]))],
#   ['erform',
#    'drop',
#    'drop',
#    'agencyhim',
#    'agencyonto',
#    'color',
#    'agency',
#    (array([0.919]), array([0.807]))],
#   ['agencyhimme', 'agency', 'agencyhim', (array([0.663]), array([0.449]))],
#   ['dropkind',
#    'field',
#    'drop',
#    'agencyhimkind',
#    'drop',
#    'agencyhim',
#    'agencyhimhope',
#    'drop',
#    'agencyhim',
#    (array([0.556]), array([0.024]))],
#   ['agencyhimlong', 'color', 'agencyhim', (array([0.233]), array([0.751]))],
#   ['agencyhim',
#    'agencyhimonto',
#    'color',
#    'drop',
#    'agencyhim',
#    'agencyhim',
#    'agencyhim',
#    (array([0.247]), array([0.422]))],
#   ['dropcivil',
#    'drop',
#    'drop',
#    'drop',
#    'agencyhim',
#    'agencylong',
#    'color',
#    'agency',
#    (array([0.455]), array([0.172]))],
#   ['norshoulder',
#    'nor',
#    'agencyhim',
#    'agency',
#    'agencyhim',
#    (array([0.703]), array([0.606]))],
#   ['inting',
#    'color',
#    'drop',
#    'agencycivil',
#    'drop',
#    'agency',
#    'agencyhim',
#    (array([0.151]), array([0.468]))],
#   ['norpainting',
#    'nor',
#    'ognize',
#    'norhalf',
#    'nor',
#    'ognize',
#    'dropprovide',
#    'nor',
#    'drop',
#    (array([0.954]), array([0.622]))],
#   ['colorany',
#    'field',
#    'colorany',
#    'colorme',
#    'color',
#    'color',
#    (array([0.261]), array([0.795]))],
#   ['colorlong', 'color', 'colorkind', (array([0.37]), array([0.181]))],
#   ['fieldonto', 'field', 'color', (array([0.411]), array([0.603]))],
#   ['colorimportant',
#    'color',
#    'nor',
#    'color',
#    (array([0.173]), array([0.335]))],
#   ['colorkind', 'majority', (array([0.975]), array([0.647]))],
#   ['majority', (array([0.587]), array([0.274]))],
#   ['agencyshoulder', 'agency', 'colorkind', (array([0.516]), array([0.174]))],
#   ['dropworld', 'drop', 'drop', (array([0.272]), array([0.284]))],
#   ['gywife',
#    'field',
#    'norprovide',
#    'droptechnology',
#    'although',
#    'agency',
#    'drophalf',
#    'drop',
#    'droptechnology',
#    (array([0.398]), array([0.572]))],
#   ['droptechnology', 'agencyimportant', (array([0.343]), array([0.684]))],
#   ['color',
#    'colorprovide',
#    'agency',
#    'color',
#    (array([0.76]), array([0.704]))],
#   ['gykind',
#    'color',
#    'drop',
#    'agency',
#    'droptechnology',
#    (array([0.295]), array([0.62]))],
#   ['erform',
#    'nor',
#    'field',
#    'eronto',
#    'field',
#    'field',
#    'field',
#    'field',
#    'agencyshoulder',
#    'agencyhim',
#    (array([0.757]), array([0.439]))],
#   ['dropkind', 'dropkind', 'dropkind', (array([0.453]), array([0.515]))],
#   ['fieldcivil',
#    'color',
#    'field',
#    'agencyonto',
#    'agency',
#    'fieldonto',
#    (array([0.275]), array([0.852]))],
#   ['ecivil',
#    'nor',
#    'agencypositive',
#    'agencyperform',
#    'agency',
#    'agency',
#    (array([0.997]), array([0.861]))],
#   ['nor', 'norhim', 'drop', 'nor', 'agency', (array([0.443]), array([0.416]))],
#   ['agency',
#    'agencypositive',
#    'agencypositive',
#    (array([0.081]), array([0.975]))],
#   ['agencypositive', 'norkind', (array([0.98]), array([0.435]))],
#   ['norprovide',
#    'nor',
#    'agencypositive',
#    'agency',
#    'agency',
#    (array([0.027]), array([0.42]))],
#   ['norprovide', 'field', 'nor', (array([0.217]), array([0.563]))],
#   ['drophope',
#    'drop',
#    'nor',
#    'agency',
#    'agencypositive',
#    'nor',
#    (array([0.411]), array([0.306]))],
#   ['colorrecognize',
#    'field',
#    'agencypositive',
#    'colorpainting',
#    'color',
#    'norkind',
#    (array([0.91]), array([0.62]))],
#   ['norwife',
#    'color',
#    'agency',
#    'norkind',
#    'nor',
#    'agency',
#    (array([0.439]), array([0.667]))],
#   ['nor', 'nor', (array([0.942]), array([0.127]))],
#   ['norprovide', 'field', 'nor', (array([0.733]), array([0.457]))],
#   ['fieldhalfkind', 'agency', 'fieldhalf', (array([0.201]), array([0.177]))],
#   ['fieldwater',
#    'agency',
#    'agency',
#    'fieldhalf',
#    'color',
#    'field',
#    (array([0.639]), array([0.359]))],
#   ['although', (array([0.751]), array([0.385]))],
#   ['oulder',
#    'color',
#    'agencykindme',
#    'although',
#    (array([0.407]), array([0.404]))],
#   ['field',
#    'oulder',
#    'field',
#    'agencykind',
#    'although',
#    'colorrecognize',
#    'color',
#    'although',
#    (array([0.372]), array([0.45]))],
#   ['agencykindme', (array([0.399]), array([0.837]))],
#   ['nglong',
#    'drop',
#    'agencykindme',
#    'althoughlong',
#    'drop',
#    'agencykind',
#    'althoughperform',
#    'agency',
#    'although',
#    'although',
#    (array([0.495]), array([0.858]))],
#   ['althoughworld', 'agency', 'although', (array([0.101]), array([0.159]))],
#   ['rovide',
#    'nor',
#    'agencykind',
#    'agencyfind',
#    'agency',
#    'although',
#    'althoughfind',
#    (array([0.853]), array([0.663]))],
#   ['norfind',
#    'nor',
#    'althoughfind',
#    'agencykind',
#    'althoughprovide',
#    'field',
#    'althoughfind',
#    'although',
#    'field',
#    (array([0.035]), array([0.574]))],
#   ['agencyimportant',
#    'agency',
#    'agency',
#    'althoughkind',
#    'nor',
#    'although',
#    (array([0.477]), array([0.589]))],
#   ['although', 'field', (array([0.664]), array([0.873]))],
#   ['althoughprovide',
#    'field',
#    'although',
#    'although',
#    'although',
#    'although',
#    'colorprovide',
#    'color',
#    'although',
#    (array([0.718]), array([0.885]))],
#   ['dehope',
#    'field',
#    'althoughprovide',
#    'dropimportant',
#    'drop',
#    'althoughprovide',
#    (array([0.121]), array([0.493]))],
#   ['zehope',
#    'nor',
#    'nortechnology',
#    'fieldrecognize',
#    'field',
#    'agencykind',
#    'agency',
#    (array([0.607]), array([0.83]))],
#   ['ognize',
#    'drop',
#    'although',
#    'inting',
#    'agency',
#    'although',
#    'norcivil',
#    'nor',
#    'although',
#    (array([0.312]), array([0.615]))],
#   ['inting', 'color', 'agencykind', (array([0.811]), array([0.959]))],
#   ['agencykindhalf',
#    'drop',
#    'althoughprovide',
#    'norme',
#    'nor',
#    'agency',
#    'agencykind',
#    (array([0.514]), array([0.989]))],
#   ['oulder', 'drop', 'although', (array([0.703]), array([0.279]))],
#   ['norany',
#    'drop',
#    'nor',
#    'agency',
#    'colorprovide',
#    'color',
#    'nor',
#    (array([0.675]), array([0.796]))],
#   ['fieldpositive',
#    'field',
#    'although',
#    'dehope',
#    'agency',
#    'althoughprovide',
#    (array([0.175]), array([0.478]))],
#   ['fieldme', 'field', 'althoughprovide', (array([0.017]), array([0.344]))],
#   ['fieldpainting',
#    'field',
#    'althoughprovide',
#    'norhim',
#    'field',
#    'nor',
#    (array([0.667]), array([0.176]))],
#   ['nor',
#    'lwater',
#    'field',
#    'although',
#    'agencykind',
#    'althoughcivil',
#    'agency',
#    'although',
#    (array([0.314]), array([0.226]))],
#   ['colorhalfworld',
#    'drop',
#    'colorhalf',
#    'drophope',
#    'drop',
#    'colorhalf',
#    (array([0.285]), array([0.671]))],
#   ['agencykind', (array([0.307]), array([0.734]))],
#   ['ognize',
#    'agency',
#    'although',
#    'agencykind',
#    'agency',
#    'colorhalf',
#    (array([0.056]), array([0.071]))],
#   ['colorpainting',
#    'agency',
#    'color',
#    'color',
#    (array([0.981]), array([0.149]))],
#   ['sitive', 'drop', 'although', (array([0.377]), array([0.839]))],
#   ['agencyshoulder',
#    'field',
#    'oulder',
#    'dropme',
#    'agency',
#    'drop',
#    (array([0.711]), array([0.266]))],
#   ['oulder', (array([0.607]), array([0.59]))],
#   ['although',
#    'oulder',
#    'color',
#    'althoughcivil',
#    'oulderprovide',
#    'field',
#    'oulder',
#    (array([0.812]), array([0.215]))],
#   ['althoughcivilme',
#    'field',
#    'although',
#    'droptechnology',
#    'color',
#    'althoughcivil',
#    'drop',
#    (array([0.148]), array([0.891]))],
#   ['oulderimportant',
#    'nor',
#    'although',
#    'oulder',
#    'droplong',
#    'agency',
#    'oulder',
#    'drop',
#    (array([0.914]), array([0.825]))],
#   ['oulder',
#    'dropcivil',
#    'color',
#    'drop',
#    'norworld',
#    'nor',
#    'althoughcivil',
#    (array([0.178]), array([0.798]))],
#   ['although', 'although', (array([0.921]), array([0.475]))],
#   ['fieldhope', 'field', 'although', (array([0.232]), array([0.161]))],
#   ['dropshoulder',
#    'drop',
#    'although',
#    'although',
#    'although',
#    'although',
#    (array([0.424]), array([0.935]))],
#   ['ognize', 'drop', 'although', (array([0.355]), array([0.426]))],
#   ['oulder',
#    'field',
#    'although',
#    'ortant',
#    'drop',
#    'although',
#    'although',
#    (array([0.343]), array([0.69]))],
#   ['although',
#    'although',
#    'althoughhalf',
#    'nor',
#    'although',
#    'although',
#    (array([0.496]), array([0.623]))],
#   ['althoughhalf',
#    'field',
#    'although',
#    'inting',
#    'nor',
#    'although',
#    'although',
#    (array([0.636]), array([0.415]))],
#   ['althoughme', 'drop', 'although', (array([0.451]), array([0.719]))],
#   ['agencyhalf', 'agency', 'although', (array([0.005]), array([0.752]))],
#   ['althoughcivil',
#    'agency',
#    'although',
#    'although',
#    'although',
#    'although',
#    'norfind',
#    'nor',
#    'although',
#    (array([0.848]), array([0.052]))],
#   ['fieldpainting',
#    'field',
#    'although',
#    'agencypainting',
#    'agency',
#    'although',
#    (array([0.909]), array([0.792]))],
#   ['dropany',
#    'field',
#    'color',
#    'dropme',
#    'drop',
#    'although',
#    'althoughonto',
#    (array([0.353]), array([0.763]))],
#   ['oulderimportant',
#    'agency',
#    'dropany',
#    'oulder',
#    (array([0.446]), array([0.689]))],
#   ['oulder',
#    'droptechnology',
#    'drop',
#    'drop',
#    'color',
#    'dropany',
#    (array([0.623]), array([0.204]))],
#   ['nology',
#    'color',
#    'oulder',
#    'oulderany',
#    'nor',
#    'oulder',
#    'oulder',
#    (array([0.317]), array([0.42]))],
#   ['fieldme', 'field', 'oulder', 'oulder', (array([0.962]), array([0.891]))],
#   ['colortechnology',
#    'drop',
#    'color',
#    'color',
#    'color',
#    (array([0.122]), array([0.634]))],
#   ['color',
#    'colorwater',
#    'agency',
#    'color',
#    'color',
#    (array([0.627]), array([0.099]))],
#   ['coloronto', 'field', 'color', (array([0.122]), array([0.333]))],
#   ['color',
#    'colorkind',
#    'color',
#    'color',
#    'color',
#    'color',
#    (array([0.664]), array([0.153]))],
#   ['color', 'color', (array([0.545]), array([0.902]))],
#   ['colorperform',
#    'color',
#    'color',
#    'agencywater',
#    'agency',
#    'color',
#    'color',
#    'color',
#    (array([0.083]), array([0.548]))],
#   ['colorkind',
#    'color',
#    'color',
#    'color',
#    'fieldme',
#    'field',
#    'color',
#    (array([0.192]), array([0.581]))],
#   ['color',
#    'color',
#    'norhim',
#    'nor',
#    'color',
#    'color',
#    (array([0.195]), array([0.609]))],
#   ['agencyworld',
#    'agency',
#    'agency',
#    'dwater',
#    'field',
#    'althoughfind',
#    'althoughfindme',
#    'color',
#    'althoughfind',
#    (array([0.411]), array([0.633]))],
#   ['agencyrecognize',
#    'color',
#    'agency',
#    'although',
#    'ognize',
#    'field',
#    'although',
#    'although',
#    'although',
#    (array([0.306]), array([0.4]))],
#   ['sitivefind',
#    'nor',
#    'althoughfind',
#    'sitive',
#    'nor',
#    'althoughfind',
#    'agencyworld',
#    'color',
#    'agency',
#    (array([0.444]), array([0.79]))],
#   ['dropimportant',
#    'drop',
#    'although',
#    'althoughfind',
#    (array([0.788]), array([0.275]))],
#   ['dropfindany',
#    'drop',
#    'agency',
#    'dropfind',
#    'drop',
#    'althoughfind',
#    (array([0.983]), array([0.617]))],
#   ['agency', 'althoughfind', 'althoughfind', (array([0.494]), array([0.987]))],
#   ['agencykind',
#    'nor',
#    'although',
#    'althoughfind',
#    'agency',
#    'althoughfind',
#    'agency',
#    (array([0.782]), array([0.103]))],
#   ['althoughhalf',
#    'drop',
#    'although',
#    'colorfind',
#    'color',
#    'although',
#    (array([0.075]), array([0.545]))],
#   ['agencyworld',
#    'field',
#    'agency',
#    'agency',
#    'agency',
#    'fieldpainting',
#    'field',
#    'although',
#    (array([0.766]), array([0.615]))],
#   ['although',
#    'althoughonto',
#    'drop',
#    'agency',
#    'although',
#    (array([0.356]), array([0.564]))],
#   ['agency', 'althoughfind', (array([0.802]), array([0.148]))],
#   ['oulderfind',
#    'nor',
#    'nor',
#    'nor',
#    'oulder',
#    (array([0.855]), array([0.37]))],
#   ['droppositive',
#    'drop',
#    'norfind',
#    'norfind',
#    (array([0.403]), array([0.626]))],
#   ['fieldfind',
#    'color',
#    'fieldhim',
#    'field',
#    'rovide',
#    'field',
#    'fieldwater',
#    'field',
#    (array([0.71]), array([0.204]))],
#   ['rovide', 'color', 'althoughprovide', (array([0.642]), array([0.373]))],
#   ['inting',
#    'agency',
#    'norperform',
#    'colorwife',
#    'color',
#    'norperform',
#    'nor',
#    'althoughprovide',
#    (array([0.153]), array([0.699]))],
#   ['nor',
#    'norperform',
#    'norcivil',
#    'agency',
#    'nor',
#    (array([0.549]), array([0.182]))],
#   ['althoughany',
#    'althoughany',
#    'althoughany',
#    'agency',
#    (array([0.509]), array([0.455]))],
#   ['althoughany',
#    'agencykind',
#    'agency',
#    'agencykind',
#    'agencykindfind',
#    'drop',
#    'agencykind',
#    (array([0.889]), array([0.406]))],
#   ['agencyrecognize',
#    'agency',
#    'althoughany',
#    'agencyhope',
#    'field',
#    'agency',
#    (array([0.147]), array([0.226]))],
#   ['agency',
#    'althoughany',
#    'agency',
#    'agencyperform',
#    'agency',
#    'althoughany',
#    'althoughany',
#    (array([0.762]), array([0.291]))],
#   ['dropworld',
#    'drop',
#    'agency',
#    'fieldprovide',
#    'field',
#    'althoughany',
#    (array([0.327]), array([0.257]))],
#   ['norrecognize',
#    'agency',
#    'rovide',
#    'rovide',
#    'droprecognize',
#    'drop',
#    'nor',
#    (array([0.045]), array([0.738]))],
#   ['rovideworld', 'nor', 'color', 'rovide', (array([0.276]), array([0.385]))],
#   ['colorperform', 'color', 'rovide', (array([0.301]), array([0.591]))],
#   ['colorfind',
#    'field',
#    'rovideprovide',
#    'dehope',
#    'nor',
#    'rovideprovide',
#    'color',
#    (array([0.553]), array([0.185]))],
#   ['agencyme', 'field', 'agency', (array([0.216]), array([0.579]))],
#   ['norhim', 'nor', 'rovide', (array([0.33]), array([0.479]))],
#   ['nor', 'nor', (array([0.087]), array([0.076]))],
#   ['fieldkind', 'field', 'agency', (array([0.584]), array([0.403]))],
#   ['oulder',
#    'nor',
#    'colorworld',
#    'colorworld',
#    'colorworldonto',
#    'field',
#    'colorworld',
#    'colorworld',
#    (array([0.171]), array([0.65]))],
#   ['ognizecivil',
#    'field',
#    'field',
#    'ognize',
#    'fieldshoulder',
#    'nor',
#    'field',
#    'field',
#    (array([0.616]), array([0.031]))],
#   ['dropwife',
#    'drop',
#    'drop',
#    'colorworld',
#    'agencykind',
#    'agencycivil',
#    'color',
#    'agency',
#    (array([0.617]), array([0.475]))],
#   ['sitive',
#    'nor',
#    'field',
#    'fieldlong',
#    'nor',
#    'field',
#    'agencyhalf',
#    'agency',
#    'field',
#    (array([0.203]), array([0.556]))],
#   ['agency',
#    'fieldperform',
#    'colorhim',
#    'color',
#    'erform',
#    (array([0.283]), array([0.029]))],
#   ['agencyrecognize',
#    'field',
#    'agency',
#    'agency',
#    'agencyimportant',
#    'agency',
#    'agency',
#    'agency',
#    (array([0.282]), array([0.681]))],
#   ['ortant',
#    'field',
#    'fieldperform',
#    'erform',
#    'fieldperform',
#    'erform',
#    'erform',
#    (array([0.203]), array([0.057]))],
#   ['drop',
#    'drop',
#    'drop',
#    'nor',
#    'drophim',
#    'drop',
#    'drop',
#    (array([0.429]), array([0.208]))],
#   ['drop',
#    'colorany',
#    'color',
#    'drop',
#    'drop',
#    'colorperform',
#    'color',
#    'drop',
#    (array([0.811]), array([0.059]))],
#   ['dropwater', 'nor', 'drop', 'fieldme', (array([0.396]), array([0.628]))],
#   ['fieldkind', 'field', 'drop', 'drop', (array([0.674]), array([0.887]))],
#   ['erform',
#    'agency',
#    'field',
#    'dropcivilfind',
#    'agency',
#    'fieldme',
#    'fieldme',
#    'dropcivil',
#    (array([0.317]), array([0.216]))],
#   ['fieldme',
#    'fieldrecognize',
#    'color',
#    'drop',
#    'fieldmepositive',
#    'color',
#    'fieldme',
#    'field',
#    (array([0.483]), array([0.954]))],
#   ['inting',
#    'drop',
#    'drop',
#    'fieldme',
#    'fieldperform',
#    (array([0.694]), array([0.09]))],
#   ['fieldme',
#    'agencyrecognize',
#    'color',
#    'agency',
#    'sitive',
#    'drop',
#    'fieldperform',
#    'dropcivil',
#    (array([0.545]), array([0.484]))],
#   ['fieldwife',
#    'drop',
#    'agency',
#    'field',
#    'dropworld',
#    'drop',
#    'fieldperform',
#    (array([0.328]), array([0.558]))],
#   ['fieldmeworld',
#    'color',
#    'dropcivil',
#    'field',
#    'droplong',
#    'drop',
#    'fieldme',
#    (array([0.259]), array([0.115]))],
#   ['droprecognize',
#    'field',
#    'dropcivil',
#    'fieldmehope',
#    'drop',
#    'fieldme',
#    'colorwater',
#    'color',
#    'dropcivil',
#    (array([0.85]), array([0.815]))],
#   ['dropwater',
#    'field',
#    'drop',
#    'field',
#    'fieldme',
#    (array([0.04]), array([0.179]))],
#   ['fieldperform',
#    'drop',
#    'fieldperformhim',
#    'agency',
#    'dropcivil',
#    'fieldperform',
#    'field',
#    (array([0.271]), array([0.894]))],
#   ['ivehim',
#    'color',
#    'drop',
#    'colorpositive',
#    'color',
#    'drop',
#    'drop',
#    (array([0.707]), array([0.064]))],
#   ['drophalf',
#    'field',
#    'droplong',
#    'droplonglong',
#    'droplonglong',
#    'dropshoulder',
#    'nor',
#    'drop',
#    (array([0.094]), array([0.515]))],
#   ['agencykind', 'agency', 'drop', 'drop', (array([0.185]), array([0.744]))],
#   ['fieldkind', 'field', 'norkind', (array([0.412]), array([0.579]))],
#   ['dropwater',
#    'drop',
#    'norkind',
#    'dropfind',
#    'drop',
#    'drop',
#    'nor',
#    (array([0.075]), array([0.605]))],
#   ['dropprovide',
#    'field',
#    'drop',
#    'drop',
#    'dropimportant',
#    'nor',
#    'drop',
#    (array([0.463]), array([0.033]))],
#   ['ngkind', 'color', 'droplonglong', (array([0.52]), array([0.53]))],
#   ['fieldfind',
#    'agency',
#    'field',
#    'dropfind',
#    'field',
#    'field',
#    'droplonglong',
#    'drop',
#    (array([0.747]), array([0.355]))],
#   ['colorshoulder',
#    'color',
#    'drop',
#    'nor',
#    'fieldprovide',
#    'color',
#    'norkind',
#    'norkindfind',
#    'field',
#    'norkind',
#    (array([0.39]), array([0.555]))],
#   ['dropkind', 'agency', 'drop', 'drop', (array([0.179]), array([0.211]))],
#   ['drop', 'fieldhope', 'field', 'drop', (array([0.649]), array([0.61]))],
#   ['dropmehope',
#    'agency',
#    'drop',
#    'dropme',
#    'agency',
#    'drop',
#    'drophim',
#    'drop',
#    'drop',
#    'drop',
#    (array([0.95]), array([0.922]))],
#   ['drop', (array([0.878]), array([0.387]))],
#   ['fieldperform', 'field', 'drop', 'drop', (array([0.477]), array([0.793]))],
#   ['dropperform', 'field', 'drop', (array([0.698]), array([0.637]))],
#   ['dropfind',
#    'drop',
#    'drop',
#    'droptechnology',
#    'nor',
#    'drop',
#    'drop',
#    (array([0.337]), array([0.098]))],
#   ['drophope', 'agency', 'drop', (array([0.012]), array([0.701]))],
#   ['norpositive', 'nor', 'field', (array([0.202]), array([0.825]))],
#   ['dropwifeme',
#    'agency',
#    'field',
#    'dropwife',
#    'drop',
#    'fieldshoulder',
#    'field',
#    'field',
#    (array([0.643]), array([0.151]))],
#   ['dropshoulder',
#    'drop',
#    'drop',
#    'norpositive',
#    'agency',
#    'drop',
#    'agency',
#    'drop',
#    'nor',
#    'dropwife',
#    (array([0.497]), array([0.252]))],
#   ['drophalf', 'sitive', 'dropwife', (array([0.788]), array([0.01]))],
#   ['norlong',
#    'agency',
#    'dropwife',
#    'drophalfany',
#    'nor',
#    'drophalf',
#    (array([0.428]), array([0.473]))],
#   ['nor', (array([0.185]), array([0.714]))],
#   ['colorprovide', 'color', 'dropwife', (array([0.975]), array([0.806]))],
#   ['dropwife', (array([0.422]), array([0.549]))],
#   ['agencycivil',
#    'nor',
#    'agency',
#    'drophalf',
#    'nor',
#    'drop',
#    (array([0.157]), array([0.414]))],
#   ['dropany',
#    'color',
#    'field',
#    'fieldhim',
#    'field',
#    'dropfind',
#    'drop',
#    'agency',
#    (array([0.594]), array([0.497]))],
#   ['fieldfind', 'field', 'drop', (array([0.289]), array([0.479]))],
#   ['fieldhimfind', 'field', (array([0.506]), array([0.506]))],
#   ['vefind',
#    'field',
#    'drop',
#    'droppositive',
#    'agency',
#    'drop',
#    'colorhalf',
#    'color',
#    'dropwife',
#    (array([0.405]), array([0.969]))],
#   ['dropwifehalf', 'nor', 'dropwife', (array([0.877]), array([0.475]))],
#   ['fieldhim',
#    'colorperform',
#    'color',
#    'fieldhim',
#    'agency',
#    'fieldhimfind',
#    (array([0.136]), array([0.034]))],
#   ['colorhalf',
#    'color',
#    'fieldhim',
#    'dropwife',
#    (array([0.07]), array([0.33]))],
#   ['agencyperform',
#    'field',
#    'agency',
#    'drop',
#    (array([0.419]), array([0.625]))],
#   ['field',
#    'agency',
#    'fieldhimhope',
#    'color',
#    'fieldhim',
#    'dropwife',
#    (array([0.987]), array([0.879]))],
#   ['colortechnology',
#    'drop',
#    'drop',
#    'norimportanthim',
#    'color',
#    'fieldhim',
#    'norimportant',
#    'nor',
#    'drop',
#    (array([0.351]), array([0.66]))],
#   ['drophope', 'color', 'drop', (array([0.328]), array([0.401]))],
#   ['drophope',
#    'color',
#    'color',
#    'colorhalf',
#    'drop',
#    'color',
#    (array([0.084]), array([0.511]))],
#   ['color', 'colorperform', 'drop', 'color', (array([0.036]), array([0.095]))],
#   ['colorprovide',
#    'field',
#    'color',
#    'colorme',
#    'color',
#    'color',
#    'color',
#    (array([0.199]), array([0.695]))],
#   ['inting', (array([0.356]), array([0.997]))],
#   ['intingwater', 'agency', 'inting', (array([0.133]), array([0.972]))],
#   ['color',
#    'color',
#    'colorwater',
#    'nor',
#    'color',
#    'colorwife',
#    (array([0.696]), array([0.106]))],
#   ['colorwife', (array([0.582]), array([0.271]))],
#   ['nor', (array([0.959]), array([0.786]))],
#   ['drop',
#    'drop',
#    'droppositive',
#    'nor',
#    'drop',
#    'drop',
#    'norrecognize',
#    (array([0.613]), array([0.164]))],
#   ['dropworld', 'field', 'drop', (array([0.401]), array([0.235]))],
#   ['fieldtechnology', 'field', 'drophalf', (array([0.858]), array([0.228]))],
#   ['fieldlongany',
#    'color',
#    'agency',
#    'drop',
#    'fieldlong',
#    'field',
#    'agency',
#    'agency',
#    (array([0.616]), array([0.532]))],
#   ['agencyrecognize',
#    'agency',
#    'agency',
#    'agency',
#    (array([0.933]), array([0.709]))],
#   ['ntwife',
#    'field',
#    'agencyimportant',
#    'nology',
#    'color',
#    'agency',
#    'agency',
#    (array([0.527]), array([0.711]))],
#   ['ognize', 'color', 'agencyimportant', (array([0.4]), array([0.44]))],
#   ['agencyimportant',
#    'tcivil',
#    'agency',
#    'agencyimportant',
#    (array([0.856]), array([0.569]))],
#   ['agencyimportant',
#    'rovideperform',
#    'agency',
#    'drop',
#    'rovide',
#    'color',
#    'agencyimportant',
#    (array([0.848]), array([0.191]))],
#   ['droplong',
#    'drop',
#    'agency',
#    'agency',
#    'drop',
#    (array([0.888]), array([0.269]))],
#   ['fieldwater', 'field', 'drop', (array([0.255]), array([0.702]))],
#   ['norhope',
#    'nor',
#    'drop',
#    'drop',
#    'drop',
#    'drop',
#    (array([0.535]), array([0.184]))],
#   ['dropperform',
#    'field',
#    'agencyimportant',
#    'ntwife',
#    'drop',
#    'agencyimportant',
#    (array([0.73]), array([0.24]))],
#   ['agencyimportant',
#    'agencyprovide',
#    'field',
#    'agency',
#    (array([0.3]), array([0.669]))],
#   ['oulder',
#    'drop',
#    'mwater',
#    'mwater',
#    'mwater',
#    'fieldlong',
#    'color',
#    'field',
#    'drop',
#    (array([0.09]), array([0.067]))],
#   ['ngwife',
#    'drop',
#    'dropperform',
#    'colorpainting',
#    'drop',
#    'color',
#    (array([0.56]), array([0.977]))],
#   ['dropany',
#    'color',
#    'ortant',
#    'drop',
#    'oulder',
#    'color',
#    'dropperformwife',
#    (array([0.194]), array([0.755]))],
#   ['droponto', 'drop', 'field', 'drop', (array([0.313]), array([0.891]))],
#   ['color',
#    'ortantkind',
#    'nor',
#    'ortant',
#    'ortant',
#    'agency',
#    'agency',
#    (array([0.136]), array([0.777]))],
#   ['dropkind', 'agency', (array([0.618]), array([0.12]))],
#   ['dropkind', 'agency', 'ortant', (array([0.251]), array([0.019]))],
#   ['color', (array([0.05]), array([0.851]))],
#   ['ortantrecognize',
#    'nor',
#    'agency',
#    'ortant',
#    'agencywife',
#    'agency',
#    'dropkind',
#    (array([0.129]), array([0.508]))],
#   ['dropkindfind', 'field', 'dropkind', (array([0.788]), array([0.559]))],
#   ['sitive', 'drop', 'dropkind', (array([0.777]), array([0.452]))],
#   ['droppainting',
#    'drop',
#    'color',
#    'color',
#    'droplong',
#    'drop',
#    'color',
#    (array([0.74]), array([0.833]))],
#   ['dropkindme',
#    'drop',
#    'color',
#    'dropkind',
#    (array([0.737]), array([0.909]))],
#   ['coloronto',
#    'agency',
#    'nor',
#    'colormeperform',
#    'agency',
#    'erform',
#    'colorme',
#    'color',
#    'color',
#    'nor',
#    (array([0.072]), array([0.165]))],
#   ['colorany',
#    'field',
#    'color',
#    'fieldwifecivil',
#    'field',
#    'color',
#    'fieldwife',
#    'field',
#    'erform',
#    (array([0.215]), array([0.803]))],
#   ['fieldlong',
#    'field',
#    'nor',
#    'erformwife',
#    'nor',
#    'dropkind',
#    'color',
#    'erform',
#    (array([0.424]), array([0.261]))],
#   ['nor',
#    'agencylong',
#    'color',
#    'dropkind',
#    'color',
#    'colorworld',
#    'agency',
#    'color',
#    (array([0.274]), array([0.187]))],
#   ['nor',
#    'dropperform',
#    'drop',
#    'erform',
#    'norpositive',
#    'color',
#    'nor',
#    'erform',
#    (array([0.242]), array([0.407]))],
#   ['nor', (array([0.778]), array([0.259]))],
#   ['dropkindperform',
#    'agency',
#    'dropkind',
#    'gwater',
#    'color',
#    'color',
#    'norpainting',
#    (array([0.892]), array([0.83]))],
#   ['color',
#    'agency',
#    'dropkind',
#    'field',
#    'field',
#    'dropkind',
#    (array([0.545]), array([0.424]))],
#   ['ortant',
#    'nor',
#    'dropkind',
#    'sitive',
#    'field',
#    'dropkindkind',
#    'dropkindkind',
#    'dropkind',
#    (array([0.369]), array([0.456]))],
#   ['inting',
#    'drop',
#    'dropkind',
#    'dropkind',
#    'agencyworld',
#    'agency',
#    'field',
#    (array([0.158]), array([0.798]))],
#   ['fieldlong',
#    'agency',
#    'field',
#    'dropkind',
#    (array([0.033]), array([0.996]))],
#   ['dropkindkind',
#    'colorpainting',
#    'color',
#    'dropkindkind',
#    (array([0.127]), array([0.604]))],
#   ['dropkindkind',
#    'norme',
#    'nor',
#    'dropkind',
#    'fieldshoulder',
#    'field',
#    'dropkindkindhim',
#    (array([0.995]), array([0.154]))],
#   ['dropkindkindhim',
#    'dropkind',
#    'dropkind',
#    (array([0.184]), array([0.082]))],
#   ['imonto', 'agency', 'dropkindkindhim', (array([0.719]), array([0.862]))],
#   ['oulder',
#    'nor',
#    'dropkind',
#    'dropkind',
#    'fieldkind',
#    'field',
#    'field',
#    'dropkind',
#    (array([0.632]), array([0.113]))],
#   ['field', 'dropkind', 'dropkind', (array([0.527]), array([0.402]))],
#   ['norwife',
#    'nor',
#    'dropkindkind',
#    'dropkindkind',
#    'coloronto',
#    'color',
#    'dropkind',
#    (array([0.206]), array([0.846]))],
#   ['dropkindprovide',
#    'dropkindkind',
#    'deonto',
#    'nor',
#    'field',
#    'dropkindkind',
#    'dropkindprovide',
#    'field',
#    (array([0.462]), array([0.406]))],
#   ['dropkindhope',
#    'nor',
#    'dropkind',
#    'fieldkind',
#    'nor',
#    'field',
#    (array([0.575]), array([0.347]))],
#   ['fieldpositive', 'nor', 'field', (array([0.011]), array([0.941]))],
#   ['ognize',
#    'color',
#    'field',
#    'defind',
#    'drop',
#    'dropkindprovide',
#    'dropkind',
#    (array([0.3]), array([0.977]))],
#   ['ndfind', 'color', 'dropkindkind', (array([0.684]), array([0.956]))],
#   ['fieldhope', 'field', 'dropkindprovide', (array([0.32]), array([0.385]))],
#   ['dropkindprovide',
#    'dropkindprovide',
#    'dropkindprovide',
#    'colortechnology',
#    'color',
#    'dropkindkind',
#    (array([0.954]), array([0.769]))],
#   ['dropkindhope',
#    'color',
#    'dropkindprovide',
#    'dropkind',
#    (array([0.191]), array([0.361]))],
#   ['ndkind',
#    'agency',
#    'dropkindprovide',
#    'field',
#    'dropkindprovide',
#    'dropkindkind',
#    'ortant',
#    'field',
#    'dropkindkind',
#    (array([0.079]), array([0.901]))],
#   ['dropkindprovide', (array([0.042]), array([0.362]))],
#   ['fieldonto', 'field', 'fieldonto', (array([0.503]), array([0.777]))],
#   ['norprovidehope',
#    'agency',
#    'dropkind',
#    'norprovide',
#    'nor',
#    'dropkind',
#    (array([0.423]), array([1.]))],
#   ['color',
#    'dropkind',
#    'field',
#    'norwife',
#    'nor',
#    'nor',
#    (array([0.743]), array([0.33]))],
#   ['norimportant',
#    'field',
#    'nor',
#    'norhalf',
#    'agency',
#    'nor',
#    'dropperform',
#    'drop',
#    'agencypositive',
#    (array([0.465]), array([0.417]))],
#   ['agencypositive',
#    'colorwater',
#    'color',
#    'norpainting',
#    (array([0.78]), array([0.687]))],
#   ['agencykind',
#    'agency',
#    'agency',
#    'agencypositive',
#    'nor',
#    'agency',
#    (array([0.042]), array([0.267]))],
#   ['drop', 'dropkind', (array([0.015]), array([0.769]))],
#   ['erform',
#    'agency',
#    'fieldperform',
#    'nortechnology',
#    'nor',
#    'drop',
#    (array([0.66]), array([0.532]))],
#   ['fieldworld',
#    'field',
#    'field',
#    'dropimportant',
#    'field',
#    'drop',
#    (array([0.184]), array([0.388]))],
#   ['dropimportant', 'field', 'drop', (array([0.09]), array([0.389]))],
#   ['sitive',
#    'color',
#    'drop',
#    'dropkindme',
#    'drop',
#    (array([0.523]), array([0.882]))]],
#  [['agencyme',
#    'color',
#    'drop',
#    'alsocivil',
#    'drop',
#    'also',
#    'agencymehim',
#    'also',
#    (array([0.997]), array([0.395]))],
#   ['dropshoulder',
#    'color',
#    'drop',
#    'droprecognize',
#    'drop',
#    'drop',
#    'color',
#    (array([0.472]), array([0.643]))],
#   ['noronto',
#    'nor',
#    'agencyme',
#    'norwife',
#    'nor',
#    'also',
#    'drop',
#    (array([0.262]), array([0.208]))],
#   ['alsoprovide', 'drop', 'also', 'drop', (array([0.579]), array([0.11]))],
#   ['agencyhim',
#    'agency',
#    'agencymehim',
#    'agencyperform',
#    'agency',
#    'also',
#    (array([0.391]), array([0.441]))],
#   ['mwaterme',
#    'nor',
#    'agencyme',
#    'also',
#    'mwater',
#    'field',
#    'agencymehim',
#    (array([0.694]), array([0.171]))],
#   ['agencymewater',
#    'agency',
#    'agencymehim',
#    'agencyme',
#    (array([0.257]), array([0.18]))],
#   ['agencyfind', 'color', 'agency', (array([0.395]), array([0.613]))],
#   ['agencyfind',
#    'drop',
#    'agency',
#    'field',
#    'agencyrecognize',
#    'agency',
#    'oulder',
#    'agency',
#    (array([0.971]), array([0.176]))],
#   ['norlong',
#    'field',
#    'nor',
#    'field',
#    'norrecognize',
#    'field',
#    'nor',
# ...
#    'oulderperform',
#    (array([0.664]), array([0.162]))],
#   ['norme',
#    'agency',
#    'field',
#    'nor',
#    'field',
#    'agency',
#    'alsokindprovide',
#    'field',
#    'field',
#    'field',
#    (array([0.846]), array([0.502]))],
#   ['alsokindwife',
#    'agency',
#    'alsokindprovide',
#    'alsokindwater',
#    'also',
#    'alsokind',
#    'also',
#    'alsokindprovide',
#    (array([0.277]), array([0.032]))],
#   ['fieldme', 'agency', 'field', (array([0.586]), array([0.001]))],
#   ['nor',
#    'nor',
#    'norkind',
#    'field',
#    'nor',
#    'nor',
#    'nor',
#    (array([0.994]), array([0.786]))],
#   ['nor', (array([0.84]), array([0.003]))],
#   ['color',
#    'colortechnology',
#    'agencywife',
#    'agency',
#    'colortechnology',
#    'color',
#    (array([0.086]), array([0.723]))],
#   ['gyonto', 'drop', 'colortechnology', (array([0.005]), array([0.2]))],
#   ['colortechnology', 'color', 'color', (array([0.845]), array([0.411]))],
#   ['nortechnology',
#    'nor',
#    'field',
#    'fieldfindkind',
#    'nor',
#    'fieldfind',
#    'fieldhope',
#    'drop',
#    'field',
#    (array([0.318]), array([0.874]))],
#   ['alsotechnology',
#    'alsoshoulder',
#    'color',
#    'alsotechnology',
#    'also',
#    'also',
#    (array([0.894]), array([0.528]))],
#   ['also', 'alsotechnology', (array([0.985]), array([0.998]))],
#   ['drophim',
#    'drop',
#    'nor',
#    'majority',
#    'ahead',
#    'agency',
#    (array([0.515]), array([0.003]))],
#   ['nor',
#    'zehalf',
#    'zehalf',
#    'majoritywater',
#    'drop',
#    'majority',
#    (array([0.198]), array([0.365]))],
#   ['aheadme',
#    'agency',
#    'zehalf',
#    'norrecognize',
#    'norrecognize',
#    'ahead',
#    (array([0.043]), array([0.37]))],
#   ['norperform',
#    'nor',
#    'nor',
#    'colorrecognize',
#    'agency',
#    'zehalf',
#    'agencypositive',
#    'color',
#    'agency',
#    (array([0.905]), array([0.003]))],
#   ['norme', 'nor', 'agencylong', (array([0.9]), array([0.37]))],
#   ['agencyhope',
#    'colorperform',
#    'color',
#    'agency',
#    'agency',
#    'ortant',
#    'color',
#    'majority',
#    (array([0.622]), array([0.105]))],
#   ['agency', 'majority', (array([0.412]), array([0.5]))],
#   ['majority',
#    'erform',
#    'field',
#    'agencyhope',
#    (array([0.852]), array([0.44]))],
#   ['agencyany',
#    'color',
#    'majority',
#    'majority',
#    'agencyhope',
#    'majority',
#    'majority',
#    'nology',
#    'agency',
#    'majority',
#    (array([0.411]), array([0.584]))],
#   ['inting',
#    'color',
#    'agencyhope',
#    'majority',
#    'majority',
#    'norme',
#    'nor',
#    'majority',
#    (array([0.742]), array([0.544]))],
#   ['agencyonto',
#    'nor',
#    'agency',
#    'nor',
#    'majority',
#    (array([0.606]), array([0.31]))],
#   ['nology',
#    'agency',
#    'majoritykind',
#    'majority',
#    'agencywater',
#    'agency',
#    'agency',
#    (array([0.823]), array([0.212]))],
#   ['majorityprovide',
#    'color',
#    'majority',
#    'majority',
#    'majority',
#    'majority',
#    (array([0.789]), array([0.347]))],
#   ['agencyhope', 'field', 'agency', (array([0.323]), array([0.484]))],
#   ['ortant',
#    'color',
#    'majority',
#    'agencyfind',
#    'agencyfind',
#    'agency',
#    (array([0.015]), array([0.062]))],
#   ['majority', (array([0.648]), array([0.296]))],
#   ['fieldpainting',
#    'agency',
#    'agency',
#    'fieldany',
#    'field',
#    'agency',
#    (array([0.144]), array([0.456]))],
#   ['agencyfind',
#    'majority',
#    'agencyfind',
#    'agencycivil',
#    'agency',
#    'majority',
#    (array([0.343]), array([0.754]))],
#   ['sitive',
#    'agency',
#    'agencyfind',
#    'majority',
#    (array([0.162]), array([0.618]))],
#   ['norshoulderhalf',
#    'nor',
#    'agency',
#    'ortant',
#    'field',
#    'agency',
#    'norshoulder',
#    'nor',
#    'majority',
#    (array([0.054]), array([0.102]))],
#   ['norpaintinglong',
#    'color',
#    'majority',
#    'agencyfind',
#    'norpainting',
#    'nor',
#    'majority',
#    (array([0.372]), array([0.522]))],
#   ['nology',
#    'agency',
#    'agencyfind',
#    'majority',
#    (array([0.604]), array([0.025]))],
#   ['drop',
#    'colorshoulder',
#    'color',
#    'droppositive',
#    'drop',
#    'majority',
#    'droppositive',
#    (array([0.613]), array([0.503]))],
#   ['majorityme',
#    'drop',
#    'drop',
#    'majority',
#    'droppositive',
#    'drop',
#    'colorworld',
#    'color',
#    'majority',
#    (array([0.893]), array([0.914]))],
#   ['ognize',
#    'color',
#    'majority',
#    'majoritylong',
#    'field',
#    'drop',
#    'majority',
#    (array([0.668]), array([0.256]))],
#   ['colorhope', 'color', 'field', (array([0.261]), array([0.068]))],
#   ['drop',
#    'field',
#    'drophalf',
#    'drop',
#    'drop',
#    (array([0.478]), array([0.189]))],
#   ['oulder',
#    'color',
#    'although',
#    'droptechnology',
#    'drop',
#    'field',
#    (array([0.993]), array([0.284]))],
#   ['dropprovide',
#    'colorshoulder',
#    'color',
#    'dropprovide',
#    (array([0.798]), array([0.571]))],
#   ['drop',
#    'although',
#    'fieldlong',
#    'field',
#    'field',
#    'field',
#    (array([0.247]), array([0.168]))],
#   ['dropme', 'drop', 'field', (array([0.649]), array([0.174]))],
#   ['althoughcivil',
#    'drop',
#    'although',
#    'although',
#    (array([0.12]), array([0.43]))],
#   ['fieldwife',
#    'field',
#    'although',
#    'norkind',
#    'nor',
#    'field',
#    'norprovide',
#    'nor',
#    'field',
#    (array([0.401]), array([0.23]))],
#   ['inting',
#    'agency',
#    'although',
#    'fieldpainting',
#    'field',
#    'field',
#    (array([0.759]), array([0.259]))],
#   ['drop', 'drop', (array([0.11]), array([0.222]))],
#   ['field',
#    'although',
#    'dropimportant',
#    'although',
#    (array([0.773]), array([0.583]))],
#   ['agencykind', 'agency', 'although', (array([0.958]), array([0.292]))],
#   ['colorfind', 'color', 'oulder', (array([0.734]), array([0.253]))],
#   ['agencypainting',
#    'nor',
#    'although',
#    'agencyworld',
#    'color',
#    'although',
#    'although',
#    'althoughkind',
#    'agency',
#    'although',
#    (array([0.488]), array([0.791]))],
#   ['sitive',
#    'color',
#    'although',
#    'although',
#    'although',
#    'oulder',
#    'although',
#    (array([0.961]), array([0.485]))],
#   ['agencyhope',
#    'nor',
#    'although',
#    'oulder',
#    'agencypainting',
#    'nor',
#    'oulder',
#    'agency',
#    'although',
#    (array([0.378]), array([0.051]))],
#   ['although',
#    'oulderpositive',
#    'field',
#    'oulder',
#    (array([0.835]), array([0.721]))],
#   ['althoughwife',
#    'field',
#    'although',
#    'oulder',
#    'although',
#    'oulder',
#    (array([0.767]), array([0.913]))],
#   ['oulder',
#    'agencyrecognize',
#    'agency',
#    'although',
#    'although',
#    (array([0.694]), array([0.654]))],
#   ['fieldhim', 'field', 'agency', (array([0.45]), array([0.674]))],
#   ['agency',
#    'oulder',
#    'although',
#    'although',
#    'although',
#    'dropshoulder',
#    'drop',
#    'oulder',
#    (array([0.318]), array([0.075]))],
#   ['droplong',
#    'agency',
#    'agency',
#    'agency',
#    'oulderme',
#    'field',
#    'although',
#    'oulderfind',
#    'drop',
#    'oulder',
#    (array([0.334]), array([0.458]))],
#   ['althoughprovide',
#    'fieldprovide',
#    'field',
#    'nor',
#    (array([0.234]), array([0.709]))],
#   ['rovide',
#    'nor',
#    'although',
#    'althoughany',
#    (array([0.889]), array([0.984]))],
#   ['althoughanywife',
#    'nor',
#    'agency',
#    'althoughanyme',
#    'color',
#    'althoughany',
#    (array([0.24]), array([0.562]))],
#   ['fieldprovide', 'field', 'nor', (array([0.758]), array([0.236]))],
#   ['ognize', 'drop', 'colorworld', (array([0.693]), array([0.152]))],
#   ['dropcivil',
#    'field',
#    'drop',
#    'drophalf',
#    'drop',
#    'field',
#    'fieldperform',
#    'field',
#    'drop',
#    (array([0.894]), array([0.379]))],
#   ['dropwife', 'agency', 'drop', (array([0.75]), array([0.153]))],
#   ['colorme', 'color', 'dropshoulder', (array([0.649]), array([0.675]))],
#   ['color', 'droplong', 'color', 'drop', (array([0.683]), array([0.313]))],
#   ['dropwaterhim', 'drop', 'dropwater', (array([0.476]), array([0.505]))],
#   ['drop',
#    'dropwife',
#    'drop',
#    'drop',
#    'drophalf',
#    'nor',
#    'drop',
#    (array([0.877]), array([0.688]))],
#   ['dropprovide',
#    'agency',
#    'colorhope',
#    'inting',
#    'color',
#    'drop',
#    'color',
#    'drop',
#    'colorhope',
#    (array([0.982]), array([0.051]))],
#   ['dropkind', 'droponto', 'nor', 'drop', (array([0.701]), array([0.305]))],
#   ['dropshoulder', 'nor', 'drop', (array([0.78]), array([0.021]))],
#   ['dropkindfind',
#    'drop',
#    'dropkind',
#    'dropwife',
#    'nor',
#    'drop',
#    'dropkind',
#    'drop',
#    (array([0.115]), array([0.565]))],
#   ['dropperform', 'nor', 'drop', 'drop', (array([0.804]), array([0.757]))],
#   ['dropkindkind',
#    'color',
#    'dropkind',
#    'dropkind',
#    'fieldwife',
#    'field',
#    'drop',
#    'dropkind',
#    (array([0.995]), array([0.901]))],
#   ['dropkind',
#    'dropkindperform',
#    'nor',
#    'dropkind',
#    'dropkindkind',
#    'field',
#    'dropkind',
#    'dropkind',
#    (array([0.245]), array([0.339]))],
#   ['dropprovideme',
#    'nor',
#    'drop',
#    'dropprovide',
#    'agency',
#    'drop',
#    (array([0.665]), array([0.157]))],
#   ['dropcivil', 'agency', 'drop', (array([0.41]), array([0.513]))],
#   ['dropkind',
#    'drop',
#    'dropkind',
#    'dropprovide',
#    'color',
#    'drop',
#    (array([0.428]), array([0.511]))],
#   ['dropme',
#    'field',
#    'dropkind',
#    'drop',
#    'droponto',
#    'agency',
#    'drop',
#    'drop',
#    'dropkind',
#    (array([0.847]), array([0.733]))],
#   ['norpositivekind',
#    'color',
#    'drop',
#    'norpositive',
#    'nor',
#    'drop',
#    (array([0.519]), array([0.329]))]],
#  [['dropfind', 'drop', 'also', (array([0.028]), array([0.45]))],
#   ['fieldany', 'color', 'field', (array([0.057]), array([0.267]))],
#   ['fieldworld',
#    'drop',
#    'field',
#    'alsopositive',
#    'color',
#    'alsokind',
#    'alsokind',
#    'alsoonto',
#    'color',
#    'also',
#    (array([0.369]), array([0.488]))],
#   ['agencyme',
#    'agency',
#    'also',
#    'colorhalf',
#    'color',
#    'field',
#    'also',
#    'agencykind',
#    'color',
#    'agency',
#    (array([0.687]), array([0.441]))],
#   ['nology',
#    'field',
#    'agency',
#    'alsokindprovide',
#    'alsokindprovide',
#    'fieldimportant',
#    'field',
#    'agency',
#    (array([0.416]), array([0.596]))],
#   ['agencyperform',
#    'nor',
#    'also',
#    'fieldme',
#    'field',
#    'agency',
#    (array([0.079]), array([0.668]))],
#   ['agencyhope',
#    'field',
#    'agency',
#    'agency',
#    'agencyperform',
#    'agency',
#    'agency',
#    (array([0.265]), array([0.126]))],
#   ['nortechnology', 'nor', 'also', (array([0.262]), array([0.365]))],
#   ['alsopainting',
#    'nor',
#    'field',
#    'also',
#    'agency',
#    'alsokindprovide',
#    'agency',
#    (array([0.092]), array([0.077]))],
#   ['oulderperform',
#    'agency',
#    'field',
#    'oulder',
#    'nor',
#    'field',
#    'field',
#    'field',
#    'alsokindprovide',
#    (array([0.888]), array([0.011]))],
#   ['alsopositive',
#    'field',
#    'alsokindprovide',
#    'alsokindwater',
#    'field',
#    'alsokind',
#    'also',
#    (array([0.24]), array([0.581]))],
#   ['also', 'field', (array([0.736]), array([0.588]))],
#   ['colorhim',
#    'field',
#    'nor',
#    'norhim',
#    'color',
#    'nor',
#    (array([0.514]), array([0.348]))],
#   ['fieldcivil',
#    'field',
#    'field',
#    'alsopainting',
#    (array([0.704]), array([0.583]))],
#   ['nor', (array([0.187]), array([0.038]))],
#   ['fieldkind',
#    'agency',
#    'field',
#    'dropany',
#    (array([0.191]), array([0.744]))],
#   ['agencyhalf', 'agency', 'alsopainting', (array([0.984]), array([0.127]))],
#   ['alsopainting',
#    'also',
#    'field',
#    'alsopainting',
#    'nor',
#    'field',
#    'also',
#    (array([0.067]), array([0.057]))],
#   ['colortechnology', 'color', 'nor', (array([0.674]), array([0.283]))],
#   ['nor', 'colorshoulder', 'color', 'drop', (array([0.52]), array([0.224]))],
#   ['fieldfind',
#    'nor',
#    'field',
#    'dropany',
#    'fieldtechnology',
#    'drop',
#    'dropany',
#    'field',
#    (array([0.207]), array([0.894]))],
#   ['alsotechnology', 'agency', 'also', (array([0.464]), array([0.766]))],
#   ['zehalf',
#    'agency',
#    'majority',
#    'norrecognize',
#    'nor',
#    'ahead',
#    (array([0.777]), array([0.048]))],
#   ['majority',
#    'agencylong',
#    'agency',
#    'majority',
#    'majorityperform',
#    'agency',
#    'majority',
#    'majority',
#    (array([0.602]), array([0.801]))],
#   ['majoritykind',
#    'nor',
#    'majority',
#    'majority',
#    'agencyhope',
#    'agency',
#    'majority',
#    'majority',
#    (array([0.92]), array([0.293]))],
#   ['majority',
#    'majority',
#    'agencyfind',
#    'agency',
#    'majority',
#    'majority',
#    (array([0.756]), array([0.187]))],
#   ['droppositive', 'drop', 'majority', (array([0.751]), array([0.185]))],
#   ['norworld',
#    'agency',
#    'majority',
#    'norhalf',
#    'nor',
#    'majority',
#    'majority',
#    (array([0.74]), array([0.738]))],
#   ['dropimportant',
#    'field',
#    'although',
#    'field',
#    'dropprovide',
#    'drop',
#    'although',
#    (array([0.982]), array([0.412]))],
#   ['oulder',
#    'agency',
#    'although',
#    'although',
#    (array([0.97]), array([0.738]))],
#   ['norhim',
#    'field',
#    'althoughany',
#    'althoughprovide',
#    'field',
#    'although',
#    'norimportant',
#    'nor',
#    'although',
#    (array([0.347]), array([0.882]))],
#   ['inting',
#    'nor',
#    'field',
#    'althoughany',
#    'although',
#    (array([0.565]), array([0.146]))],
#   ['althoughany',
#    'although',
#    'although',
#    'althoughany',
#    'field',
#    'agencykind',
#    'agency',
#    'although',
#    (array([0.473]), array([0.399]))],
#   ['fieldwife',
#    'field',
#    'although',
#    'dropme',
#    'drop',
#    'field',
#    (array([0.431]), array([0.382]))],
#   ['althoughperform',
#    'nor',
#    'althoughany',
#    'colorworld',
#    'color',
#    'although',
#    'although',
#    'althoughany',
#    (array([0.249]), array([0.371]))],
#   ['fieldpositive',
#    'field',
#    'dropshoulder',
#    'drop',
#    (array([0.265]), array([0.749]))],
#   ['fieldfind', 'field', 'drop', (array([0.389]), array([0.56]))],
#   ['dropshoulder',
#    'dropwater',
#    'field',
#    'drop',
#    'drop',
#    'colorhim',
#    'color',
#    'drop',
#    (array([0.651]), array([0.925]))],
#   ['dropwife',
#    'color',
#    'drop',
#    'drop',
#    'drop',
#    'drophalf',
#    'color',
#    'drop',
#    (array([0.1]), array([0.315]))],
#   ['drop',
#    'dropfind',
#    'field',
#    'dropshoulder',
#    'drop',
#    'drop',
#    'drop',
#    'drop',
#    (array([0.269]), array([0.783]))],
#   ['agencyany', 'agency', 'drop', 'drop', (array([0.514]), array([0.213]))],
#   ['droptechnology',
#    'agency',
#    'drop',
#    'drop',
#    'dropshoulder',
#    'drop',
#    (array([0.169]), array([0.993]))],
#   ['drop', 'drop', (array([0.805]), array([0.336]))],
#   ['drop', 'colorhope', 'color', 'drop', (array([0.399]), array([0.634]))],
#   ['dropshoulder', (array([0.23]), array([0.136]))],
#   ['dropkind', 'drop', 'drop', (array([0.805]), array([0.087]))]],
#  [['alsokindprovide',
#    'agency',
#    'field',
#    'alsokind',
#    'agency',
#    'also',
#    'also',
#    (array([0.978]), array([0.536]))],
#   ['alsopainting',
#    'nor',
#    'also',
#    'dropany',
#    'drop',
#    'field',
#    (array([0.758]), array([0.533]))],
#   ['ahead',
#    'although',
#    'aheadlong',
#    'agency',
#    'ahead',
#    'agency',
#    'effort',
#    (array([0.122]), array([0.307]))],
#   ['fieldfind',
#    'field',
#    'majority',
#    'agency',
#    'ahead',
#    'ahead',
#    'majority',
#    (array([0.63]), array([0.639]))],
#   ['ahead',
#    'norfind',
#    'nor',
#    'effort',
#    'althoughany',
#    'color',
#    'although',
#    (array([0.38]), array([0.942]))],
#   ['majority', 'majority', 'majority', (array([0.76]), array([0.556]))],
#   ['althoughany',
#    'field',
#    'although',
#    'although',
#    'although',
#    (array([0.899]), array([0.115]))],
#   ['ahead',
#    'effort',
#    'dropkind',
#    'drop',
#    'although',
#    (array([0.084]), array([0.926]))],
#   ['droplong',
#    'drop',
#    'agency',
#    'although',
#    'fieldwater',
#    'field',
#    'although',
#    (array([0.48]), array([0.287]))],
#   ['ahead', (array([0.311]), array([0.758]))],
#   ['drop', 'dropshoulder', 'drop', 'drop', (array([0.965]), array([0.158]))]],
#  [['field', 'also', 'candidate', (array([0.768]), array([0.822]))],
#   ['agency',
#    'ahead',
#    'effort',
#    'majority',
#    'although',
#    (array([0.916]), array([0.851]))],
#   ['drop', (array([0.488]), array([0.351]))],
#   ['color', 'hit', 'factor', (array([0.57]), array([0.118]))],
#   ['nor', 'eye', 'piece', 'statement', (array([0.006]), array([0.532]))]]]

# %% [markdown]
# # Triggerfunction
#
# Die Triggerfunktionen werden ein Set von Funktionen sein, welche sobald festgelegte Bedingungen in der Entwicklung einer Generation auftreten, die Verhaltenswahrscheinlichkeiten von auszuwählenden Topics umschreibt. Dies hat den zweck, eine Umgebung zu entwickeln, in welcher latent wirkende Muster bereichsübergreifend aktiv sein können. Da diese Umgebung beliebig komplex und verrauscht konstruiert werden kann, soll dies somit ein Testfeld für prognostische, patternanalysierende Algorithmen bieten.
#
#
# Hierfür muss jedeoch zunächst ein neuer Informationsraum geschaffen werden, welcher verwendet wird um Änderungen über Generationen besser nachvollziehen zu können. Dies bedeutet, dass eine Triggerfunktion, welche ein Verhalten trackt aus drei Teilfunktionaltitäten besteht:
#     1. Das Sammeln der benötigten Informationen für den neuen Informationsraum.
#     2. Das Bewerten des neuen Informationsraumen ob eine Änderung getriggert wird.
#     3. Falls getriggert: Das Ändern der Verhaltenswahrscheinlichkeiten.

# %% [raw]
# ## Pseudocode
#
# #stf ^= simple_trigger_function
# def get_data_for_stf(inputdata):
#     take input data and create information space needed.
#     return information space needed to stf()
#
# def check_data_for_pattern_stf(data from get_data_for_stf):
#     take input data and check if a contraint in behaviour is hit
#     if hit:
#         call change_variable_stf()
#
# def change_variable_stf(inputdata):
#     goes to topic space from input data and changes behavioural parameters
#     ##This can be run after creating a generation and override it before handing it over as input for the next generation
#
#
# def stf():
#     new_information_space = []
#     new_information_space = get_data_for_stf(place where the informations are taken)
#     check_data_for_pattern_stf(new_information_space)
#         if true:
#             change_variable_stf(topic_space place which shall be changed)
